# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "CIFAR10"
MODEL_NAME = "VGG16"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 100
LOCAL_BS = 32 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Plane':0,
               'Car':1, 
               'Bird':2, 
               'Cat':3, 
               'Deer':4,
               'Dog':5, 
               'Frog':6, 
               'Horse':7, 
               'Ship':8, 
               'Truck':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 5 # the source class
TARGET_CLASS = 3 # the target class 

CLASS_PER_PEER = 1
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating VGG16 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/110 [00:00<?, ?it/s]
#  | Global training round : 1/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.116511
# Mixing took 3.4031
# -> Update reputation
# Aggregation took 3.2159
#
# Average test loss: 2.3130, Test accuracy: 1035/10000 (10.35%)
#
# Class      - Accuracy
# Plane      - 0.1
# Car        - 0.6
# Bird       - 0.2
# Cat        - 0.0
# Deer       - 2.4
# Dog        - 0.0
# Frog       - 99.9
# Horse      - 0.0
# Ship       - 0.3
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/110 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: 0.0
# Peer 19  is  honest reputation: 0.044448256492614746
# Peer 18  is  honest reputation: 0.005255520343780518
# Peer 7  is  honest reputation: -8.958578109741211e-05
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0002688169479370117
# Peer 3  is  honest reputation: 0.02769792079925537
# Peer 16  is  honest reputation: -0.04854941368103027
# Peer 1  is  honest reputation: 0.016990959644317627
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 1.893535
# Mixing took 3.1328
# -> Update reputation
# Aggregation took 3.0508
#
# Average test loss: 1.9291, Test accuracy: 2714/10000 (27.14%)
#
# Class      - Accuracy
# Plane      - 43.7
# Car        - 53.2
# Bird       - 8.3
# Cat        - 1.5
# Deer       - 12.6
# Dog        - 1.7
# Frog       - 90.6
# Horse      - 12.8
# Ship       - 35.8
# Truck      - 11.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.0820465087890625
# Peer 4  is  honest reputation: 0.05699431896209717
# Peer 12  is  attacker reputation: -0.1783510446548462
# Peer 5  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.009416043758392334
# Peer 2  is  attacker reputation: -0.2586359977722168
# Peer 15  is  honest reputation: 0.084384024143219
# Peer 3  is  honest reputation: 0.027454078197479248
# Peer 17  is  honest reputation: 0.059403955936431885
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 1.681261
# Mixing took 3.0097
# -> Update reputation
# Aggregation took 3.1358
#
# Average test loss: 1.6613, Test accuracy: 3672/10000 (36.72%)
#
# Class      - Accuracy
# Plane      - 44.9
# Car        - 38.9
# Bird       - 13.4
# Cat        - 31.8
# Deer       - 20.8
# Dog        - 0.0
# Frog       - 80.5
# Horse      - 35.5
# Ship       - 49.5
# Truck      - 51.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.12955516576766968
# Peer 6  is  honest reputation: -0.069327712059021
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.07305794954299927
# Peer 18  is  honest reputation: 0.10697484016418457
# Peer 12  is  attacker reputation: -0.12714248895645142
# Peer 13  is  honest reputation: -0.05365878343582153
# Peer 5  is  attacker reputation: 0.03397810459136963
# Peer 11  is  honest reputation: -0.12502938508987427
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 1.543855
# Mixing took 3.0738
# -> Update reputation
# Aggregation took 3.1238
#
# Average test loss: 1.4962, Test accuracy: 4468/10000 (44.68%)
#
# Class      - Accuracy
# Plane      - 45.7
# Car        - 63.8
# Bird       - 23.7
# Cat        - 31.9
# Deer       - 51.4
# Dog        - 10.3
# Frog       - 72.3
# Horse      - 49.6
# Ship       - 50.1
# Truck      - 48.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.20203012228012085
# Peer 13  is  honest reputation: 0.07176661491394043
# Peer 2  is  attacker reputation: -0.21783626079559326
# Peer 3  is  honest reputation: 0.14405691623687744
# Peer 12  is  attacker reputation: -0.17408382892608643
# Peer 16  is  honest reputation: -0.04781794548034668
# Peer 0  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.10365647077560425
# Peer 19  is  honest reputation: 0.22658240795135498
# Average of peers' local losses: 1.391706
# Mixing took 3.1559
# -> Update reputation
# Aggregation took 3.1969
#
# Average test loss: 1.3953, Test accuracy: 4802/10000 (48.02%)
#
# Class      - Accuracy
# Plane      - 32.7
# Car        - 74.6
# Bird       - 21.8
# Cat        - 43.6
# Deer       - 51.9
# Dog        - 0.0
# Frog       - 79.0
# Horse      - 54.4
# Ship       - 75.5
# Truck      - 46.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.11110508441925049
# Peer 14  is  honest reputation: 0.017040669918060303
# Peer 7  is  honest reputation: 0.08574157953262329
# Peer 18  is  honest reputation: 0.2641168236732483
# Peer 8  is  honest reputation: 0.1366700530052185
# Peer 6  is  honest reputation: 0.04176229238510132
# Peer 5  is  attacker reputation: -0.09008806943893433
# Peer 11  is  honest reputation: -0.06560879945755005
# Peer 2  is  attacker reputation: -0.22351646423339844
# Peer 3  is  honest reputation: 0.2603016495704651
# Average of peers' local losses: 1.273543
# Mixing took 3.305
# -> Update reputation
# Aggregation took 3.2079
#
# Average test loss: 1.3035, Test accuracy: 5268/10000 (52.68%)
#
# Class      - Accuracy
# Plane      - 41.4
# Car        - 68.6
# Bird       - 30.4
# Cat        - 36.5
# Deer       - 55.1
# Dog        - 9.7
# Frog       - 83.3
# Horse      - 58.1
# Ship       - 75.7
# Truck      - 68.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.16776806116104126
# Peer 2  is  attacker reputation: -0.3133149743080139
# Peer 7  is  honest reputation: 0.11718219518661499
# Peer 5  is  attacker reputation: -0.06944280862808228
# Peer 19  is  honest reputation: 0.36581188440322876
# Peer 11  is  honest reputation: -0.07249057292938232
# Peer 16  is  honest reputation: 0.046146929264068604
# Peer 6  is  honest reputation: -0.06927543878555298
# Peer 8  is  honest reputation: 0.2244887351989746
# Peer 13  is  honest reputation: 0.18512558937072754
# Average of peers' local losses: 1.172187
# Mixing took 3.3871
# -> Update reputation
# Aggregation took 3.2259
#
# Average test loss: 1.2087, Test accuracy: 5677/10000 (56.77%)
#
# Class      - Accuracy
# Plane      - 46.9
# Car        - 73.1
# Bird       - 33.0
# Cat        - 43.0
# Deer       - 64.3
# Dog        - 21.3
# Frog       - 81.3
# Horse      - 56.8
# Ship       - 82.0
# Truck      - 66.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/110 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -0.39092618227005005
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.2334015965461731
# Peer 11  is  honest reputation: -0.043922364711761475
# Peer 0  is  attacker reputation: 0.054027020931243896
# Peer 10  is  honest reputation: -0.00483393669128418
# Peer 4  is  honest reputation: 0.1647971272468567
# Peer 12  is  attacker reputation: -0.2720080614089966
# Peer 18  is  honest reputation: 0.3348328471183777
# Peer 5  is  attacker reputation: -0.047784626483917236
# Average of peers' local losses: 1.040640
# Mixing took 3.4822
# -> Update reputation
# Aggregation took 3.256
#
# Average test loss: 1.1789, Test accuracy: 5729/10000 (57.29%)
#
# Class      - Accuracy
# Plane      - 50.9
# Car        - 78.6
# Bird       - 47.2
# Cat        - 50.7
# Deer       - 56.9
# Dog        - 0.1
# Frog       - 78.5
# Horse      - 58.8
# Ship       - 82.2
# Truck      - 69.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.3307393789291382
# Peer 8  is  honest reputation: 0.323741614818573
# Peer 15  is  honest reputation: 0.22253668308258057
# Peer 3  is  honest reputation: 0.3032068610191345
# Peer 0  is  attacker reputation: 0.06630748510360718
# Peer 17  is  honest reputation: 0.15750306844711304
# Peer 11  is  honest reputation: -0.14057934284210205
# Peer 6  is  honest reputation: 0.03308892250061035
# Peer 9  is  honest reputation: 0.07755565643310547
# Peer 10  is  honest reputation: 0.05707836151123047
# Average of peers' local losses: 0.981967
# Mixing took 3.323
# -> Update reputation
# Aggregation took 3.2399
#
# Average test loss: 1.1116, Test accuracy: 6159/10000 (61.59%)
#
# Class      - Accuracy
# Plane      - 55.5
# Car        - 81.3
# Bird       - 51.5
# Cat        - 38.1
# Deer       - 64.9
# Dog        - 38.8
# Frog       - 81.4
# Horse      - 58.2
# Ship       - 81.2
# Truck      - 65.0
#
# Backdoor ASR 0.0
#  | Global training round : 10/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.11290830373764038
# Peer 11  is  honest reputation: -0.1523635983467102
# Peer 2  is  attacker reputation: -0.44235074520111084
# Peer 12  is  attacker reputation: -0.16424214839935303
# Peer 1  is  honest reputation: 0.2045179009437561
# Peer 13  is  honest reputation: 0.2567254900932312
# Peer 4  is  honest reputation: 0.2663041949272156
# Peer 18  is  honest reputation: 0.44991493225097656
# Peer 16  is  honest reputation: -0.09098434448242188
# Peer 10  is  honest reputation: 0.039267539978027344
# Average of peers' local losses: 0.885899
# Mixing took 3.4191
# -> Update reputation
# Aggregation took 3.2439
#
# Average test loss: 1.0682, Test accuracy: 6389/10000 (63.89%)
#
# Class      - Accuracy
# Plane      - 58.3
# Car        - 81.5
# Bird       - 53.6
# Cat        - 54.7
# Deer       - 66.0
# Dog        - 30.4
# Frog       - 77.8
# Horse      - 62.2
# Ship       - 85.2
# Truck      - 69.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.18335241079330444
# Peer 17  is  honest reputation: 0.3050006628036499
# Peer 10  is  honest reputation: 0.11152642965316772
# Peer 4  is  honest reputation: 0.417125940322876
# Peer 7  is  honest reputation: 0.19623291492462158
# Peer 18  is  honest reputation: 0.6032902002334595
# Peer 8  is  honest reputation: 0.4506506323814392
# Peer 19  is  honest reputation: 0.42333686351776123
# Peer 14  is  honest reputation: 0.10939311981201172
# Peer 3  is  honest reputation: 0.5042316317558289
# Average of peers' local losses: 0.836168
# Mixing took 3.4862
# -> Update reputation
# [0.54265419 0.39020869 0.01289348 0.42735555 0.2714973  0.12458771
#  0.51251861 0.39814842 0.42869214 0.17959579]
# Aggregation took 2.149
#
# Average test loss: 0.9767, Test accuracy: 6788/10000 (67.88%)
#
# Class      - Accuracy
# Plane      - 69.7
# Car        - 85.2
# Bird       - 47.7
# Cat        - 45.6
# Deer       - 71.4
# Dog        - 46.7
# Frog       - 80.7
# Horse      - 70.4
# Ship       - 81.9
# Truck      - 79.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.4482293128967285
# Peer 14  is  honest reputation: 0.20834767818450928
# Peer 5  is  attacker reputation: 0.07633155584335327
# Peer 13  is  honest reputation: 0.37558627128601074
# Peer 17  is  honest reputation: 0.43882888555526733
# Peer 6  is  honest reputation: 0.1874651312828064
# Peer 19  is  honest reputation: 0.4850759506225586
# Peer 7  is  honest reputation: 0.3052622675895691
# Peer 8  is  honest reputation: 0.483439564704895
# Peer 15  is  honest reputation: 0.3947297930717468
# Average of peers' local losses: 0.759336
# Mixing took 3.5933
# -> Update reputation
# [0.44740865 0.42143724 0.1966756  0.0436188  0.38353375 0.52290632
#  0.32702247 0.15321804 0.52585853 0.46976153]
# Aggregation took 2.176
#
# Average test loss: 0.9888, Test accuracy: 6822/10000 (68.22%)
#
# Class      - Accuracy
# Plane      - 67.2
# Car        - 85.7
# Bird       - 53.7
# Cat        - 43.7
# Deer       - 68.8
# Dog        - 44.1
# Frog       - 86.0
# Horse      - 69.7
# Ship       - 84.8
# Truck      - 78.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.6071141958236694
# Peer 14  is  honest reputation: 0.22605472803115845
# Peer 10  is  honest reputation: 0.03967690467834473
# Peer 9  is  honest reputation: 0.1520211100578308
# Peer 7  is  honest reputation: 0.43097901344299316
# Peer 6  is  honest reputation: 0.18121689558029175
# Peer 15  is  honest reputation: 0.3662732243537903
# Peer 13  is  honest reputation: 0.5082383751869202
# Peer 1  is  honest reputation: 0.16948288679122925
# Peer 5  is  attacker reputation: 0.07042920589447021
# Average of peers' local losses: 0.705225
# Mixing took 3.4141
# -> Update reputation
# [0.49381517 0.17300832 0.2797873  0.48517672 0.13777408 0.2926664
#  0.25509807 0.39954929 0.49949364 0.        ]
# Aggregation took 2.0619
#
# Average test loss: 0.9458, Test accuracy: 7065/10000 (70.65%)
#
# Class      - Accuracy
# Plane      - 70.5
# Car        - 86.1
# Bird       - 56.1
# Cat        - 50.3
# Deer       - 72.3
# Dog        - 50.8
# Frog       - 81.5
# Horse      - 74.9
# Ship       - 83.9
# Truck      - 80.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.5929223895072937
# Peer 19  is  honest reputation: 0.6111860871315002
# Peer 3  is  honest reputation: 0.6346926689147949
# Peer 14  is  honest reputation: 0.28741931915283203
# Peer 8  is  honest reputation: 0.5156720280647278
# Peer 4  is  honest reputation: 0.47622108459472656
# Peer 6  is  honest reputation: 0.27339065074920654
# Peer 17  is  honest reputation: 0.5365470051765442
# Peer 13  is  honest reputation: 0.534570574760437
# Peer 15  is  honest reputation: 0.4090518355369568
# Average of peers' local losses: 0.615570
# Mixing took 3.5963
# -> Update reputation
# [0.6600043  0.49040217 0.58405593 0.3877041  0.38780782 0.44559589
#  0.58318404 0.34242226 0.55318629 0.44566596]
# Aggregation took 2.1019
#
# Average test loss: 0.9363, Test accuracy: 7162/10000 (71.62%)
#
# Class      - Accuracy
# Plane      - 72.7
# Car        - 88.5
# Bird       - 62.4
# Cat        - 45.2
# Deer       - 71.1
# Dog        - 56.4
# Frog       - 83.3
# Horse      - 71.0
# Ship       - 86.0
# Truck      - 79.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.653213620185852
# Peer 3  is  honest reputation: 0.7787606120109558
# Peer 9  is  honest reputation: 0.2467975616455078
# Peer 1  is  honest reputation: 0.16070550680160522
# Peer 13  is  honest reputation: 0.46513086557388306
# Peer 7  is  honest reputation: 0.527032732963562
# Peer 19  is  honest reputation: 0.6089003682136536
# Peer 17  is  honest reputation: 0.6545358896255493
# Peer 10  is  honest reputation: 0.12459522485733032
# Peer 8  is  honest reputation: 0.5225290656089783
# Average of peers' local losses: 0.577557
# Mixing took 3.4782
# -> Update reputation
# [0.44189    0.47776585 0.39204103 0.25761197 0.21929512 0.6528711
#  0.64597456 0.6173001  0.65575493 0.50421118]
# Aggregation took 2.0749
#
# Average test loss: 0.9429, Test accuracy: 7246/10000 (72.46%)
#
# Class      - Accuracy
# Plane      - 72.3
# Car        - 87.4
# Bird       - 61.2
# Cat        - 52.7
# Deer       - 70.6
# Dog        - 55.9
# Frog       - 84.5
# Horse      - 72.4
# Ship       - 85.1
# Truck      - 82.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.4605163335800171
# Peer 9  is  honest reputation: 0.40014880895614624
# Peer 6  is  honest reputation: 0.34277331829071045
# Peer 8  is  honest reputation: 0.5060246586799622
# Peer 1  is  honest reputation: 0.20885485410690308
# Peer 14  is  honest reputation: 0.3950344920158386
# Peer 4  is  honest reputation: 0.3951565623283386
# Peer 0  is  attacker reputation: -0.011899888515472412
# Peer 18  is  honest reputation: 0.7542989253997803
# Peer 3  is  honest reputation: 0.7712686061859131
# Average of peers' local losses: 0.536584
# Mixing took 3.336
# -> Update reputation
# [0.43661893 0.66807912 0.42222172 0.30066819 0.46500285 0.68352397
#  0.46935885 0.39264051 0.         0.47503277]
# Aggregation took 2.0529
#
# Average test loss: 0.9269, Test accuracy: 7356/10000 (73.56%)
#
# Class      - Accuracy
# Plane      - 73.1
# Car        - 86.4
# Bird       - 58.6
# Cat        - 51.7
# Deer       - 73.2
# Dog        - 65.4
# Frog       - 83.1
# Horse      - 76.2
# Ship       - 88.1
# Truck      - 79.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.5408762693405151
# Peer 10  is  honest reputation: 0.24948829412460327
# Peer 15  is  honest reputation: 0.46521830558776855
# Peer 8  is  honest reputation: 0.426572322845459
# Peer 18  is  honest reputation: 0.8118781447410583
# Peer 13  is  honest reputation: 0.4927294850349426
# Peer 5  is  attacker reputation: -0.020542919635772705
# Peer 9  is  honest reputation: 0.4854273796081543
# Peer 6  is  honest reputation: 0.44422537088394165
# Peer 4  is  honest reputation: 0.39109766483306885
# Average of peers' local losses: 0.488703
# Mixing took 3.4962
# -> Update reputation
# [0.5303497  0.45295259 0.59412523 0.75251959 0.42487664 0.28579835
#  0.60284848 0.         0.50741316 0.46519874]
# Aggregation took 2.0559
#
# Average test loss: 0.9082, Test accuracy: 7355/10000 (73.55%)
# Class      - Accuracy
# Plane      - 74.6
# Car        - 85.3
# Bird       - 58.8
# Cat        - 55.2
# Deer       - 72.5
# Dog        - 58.9
# Frog       - 84.7
# Horse      - 75.8
# Ship       - 86.2
# Truck      - 83.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.4550939202308655
# Peer 3  is  honest reputation: 0.7834453582763672
# Peer 14  is  honest reputation: 0.47985517978668213
# Peer 4  is  honest reputation: 0.40479642152786255
# Peer 6  is  honest reputation: 0.5104082226753235
# Peer 8  is  honest reputation: 0.43957722187042236
# Peer 17  is  honest reputation: 0.7662258148193359
# Peer 12  is  attacker reputation: -0.03365260362625122
# Peer 15  is  honest reputation: 0.6351863145828247
# Peer 19  is  honest reputation: 0.7065705060958862
# Average of peers' local losses: 0.448431
# Mixing took 3.248
# -> Update reputation
# [0.50883552 0.69064817 0.45756444 0.         0.78290832 0.64250674
#  0.67247177 0.4880311  0.53083715 0.73167858]
# Aggregation took 2.0549
#
# Average test loss: 0.9364, Test accuracy: 7377/10000 (73.77%)
#
# Class      - Accuracy
# Plane      - 77.4
# Car        - 84.8
# Bird       - 62.9
# Cat        - 49.9
# Deer       - 75.9
# Dog        - 60.1
# Frog       - 84.3
# Horse      - 73.4
# Ship       - 85.8
# Truck      - 83.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.5418000221252441
# Peer 19  is  honest reputation: 0.7547541260719299
# Peer 4  is  honest reputation: 0.46671730279922485
# Peer 7  is  honest reputation: 0.6487783193588257
# Peer 17  is  honest reputation: 0.9584008455276489
# Peer 14  is  honest reputation: 0.3997865319252014
# Peer 15  is  honest reputation: 0.7208019495010376
# Peer 1  is  honest reputation: 0.28643369674682617
# Peer 18  is  honest reputation: 0.9299076199531555
# Peer 5  is  attacker reputation: -0.09436842799186707
# Average of peers' local losses: 0.413722
# Mixing took 3.4581
# -> Update reputation
# [0.71471969 0.83110691 0.76798764 0.66793503 0.52009609 0.58478572
#  0.         0.58497379 0.42853779 0.67465442]
# Aggregation took 2.0609
#
# Average test loss: 0.9365, Test accuracy: 7472/10000 (74.72%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 85.5
# Bird       - 62.2
# Cat        - 57.3
# Deer       - 75.3
# Dog        - 58.6
# Frog       - 83.8
# Horse      - 76.2
# Ship       - 85.4
# Truck      - 83.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.7134345173835754
# Peer 8  is  honest reputation: 0.49687016010284424
# Peer 19  is  honest reputation: 0.7909637689590454
# Peer 18  is  honest reputation: 0.9096007347106934
# Peer 6  is  honest reputation: 0.6679912805557251
# Peer 9  is  honest reputation: 0.5639023184776306
# Peer 7  is  honest reputation: 0.701202929019928
# Peer 17  is  honest reputation: 1.085902452468872
# Peer 10  is  honest reputation: 0.2451533079147339
# Peer 4  is  honest reputation: 0.5641881823539734
# Average of peers' local losses: 0.369936
# Mixing took 3.4161
# -> Update reputation
# [0.7217591  0.86834431 0.61412379 0.77669484 0.67376098 0.71830526
#  0.66501975 0.25730428 0.76156142 0.57861805]
# Aggregation took 2.0929
#
# Average test loss: 0.9542, Test accuracy: 7499/10000 (74.99%)
#
# Class      - Accuracy
# Plane      - 75.9
# Car        - 89.5
# Bird       - 63.0
# Cat        - 53.8
# Deer       - 72.9
# Dog        - 61.9
# Frog       - 88.4
# Horse      - 76.4
# Ship       - 86.3
# Truck      - 81.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.6097128987312317
# Peer 3  is  honest reputation: 0.8378905653953552
# Peer 14  is  honest reputation: 0.4706689119338989
# Peer 18  is  honest reputation: 0.8941195011138916
# Peer 9  is  honest reputation: 0.5545801520347595
# Peer 1  is  honest reputation: 0.35230159759521484
# Peer 4  is  honest reputation: 0.7117965221405029
# Peer 10  is  honest reputation: 0.15741685032844543
# Peer 17  is  honest reputation: 1.2205063700675964
# Peer 19  is  honest reputation: 0.931182861328125
# Average of peers' local losses: 0.341286
# Mixing took 2.8666
# -> Update reputation
# [0.78371272 0.88236209 0.24598908 0.52760172 0.74342243 0.73874906
#  0.74763993 0.63592877]
# Aggregation took 1.7436
#
# Average test loss: 0.9426, Test accuracy: 7512/10000 (75.12%)
#
# Class      - Accuracy
# Plane      - 76.8
# Car        - 86.8
# Bird       - 61.3
# Cat        - 55.6
# Deer       - 76.8
# Dog        - 67.2
# Frog       - 83.2
# Horse      - 73.4
# Ship       - 86.3
# Truck      - 83.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.8055046796798706
# Peer 14  is  honest reputation: 0.48101335763931274
# Peer 13  is  honest reputation: 0.43903273344039917
# Peer 1  is  honest reputation: 0.35230159759521484
# Peer 15  is  honest reputation: 0.7983323335647583
# Peer 10  is  honest reputation: 0.14533647894859314
# Peer 19  is  honest reputation: 0.9491198062896729
# Peer 18  is  honest reputation: 0.8522846102714539
# Peer 6  is  honest reputation: 0.6959577798843384
# Peer 9  is  honest reputation: 0.6455056667327881
# Average of peers' local losses: 0.332639
# Mixing took 2.6514
# -> Update reputation
# [0.81110224 0.74823766 0.69789895 0.25757938 0.61683379 0.40159464
#  0.6791351  0.69705979]
# Aggregation took 1.6895
#
# Average test loss: 0.9730, Test accuracy: 7552/10000 (75.52%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 85.8
# Bird       - 65.6
# Cat        - 50.4
# Deer       - 74.4
# Dog        - 65.0
# Frog       - 83.6
# Horse      - 80.1
# Ship       - 87.6
# Truck      - 82.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.8419173359870911
# Peer 15  is  honest reputation: 0.7983323335647583
# Peer 9  is  honest reputation: 0.7557559609413147
# Peer 10  is  honest reputation: 0.1577114760875702
# Peer 7  is  honest reputation: 0.7573900818824768
# Peer 16  is  honest reputation: -0.09465426206588745
# Peer 19  is  honest reputation: 1.0244399309158325
# Peer 1  is  honest reputation: 0.319746196269989
# Peer 18  is  honest reputation: 0.8631364107131958
# Peer 17  is  honest reputation: 1.2805331349372864
# Average of peers' local losses: 0.325210
# Mixing took 3.5622
# -> Update reputation
# [0.         0.73428212 0.84770572 0.75143624 0.71687235 0.76400869
#  0.46724023 0.36580236 0.77525871 0.90987647]
# Aggregation took 2.219
#
# Average test loss: 0.9445, Test accuracy: 7550/10000 (75.50%)
#
# Class      - Accuracy
# Plane      - 77.7
# Car        - 87.8
# Bird       - 63.6
# Cat        - 49.1
# Deer       - 76.9
# Dog        - 67.9
# Frog       - 84.0
# Horse      - 77.9
# Ship       - 87.0
# Truck      - 83.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/110 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.3565009832382202
# Peer 6  is  honest reputation: 0.7217044234275818
# Peer 4  is  honest reputation: 0.8617797493934631
# Peer 7  is  honest reputation: 0.8262130618095398
# Peer 13  is  honest reputation: 0.43903273344039917
# Peer 14  is  honest reputation: 0.6140755414962769
# Peer 15  is  honest reputation: 0.8833428025245667
# Peer 8  is  honest reputation: 0.6097128987312317
# Peer 0  is  attacker reputation: -0.13924744725227356
# Peer 10  is  honest reputation: 0.23353537917137146
# Average of peers' local losses: 0.328591
# Mixing took 2.4412
# -> Update reputation
# [0.68617727 0.         0.78519721 0.76811131 0.55435278 0.80923381
#  0.45909085 0.59512123]
# Aggregation took 1.6435
#
# Average test loss: 0.9284, Test accuracy: 7567/10000 (75.67%)
#
# Class      - Accuracy
# Plane      - 79.2
# Car        - 86.8
# Bird       - 64.0
# Cat        - 58.5
# Deer       - 74.7
# Dog        - 58.7
# Frog       - 88.5
# Horse      - 76.4
# Ship       - 86.9
# Truck      - 83.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.31018009781837463
# Peer 3  is  honest reputation: 0.8557416200637817
# Peer 9  is  honest reputation: 0.7511478662490845
# Peer 14  is  honest reputation: 0.6547168493270874
# Peer 6  is  honest reputation: 0.7217044234275818
# Peer 4  is  honest reputation: 0.9388264417648315
# Peer 15  is  honest reputation: 0.872803270816803
# Peer 7  is  honest reputation: 0.8297262191772461
# Peer 5  is  attacker reputation: -0.1823895275592804
# Peer 18  is  honest reputation: 0.7879238724708557
# Average of peers' local losses: 0.267946
# Mixing took 3.0668
# -> Update reputation
# [0.74100312 0.77745718 0.73885361 0.79459047 0.68054147 0.
#  0.81601483 0.82077979 0.48937489 0.78102564]
# Aggregation took 2.0008
#
# Average test loss: 0.9275, Test accuracy: 7621/10000 (76.21%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 88.8
# Bird       - 65.5
# Cat        - 54.8
# Deer       - 73.5
# Dog        - 63.8
# Frog       - 84.3
# Horse      - 79.0
# Ship       - 88.2
# Truck      - 84.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.8396257162094116
# Peer 19  is  honest reputation: 1.097909688949585
# Peer 7  is  honest reputation: 0.8844791650772095
# Peer 1  is  honest reputation: 0.4386647939682007
# Peer 17  is  honest reputation: 1.3767732977867126
# Peer 6  is  honest reputation: 0.7534162998199463
# Peer 10  is  honest reputation: 0.3359539806842804
# Peer 16  is  honest reputation: -0.19674599170684814
# Peer 8  is  honest reputation: 0.6097128987312317
# Peer 13  is  honest reputation: 0.4995800256729126
# Average of peers' local losses: 0.279472
# Mixing took 3.0538
# -> Update reputation
# [0.73038609 0.86885731 0.57217397 0.92498839 0.49388883 0.80363376
#  0.         0.67062557 0.76577743 0.74926854]
# Aggregation took 2.0158
#
# Average test loss: 0.9350, Test accuracy: 7642/10000 (76.42%)
#
# Class      - Accuracy
# Plane      - 78.2
# Car        - 88.9
# Bird       - 64.8
# Cat        - 55.5
# Deer       - 77.6
# Dog        - 63.6
# Frog       - 84.7
# Horse      - 78.8
# Ship       - 89.1
# Truck      - 83.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.9018399119377136
# Peer 14  is  honest reputation: 0.7486660480499268
# Peer 9  is  honest reputation: 0.6308378577232361
# Peer 1  is  honest reputation: 0.44380033016204834
# Peer 15  is  honest reputation: 0.9454882144927979
# Peer 13  is  honest reputation: 0.6049304604530334
# Peer 10  is  honest reputation: 0.3342421352863312
# Peer 7  is  honest reputation: 0.8030886054039001
# Peer 8  is  honest reputation: 0.7226057648658752
# Peer 6  is  honest reputation: 0.7643365859985352
# Average of peers' local losses: 0.215261
# Mixing took 2.3942
# -> Update reputation
# [0.50465847 0.71483904 0.84448012 0.78556886 0.69840908 0.57959825
#  0.71445668 0.74923144]
# Aggregation took 1.6385
#
# Average test loss: 0.9294, Test accuracy: 7641/10000 (76.41%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 86.2
# Bird       - 65.8
# Cat        - 58.0
# Deer       - 76.6
# Dog        - 61.4
# Frog       - 83.5
# Horse      - 80.5
# Ship       - 88.0
# Truck      - 84.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.0296409130096436
# Peer 1  is  honest reputation: 0.4549088478088379
# Peer 4  is  honest reputation: 0.9599183797836304
# Peer 13  is  honest reputation: 0.6572391986846924
# Peer 19  is  honest reputation: 1.121449589729309
# Peer 10  is  honest reputation: 0.3485881984233856
# Peer 3  is  honest reputation: 0.8487109541893005
# Peer 8  is  honest reputation: 0.6892802119255066
# Peer 6  is  honest reputation: 0.7643365859985352
# Peer 7  is  honest reputation: 0.8030886054039001
# Average of peers' local losses: 0.209888
# Mixing took 1.8387
# -> Update reputation
# [0.46811461 0.55389224 0.89697373 0.82065706 0.76863872 0.87410651]
# Aggregation took 1.2131
#
# Average test loss: 0.9634, Test accuracy: 7628/10000 (76.28%)
#
# Class      - Accuracy
# Plane      - 74.9
# Car        - 88.3
# Bird       - 66.1
# Cat        - 54.8
# Deer       - 76.8
# Dog        - 68.0
# Frog       - 84.7
# Horse      - 78.4
# Ship       - 87.8
# Truck      - 83.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/110 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.7643365859985352
# Peer 15  is  honest reputation: 1.143276870250702
# Peer 12  is  attacker reputation: -0.2068982720375061
# Peer 7  is  honest reputation: 0.951877772808075
# Peer 18  is  honest reputation: 0.7642520070075989
# Peer 9  is  honest reputation: 0.6900616884231567
# Peer 19  is  honest reputation: 1.249566912651062
# Peer 13  is  honest reputation: 0.6572391986846924
# Peer 14  is  honest reputation: 0.8528031706809998
# Peer 10  is  honest reputation: 0.3007044494152069
# Average of peers' local losses: 0.187820
# Mixing took 2.4322
# -> Update reputation
# [0.9088554  0.79630351 0.71931888 0.73075766 0.         0.82437922
#  0.53040008 0.81628395]
# Aggregation took 1.6145
#
# Average test loss: 0.9842, Test accuracy: 7658/10000 (76.58%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 89.2
# Bird       - 65.6
# Cat        - 54.5
# Deer       - 75.7
# Dog        - 63.7
# Frog       - 86.8
# Horse      - 80.3
# Ship       - 85.9
# Truck      - 84.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/110 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: -0.20709985494613647
# Peer 15  is  honest reputation: 0.959210604429245
# Peer 7  is  honest reputation: 0.951877772808075
# Peer 10  is  honest reputation: 0.37957826256752014
# Peer 6  is  honest reputation: 0.8773041367530823
# Peer 17  is  honest reputation: 1.4155674576759338
# Peer 4  is  honest reputation: 0.9599183797836304
# Peer 9  is  honest reputation: 0.7192279100418091
# Peer 14  is  honest reputation: 0.9344548583030701
# Peer 19  is  honest reputation: 1.3097825050354004
# Average of peers' local losses: 0.183881
# Mixing took 2.4202
# -> Update reputation
# [0.91277591 0.85522514 0.03364009 0.92585861 0.7190749  0.75838544
#  0.78874256 0.78516453]
# Aggregation took 1.6275
#
# Average test loss: 0.9453, Test accuracy: 7696/10000 (76.96%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 87.7
# Bird       - 66.3
# Cat        - 57.9
# Deer       - 74.3
# Dog        - 66.4
# Frog       - 84.7
# Horse      - 79.7
# Ship       - 86.5
# Truck      - 85.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/110 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.4170301556587219
# Peer 9  is  honest reputation: 0.7834909558296204
# Peer 19  is  honest reputation: 1.4216793775558472
# Peer 8  is  honest reputation: 0.8100438117980957
# Peer 7  is  honest reputation: 0.9458595514297485
# Peer 10  is  honest reputation: 0.37957826256752014
# Peer 13  is  honest reputation: 0.6951087117195129
# Peer 6  is  honest reputation: 0.8773041367530823
# Peer 18  is  honest reputation: 0.7642520070075989
# Peer 4  is  honest reputation: 1.15305495262146
# Average of peers' local losses: 0.153042
# Mixing took 3.0388
# -> Update reputation
# [0.78776249 0.88561529 0.45296465 0.64661407 0.76149176 0.71730551
#  0.7887153  0.79678261 0.92077869 0.6064519 ]
# Aggregation took 2.0058
#
# Average test loss: 0.9817, Test accuracy: 7681/10000 (76.81%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 87.6
# Bird       - 64.9
# Cat        - 55.1
# Deer       - 75.6
# Dog        - 66.5
# Frog       - 85.8
# Horse      - 79.8
# Ship       - 87.6
# Truck      - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.943271279335022
# Peer 13  is  honest reputation: 0.6472220420837402
# Peer 15  is  honest reputation: 0.870168000459671
# Peer 7  is  honest reputation: 0.9457874298095703
# Peer 10  is  honest reputation: 0.5810541808605194
# Peer 18  is  honest reputation: 0.7798367142677307
# Peer 6  is  honest reputation: 0.8775204420089722
# Peer 14  is  honest reputation: 0.9364609122276306
# Peer 17  is  honest reputation: 1.5063408613204956
# Peer 1  is  honest reputation: 0.3661881685256958
# Average of peers' local losses: 0.143006
# Mixing took 2.4783
# -> Update reputation
# [0.47751339 0.93388894 0.63703398 0.74039406 0.73594141 0.80782011
#  0.75046572 0.70464361]
# Aggregation took 1.6535
#
# Average test loss: 0.9799, Test accuracy: 7698/10000 (76.98%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 87.8
# Bird       - 64.0
# Cat        - 57.4
# Deer       - 77.7
# Dog        - 66.2
# Frog       - 85.8
# Horse      - 79.6
# Ship       - 86.8
# Truck      - 85.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.9675025343894958
# Peer 6  is  honest reputation: 0.8775204420089722
# Peer 7  is  honest reputation: 0.8517846465110779
# Peer 10  is  honest reputation: 0.6309302747249603
# Peer 19  is  honest reputation: 1.471884548664093
# Peer 3  is  honest reputation: 0.8487109541893005
# Peer 4  is  honest reputation: 1.2789852619171143
# Peer 11  is  honest reputation: -0.08858299255371094
# Peer 18  is  honest reputation: 0.8291152119636536
# Peer 9  is  honest reputation: 0.8193312883377075
# Average of peers' local losses: 0.137679
# Mixing took 2.4112
# -> Update reputation
# [0.76401427 0.94368695 0.03081649 0.87415958 0.80121149 0.76204771
#  0.71951852 0.74248379]
# Aggregation took 1.6245
#
# Average test loss: 1.0032, Test accuracy: 7684/10000 (76.84%)
#
# Class      - Accuracy
# Plane      - 80.2
# Car        - 89.4
# Bird       - 64.1
# Cat        - 56.5
# Deer       - 74.4
# Dog        - 66.1
# Frog       - 85.8
# Horse      - 77.6
# Ship       - 88.1
# Truck      - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.8703654408454895
# Peer 13  is  honest reputation: 0.7542285323143005
# Peer 1  is  honest reputation: 0.3975224494934082
# Peer 7  is  honest reputation: 0.8517846465110779
# Peer 10  is  honest reputation: 0.7759305536746979
# Peer 8  is  honest reputation: 0.9712712168693542
# Peer 15  is  honest reputation: 0.870168000459671
# Peer 18  is  honest reputation: 0.8750725984573364
# Peer 4  is  honest reputation: 1.2197350859642029
# Peer 17  is  honest reputation: 1.5657402873039246
# Average of peers' local losses: 0.138324
# Mixing took 2.4803
# -> Update reputation
# [0.77585701 0.72308912 0.89685213 0.78835588 0.62177833 0.73548971
#  0.93764482 0.77579862]
# Aggregation took 1.8507
#
# Average test loss: 0.9683, Test accuracy: 7674/10000 (76.74%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 89.3
# Bird       - 62.3
# Cat        - 55.3
# Deer       - 75.4
# Dog        - 63.7
# Frog       - 84.7
# Horse      - 80.9
# Ship       - 87.7
# Truck      - 86.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.7833737134933472
# Peer 4  is  honest reputation: 1.325178325176239
# Peer 1  is  honest reputation: 0.3975224494934082
# Peer 3  is  honest reputation: 0.9041616916656494
# Peer 14  is  honest reputation: 0.9984868168830872
# Peer 17  is  honest reputation: 1.5874754786491394
# Peer 11  is  honest reputation: -0.09988915920257568
# Peer 6  is  honest reputation: 0.8775204420089722
# Peer 19  is  honest reputation: 1.6399924159049988
# Peer 8  is  honest reputation: 0.9712712168693542
# Average of peers' local losses: 0.144232
# Mixing took 3.0508
# -> Update reputation
# [0.81532627 0.77402116 0.03352221 0.81674894 0.7764172  0.89501684
#  0.74432136 0.49298582 0.93315648 0.93800739]
# Aggregation took 2.0008
#
# Average test loss: 0.9731, Test accuracy: 7748/10000 (77.48%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 89.8
# Bird       - 65.0
# Cat        - 59.3
# Deer       - 72.8
# Dog        - 67.8
# Frog       - 86.0
# Horse      - 82.0
# Ship       - 87.3
# Truck      - 84.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.9363574981689453
# Peer 18  is  honest reputation: 0.8098669648170471
# Peer 4  is  honest reputation: 1.324001669883728
# Peer 3  is  honest reputation: 0.9076915383338928
# Peer 14  is  honest reputation: 1.024383544921875
# Peer 10  is  honest reputation: 0.5971836447715759
# Peer 9  is  honest reputation: 0.8252766728401184
# Peer 17  is  honest reputation: 1.5596877336502075
# Peer 11  is  honest reputation: -0.08905506134033203
# Peer 6  is  honest reputation: 0.9136961698532104
# Average of peers' local losses: 0.090474
# Mixing took 2.4212
# -> Update reputation
# [0.78155857 0.95459339 0.92863207 0.7236859  0.03726344 0.8763268
#  0.70934607 0.75310791]
# Aggregation took 1.6375
#
# Average test loss: 1.0492, Test accuracy: 7730/10000 (77.30%)
#
# Class      - Accuracy
# Plane      - 83.5
# Car        - 87.9
# Bird       - 63.4
# Cat        - 56.7
# Deer       - 75.7
# Dog        - 66.7
# Frog       - 84.3
# Horse      - 81.9
# Ship       - 87.6
# Truck      - 85.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 1.0201250910758972
# Peer 17  is  honest reputation: 1.769787847995758
# Peer 11  is  honest reputation: -0.07407134771347046
# Peer 6  is  honest reputation: 0.8687449991703033
# Peer 14  is  honest reputation: 1.2483623027801514
# Peer 19  is  honest reputation: 1.5986104011535645
# Peer 10  is  honest reputation: 0.8039889335632324
# Peer 13  is  honest reputation: 0.8375099301338196
# Peer 18  is  honest reputation: 0.8098669648170471
# Peer 7  is  honest reputation: 0.9363574981689453
# Average of peers' local losses: 0.128321
# Mixing took 3.0518
# -> Update reputation
# [0.84767706 0.71425803 0.62236612 0.92668661 0.07069995 0.94225868
#  0.7381904  0.75332487 0.75344719 0.80255212]
# Aggregation took 1.9958
#
# Average test loss: 0.9783, Test accuracy: 7730/10000 (77.30%)
#
# Class      - Accuracy
# Plane      - 81.3
# Car        - 87.2
# Bird       - 66.4
# Cat        - 56.1
# Deer       - 77.6
# Dog        - 64.8
# Frog       - 85.2
# Horse      - 79.6
# Ship       - 88.6
# Truck      - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/110 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 1.2371009588241577
# Peer 17  is  honest reputation: 1.623667061328888
# Peer 7  is  honest reputation: 0.9701415300369263
# Peer 13  is  honest reputation: 0.9698586463928223
# Peer 3  is  honest reputation: 0.9380109310150146
# Peer 15  is  honest reputation: 0.9040150344371796
# Peer 18  is  honest reputation: 0.8850833773612976
# Peer 9  is  honest reputation: 0.774514377117157
# Peer 8  is  honest reputation: 1.0950022339820862
# Peer 1  is  honest reputation: 0.4174073338508606
# Average of peers' local losses: 0.049903
# Mixing took 3.0518
# -> Update reputation
# [0.8480652  0.96928494 0.71193579 0.32575961 0.93771032 0.89392676
#  0.89241487 0.91427155 0.77921079 0.69911969]
# Aggregation took 2.0058
#
# Average test loss: 1.0694, Test accuracy: 7735/10000 (77.35%)
#
# Class      - Accuracy
# Plane      - 82.8
# Car        - 88.0
# Bird       - 65.0
# Cat        - 57.8
# Deer       - 72.9
# Dog        - 67.5
# Frog       - 84.3
# Horse      - 82.1
# Ship       - 86.6
# Truck      - 86.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 2.069596588611603
# Peer 13  is  honest reputation: 1.4303990602493286
# Peer 15  is  honest reputation: 0.8548366725444794
# Peer 6  is  honest reputation: 0.7181180417537689
# Peer 3  is  honest reputation: 0.88035848736763
# Peer 18  is  honest reputation: 1.032618522644043
# Peer 10  is  honest reputation: 0.9357513189315796
# Peer 19  is  honest reputation: 1.7470771074295044
# Peer 7  is  honest reputation: 1.4229234457015991
# Peer 8  is  honest reputation: 1.542214035987854
# Average of peers' local losses: 0.028512
# Mixing took 2.4112
# -> Update reputation
# [0.73195211 0.53579163 0.97168507 0.94644861 0.98578552 0.94964793
#  0.92168781 0.62921359]
# Aggregation took 1.6395
#
# Average test loss: 1.0973, Test accuracy: 7760/10000 (77.60%)
#
# Class      - Accuracy
# Plane      - 83.0
# Car        - 88.4
# Bird       - 65.7
# Cat        - 57.7
# Deer       - 74.5
# Dog        - 67.1
# Frog       - 84.4
# Horse      - 82.8
# Ship       - 86.4
# Truck      - 86.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 1.5893880724906921
# Peer 15  is  honest reputation: 0.729373425245285
# Peer 13  is  honest reputation: 1.8174422979354858
# Peer 6  is  honest reputation: 0.5874940156936646
# Peer 4  is  honest reputation: 1.5370067954063416
# Peer 14  is  honest reputation: 1.7079934477806091
# Peer 11  is  honest reputation: 0.06007826328277588
# Peer 7  is  honest reputation: 1.785820186138153
# Peer 19  is  honest reputation: 2.1108874678611755
# Peer 17  is  honest reputation: 2.459014594554901
# Average of peers' local losses: 0.052526
# Mixing took 3.0568
# -> Update reputation
# [0.9834886  0.99109867 0.99586297 0.8392453  0.98095352 0.97565174
#  0.68920022 0.02757409 0.92371768 0.96377604]
# Aggregation took 1.9958
#
# Average test loss: 1.1233, Test accuracy: 7744/10000 (77.44%)
#
# Class      - Accuracy
# Plane      - 82.9
# Car        - 89.0
# Bird       - 66.2
# Cat        - 59.0
# Deer       - 74.6
# Dog        - 65.9
# Frog       - 83.6
# Horse      - 81.2
# Ship       - 86.9
# Truck      - 85.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 2.564669668674469
# Peer 3  is  honest reputation: 0.9221795499324799
# Peer 6  is  honest reputation: 1.0781645774841309
# Peer 11  is  honest reputation: -0.11286982893943787
# Peer 10  is  honest reputation: 0.9357513189315796
# Peer 7  is  honest reputation: 1.8560009598731995
# Peer 9  is  honest reputation: 1.2384817004203796
# Peer 18  is  honest reputation: 1.032618522644043
# Peer 14  is  honest reputation: 2.181774854660034
# Peer 8  is  honest reputation: 2.0576457381248474
# Average of peers' local losses: 0.056936
# Mixing took 3.0328
# -> Update reputation
# [0.94072954 0.93441519 0.99226052 0.         0.79902845 0.98609242
#  0.9873099  0.91853987 0.98923541 0.94095279]
# Aggregation took 2.0138
#
# Average test loss: 1.1246, Test accuracy: 7776/10000 (77.76%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 88.8
# Bird       - 67.0
# Cat        - 59.9
# Deer       - 74.4
# Dog        - 66.7
# Frog       - 84.4
# Horse      - 80.6
# Ship       - 87.1
# Truck      - 86.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 1.4733359515666962
# Peer 19  is  honest reputation: 2.54259592294693
# Peer 9  is  honest reputation: 1.5135491788387299
# Peer 13  is  honest reputation: 2.253829777240753
# Peer 18  is  honest reputation: 1.4593588411808014
# Peer 14  is  honest reputation: 2.247996062040329
# Peer 0  is  attacker reputation: -0.2231941521167755
# Peer 1  is  honest reputation: 0.32733723521232605
# Peer 15  is  honest reputation: 0.7059798538684845
# Peer 8  is  honest reputation: 2.3768723905086517
# Average of peers' local losses: 0.066134
# Mixing took 2.4002
# -> Update reputation
# [0.48114088 0.99344662 0.98028157 0.97874795 0.         0.9413976
#  0.99634963 0.9952765 ]
# Aggregation took 1.6445
#
# Average test loss: 1.1076, Test accuracy: 7784/10000 (77.84%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 89.1
# Bird       - 69.6
# Cat        - 62.3
# Deer       - 74.2
# Dog        - 61.9
# Frog       - 84.2
# Horse      - 82.3
# Ship       - 88.0
# Truck      - 85.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 2.948975384235382
# Peer 16  is  honest reputation: -0.26141464710235596
# Peer 18  is  honest reputation: 1.4827849566936493
# Peer 7  is  honest reputation: 2.294108361005783
# Peer 8  is  honest reputation: 2.88471457362175
# Peer 1  is  honest reputation: 0.25705888867378235
# Peer 6  is  honest reputation: 1.5116048157215118
# Peer 10  is  honest reputation: 0.8631700575351715
# Peer 3  is  honest reputation: 1.3468537330627441
# Peer 14  is  honest reputation: 2.7555849254131317
# Average of peers' local losses: 0.088173
# Mixing took 1.7996
# -> Update reputation
# [0.99686729 0.00488335 0.9971797  0.99543096 0.95577714 0.45106979]
# Aggregation took 1.2151
#
# Average test loss: 1.0122, Test accuracy: 7792/10000 (77.92%)
#
# Class      - Accuracy
# Plane      - 81.9
# Car        - 88.4
# Bird       - 66.3
# Cat        - 59.6
# Deer       - 75.3
# Dog        - 67.1
# Frog       - 84.8
# Horse      - 82.4
# Ship       - 87.7
# Truck      - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.8631700575351715
# Peer 4  is  honest reputation: 1.9994742572307587
# Peer 9  is  honest reputation: 2.0373115241527557
# Peer 15  is  honest reputation: 0.7059798538684845
# Peer 13  is  honest reputation: 2.253829777240753
# Peer 3  is  honest reputation: 1.3468537330627441
# Peer 7  is  honest reputation: 2.294108361005783
# Peer 14  is  honest reputation: 2.7689150273799896
# Peer 16  is  honest reputation: -0.265857994556427
# Peer 19  is  honest reputation: 2.5914107263088226
# Average of peers' local losses: 0.127531
# Mixing took 2.4212
# -> Update reputation
# [0.03290959 0.99062983 0.97809863 0.98552282 0.99541856 0.7903889
#  0.97192128 0.98899649]
# Aggregation took 1.6205
#
# Average test loss: 0.9517, Test accuracy: 7771/10000 (77.71%)
#
# Class      - Accuracy
# Plane      - 83.3
# Car        - 89.3
# Bird       - 67.2
# Cat        - 55.1
# Deer       - 76.4
# Dog        - 69.0
# Frog       - 82.9
# Horse      - 80.9
# Ship       - 88.2
# Truck      - 84.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.8631700575351715
# Peer 14  is  honest reputation: 2.851670414209366
# Peer 8  is  honest reputation: 2.957976907491684
# Peer 15  is  honest reputation: 0.885839968919754
# Peer 18  is  honest reputation: 1.6239091455936432
# Peer 9  is  honest reputation: 2.0650438964366913
# Peer 13  is  honest reputation: 2.2739049792289734
# Peer 4  is  honest reputation: 1.9392487108707428
# Peer 3  is  honest reputation: 1.3468537330627441
# Peer 16  is  honest reputation: -0.1537056565284729
# Average of peers' local losses: 0.102658
# Mixing took 2.4322
# -> Update reputation
# [0.89147586 0.99598352 0.98998205 0.98492385 0.85901289 0.98179954
#  0.99706623 0.78690489]
# Aggregation took 1.6305
#
# Average test loss: 0.9872, Test accuracy: 7767/10000 (77.67%)
#
# Class      - Accuracy
# Plane      - 82.9
# Car        - 88.7
# Bird       - 66.9
# Cat        - 59.6
# Deer       - 76.0
# Dog        - 64.9
# Frog       - 85.2
# Horse      - 79.7
# Ship       - 87.3
# Truck      - 85.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.6239091455936432
# Peer 3  is  honest reputation: 1.2424428761005402
# Peer 7  is  honest reputation: 2.411958247423172
# Peer 13  is  honest reputation: 2.4591240286827087
# Peer 17  is  honest reputation: 3.0105831027030945
# Peer 4  is  honest reputation: 2.158529609441757
# Peer 10  is  honest reputation: 0.8766237199306488
# Peer 8  is  honest reputation: 2.917615920305252
# Peer 9  is  honest reputation: 2.253483682870865
# Peer 19  is  honest reputation: 2.4927101731300354
# Average of peers' local losses: 0.038277
# Mixing took 2.4122
# -> Update reputation
# [0.99061135 0.9890037  0.98670959 0.94616119 0.95377142 0.99867868
#  0.99435945 0.91529334]
# Aggregation took 1.6325
#
# Average test loss: 1.0191, Test accuracy: 7756/10000 (77.56%)
#
# Class      - Accuracy
# Plane      - 81.0
# Car        - 89.5
# Bird       - 67.4
# Cat        - 57.2
# Deer       - 74.8
# Dog        - 66.7
# Frog       - 84.4
# Horse      - 82.1
# Ship       - 87.1
# Truck      - 85.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/110 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: -0.1537056565284729
# Peer 17  is  honest reputation: 3.474177062511444
# ...
# Peer 4  is  honest reputation: 6.1036630272865295
# Peer 18  is  honest reputation: 4.967225611209869
# Peer 17  is  honest reputation: 7.0811112225055695
# Average of peers' local losses: 0.013597
# Mixing took 3.0408
# -> Update reputation
# [0.99999824 0.99999998 0.99999966 0.99991061 0.99341409 0.9999989
#  0.95072939 0.99998961 0.99996036 1.        ]
# Aggregation took 2.0098
#
# Average test loss: 1.0056, Test accuracy: 7884/10000 (78.84%)
#
# Class      - Accuracy
# Plane      - 83.3
# Car        - 90.2
# Bird       - 68.9
# Cat        - 58.9
# Deer       - 76.2
# Dog        - 67.5
# Frog       - 84.7
# Horse      - 84.4
# Ship       - 87.6
# Truck      - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/110 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 8.006719142198563
# Peer 15  is  honest reputation: 0.7361092269420624
# Peer 7  is  honest reputation: 5.61981937289238
# Peer 8  is  honest reputation: 5.868158638477325
# Peer 6  is  honest reputation: 2.611389845609665
# Peer 3  is  honest reputation: 3.473284959793091
# Peer 1  is  honest reputation: 1.7531294226646423
# Peer 13  is  honest reputation: 3.9046112298965454
# Peer 4  is  honest reputation: 6.102438747882843
# Peer 10  is  honest reputation: 4.311243385076523
# Average of peers' local losses: 0.000949
# Mixing took 2.4102
# -> Update reputation
# [0.99999835 0.99999998 0.99989228 0.99968542 0.9539093  0.99381981
#  0.99999896 0.99996394]
# Aggregation took 1.6415
#
# Average test loss: 1.0437, Test accuracy: 7870/10000 (78.70%)
#
# Class      - Accuracy
# Plane      - 82.8
# Car        - 90.2
# Bird       - 68.5
# Cat        - 60.5
# Deer       - 75.9
# Dog        - 67.0
# Frog       - 83.8
# Horse      - 83.9
# Ship       - 87.6
# Truck      - 86.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 4.358513742685318
# Peer 3  is  honest reputation: 3.2754294872283936
# Peer 6  is  honest reputation: 2.611389845609665
# Peer 14  is  honest reputation: 8.05412295460701
# Peer 8  is  honest reputation: 5.901008367538452
# Peer 9  is  honest reputation: 6.311281710863113
# Peer 17  is  honest reputation: 6.696025341749191
# Peer 15  is  honest reputation: 0.7702818810939789
# Peer 18  is  honest reputation: 4.980850279331207
# Peer 4  is  honest reputation: 6.13353306055069
# Average of peers' local losses: 0.000782
# Mixing took 2.3992
# -> Update reputation
# [0.99999968 0.99999846 0.99999906 0.95870367 0.99999998 0.99996913
#  0.99841037 0.99998775]
# Aggregation took 1.6315
#
# Average test loss: 1.0748, Test accuracy: 7862/10000 (78.62%)
#
# Class      - Accuracy
# Plane      - 83.0
# Car        - 90.5
# Bird       - 68.2
# Cat        - 60.7
# Deer       - 75.0
# Dog        - 66.6
# Frog       - 84.1
# Horse      - 84.1
# Ship       - 87.6
# Truck      - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 101/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.2754294872283936
# Peer 14  is  honest reputation: 8.128293961286545
# Peer 15  is  honest reputation: 0.8264260590076447
# Peer 18  is  honest reputation: 4.898496031761169
# Peer 19  is  honest reputation: 8.876504957675934
# Peer 8  is  honest reputation: 5.936717510223389
# Peer 12  is  attacker reputation: -1.0974312871694565
# Peer 1  is  honest reputation: 1.7850231528282166
# Peer 9  is  honest reputation: 6.311281710863113
# Peer 13  is  honest reputation: 3.8113282918930054
# Average of peers' local losses: 0.042248
# Mixing took 2.4522
# -> Update reputation
# [0.99999946 1.         0.         0.98762511 0.99999999 0.99992237
#  0.99999129 0.99977535]
# Aggregation took 1.6305
#
# Average test loss: 1.0663, Test accuracy: 7851/10000 (78.51%)
#
# Class      - Accuracy
# Plane      - 82.8
# Car        - 90.1
# Bird       - 67.4
# Cat        - 63.8
# Deer       - 75.8
# Dog        - 63.0
# Frog       - 83.7
# Horse      - 83.8
# Ship       - 87.7
# Truck      - 87.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 102/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 5.61981937289238
# Peer 10  is  honest reputation: 4.436252683401108
# Peer 19  is  honest reputation: 9.00026822090149
# Peer 14  is  honest reputation: 8.270319491624832
# Peer 0  is  attacker reputation: -1.1205310076475143
# Peer 4  is  honest reputation: 6.180204689502716
# Peer 1  is  honest reputation: 1.4137333631515503
# Peer 6  is  honest reputation: 2.4650953114032745
# Peer 18  is  honest reputation: 5.046249330043793
# Peer 8  is  honest reputation: 5.936717510223389
# Average of peers' local losses: 0.044911
# Mixing took 3.0638
# -> Update reputation
# [0.99861011 0.99999206 1.         0.99997366 0.98854601 0.99999916
#  0.99999541 0.         0.99999999 0.99999735]
# Aggregation took 1.9918
#
# Average test loss: 1.0624, Test accuracy: 7851/10000 (78.51%)
#
# Class      - Accuracy
# Plane      - 82.9
# Car        - 90.7
# Bird       - 68.4
# Cat        - 62.9
# Deer       - 76.3
# Dog        - 61.6
# Frog       - 83.9
# Horse      - 84.2
# Ship       - 87.9
# Truck      - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 103/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 9.028804540634155
# Peer 15  is  honest reputation: 0.8264260590076447
# Peer 1  is  honest reputation: 1.4285154938697815
# Peer 18  is  honest reputation: 5.068371593952179
# Peer 6  is  honest reputation: 2.4855965673923492
# Peer 10  is  honest reputation: 4.468970566987991
# Peer 9  is  honest reputation: 6.43579825758934
# Peer 4  is  honest reputation: 6.191027104854584
# Peer 2  is  attacker reputation: -1.141525775194168
# Peer 7  is  honest reputation: 5.616383463144302
# Average of peers' local losses: 0.045132
# Mixing took 3.0598
# -> Update reputation
# [0.99999322 0.99881678 0.         0.88977229 1.         0.99999773
#  0.99999956 0.99997766 0.99999924 0.98986847]
# Aggregation took 2.0128
#
# Average test loss: 1.0607, Test accuracy: 7866/10000 (78.66%)
#
# Class      - Accuracy
# Plane      - 83.1
# Car        - 89.8
# Bird       - 68.6
# Cat        - 62.9
# Deer       - 76.0
# Dog        - 63.1
# Frog       - 83.8
# Horse      - 84.7
# Ship       - 88.1
# Truck      - 86.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 104/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 6.462942510843277
# Peer 4  is  honest reputation: 6.188519358634949
# Peer 8  is  honest reputation: 5.342153191566467
# Peer 15  is  honest reputation: 0.21678480505943298
# Peer 1  is  honest reputation: 1.4360386729240417
# Peer 6  is  honest reputation: 2.5119878351688385
# Peer 14  is  honest reputation: 8.280627280473709
# Peer 19  is  honest reputation: 9.051633536815643
# Peer 16  is  honest reputation: -1.1750018000602722
# Peer 3  is  honest reputation: 3.421215832233429
# Average of peers' local losses: 0.051176
# Mixing took 3.0908
# -> Update reputation
# [0.99999999 0.99986138 0.99999946 0.91963218 0.99999916 0.
#  0.999997   1.         0.99296373 0.99918515]
# Aggregation took 2.0068
#
# Average test loss: 1.0502, Test accuracy: 7876/10000 (78.76%)
#
# Class      - Accuracy
# Plane      - 83.0
# Car        - 89.7
# Bird       - 68.9
# Cat        - 60.8
# Deer       - 76.2
# Dog        - 66.4
# Frog       - 84.1
# Horse      - 83.7
# Ship       - 88.2
# Truck      - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 105/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.22330406308174133
# Peer 13  is  honest reputation: 3.9525248408317566
# Peer 14  is  honest reputation: 8.301906198263168
# Peer 3  is  honest reputation: 3.4250810146331787
# Peer 7  is  honest reputation: 5.641102820634842
# Peer 18  is  honest reputation: 5.093152761459351
# Peer 17  is  honest reputation: 6.723476737737656
# Peer 6  is  honest reputation: 2.5392893254756927
# Peer 4  is  honest reputation: 6.195450007915497
# Peer 10  is  honest reputation: 4.497169584035873
# Average of peers' local losses: 0.000779
# Mixing took 1.8297
# -> Update reputation
# [0.9999958  0.99999999 0.99999943 0.99999974 0.93086096 0.99998659]
# Aggregation took 1.2091
#
# Average test loss: 1.0748, Test accuracy: 7868/10000 (78.68%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 89.7
# Bird       - 68.8
# Cat        - 60.7
# Deer       - 76.0
# Dog        - 66.5
# Frog       - 83.9
# Horse      - 84.0
# Ship       - 87.7
# Truck      - 86.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 106/110 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 5.340864777565002
# Peer 9  is  honest reputation: 5.977696478366852
# Peer 3  is  honest reputation: 3.4250810146331787
# Peer 7  is  honest reputation: 5.641102820634842
# Peer 15  is  honest reputation: 0.3014674484729767
# Peer 6  is  honest reputation: 2.5392893254756927
# Peer 13  is  honest reputation: 3.9525248408317566
# Peer 19  is  honest reputation: 9.065867841243744
# Peer 14  is  honest reputation: 8.383901208639145
# Peer 10  is  honest reputation: 4.593132525682449
# Average of peers' local losses: 0.000756
# Mixing took 2.4482
# -> Update reputation
# [0.99936053 1.         0.99999925 0.99998685 0.99999999 0.99999802
#  0.99999685 0.99986358]
# Aggregation took 1.6155
#
# Average test loss: 1.0863, Test accuracy: 7860/10000 (78.60%)
#
# Class      - Accuracy
# Plane      - 83.3
# Car        - 89.8
# Bird       - 69.1
# Cat        - 59.7
# Deer       - 75.6
# Dog        - 66.9
# Frog       - 83.3
# Horse      - 83.7
# Ship       - 87.7
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 107/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 5.549782067537308
# Peer 19  is  honest reputation: 9.166417479515076
# Peer 9  is  honest reputation: 6.034176409244537
# Peer 13  is  honest reputation: 3.9525248408317566
# Peer 15  is  honest reputation: 0.3014674484729767
# Peer 10  is  honest reputation: 4.602969259023666
# Peer 18  is  honest reputation: 5.173768579959869
# Peer 3  is  honest reputation: 3.4330891370773315
# Peer 17  is  honest reputation: 6.569121152162552
# Peer 8  is  honest reputation: 5.316840410232544
# Average of peers' local losses: 0.000760
# Mixing took 2.4893
# -> Update reputation
# [1.         0.99999934 0.99999968 0.99999567 0.99998699 0.94028267
#  0.99999713 0.99986563]
# Aggregation took 1.6285
#
# Average test loss: 1.1038, Test accuracy: 7857/10000 (78.57%)
#
# Class      - Accuracy
# Plane      - 83.1
# Car        - 90.0
# Bird       - 68.6
# Cat        - 59.8
# Deer       - 75.3
# Dog        - 66.7
# Frog       - 83.5
# Horse      - 84.0
# Ship       - 87.8
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 108/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 5.549782067537308
# Peer 1  is  honest reputation: 1.4598165154457092
# Peer 6  is  honest reputation: 2.660513073205948
# Peer 8  is  honest reputation: 5.364295482635498
# Peer 4  is  honest reputation: 6.169395565986633
# Peer 17  is  honest reputation: 6.456155627965927
# Peer 10  is  honest reputation: 4.608111768960953
# Peer 9  is  honest reputation: 6.095118045806885
# Peer 11  is  honest reputation: -1.291182041168213
# Peer 18  is  honest reputation: 5.158341109752655
# Average of peers' local losses: 0.042382
# Mixing took 1.8847
# -> Update reputation
# [0.99999969 0.99999946 0.99306799 0.99999934 0.99999566 0.99999731]
# Aggregation took 1.2151
#
# Average test loss: 1.1137, Test accuracy: 7853/10000 (78.53%)
#
# Class      - Accuracy
# Plane      - 83.3
# Car        - 89.7
# Bird       - 68.2
# Cat        - 59.7
# Deer       - 75.8
# Dog        - 66.4
# Frog       - 84.0
# Horse      - 83.9
# Ship       - 88.0
# Truck      - 86.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 109/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 6.482948392629623
# Peer 18  is  honest reputation: 5.157558560371399
# Peer 11  is  honest reputation: -1.291182041168213
# Peer 19  is  honest reputation: 9.236069679260254
# Peer 15  is  honest reputation: 0.37714990973472595
# Peer 1  is  honest reputation: 1.4673070311546326
# Peer 9  is  honest reputation: 6.097465813159943
# Peer 3  is  honest reputation: 3.4406630992889404
# Peer 14  is  honest reputation: 8.402155071496964
# Peer 13  is  honest reputation: 3.9525248408317566
# Average of peers' local losses: 0.043505
# Mixing took 1.8727
# -> Update reputation
# [0.99999947 0.99999976 1.         0.99999999 0.99988632 0.9999966 ]
# Aggregation took 1.2131
#
# Average test loss: 1.1229, Test accuracy: 7859/10000 (78.59%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 89.7
# Bird       - 68.5
# Cat        - 60.4
# Deer       - 75.5
# Dog        - 66.9
# Frog       - 83.6
# Horse      - 83.9
# Ship       - 88.0
# Truck      - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 110/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.37714990973472595
# Peer 17  is  honest reputation: 6.6120714247226715
# Peer 8  is  honest reputation: 5.364295482635498
# Peer 9  is  honest reputation: 6.209525048732758
# Peer 13  is  honest reputation: 3.9525248408317566
# Peer 1  is  honest reputation: 1.4673070311546326
# Peer 10  is  honest reputation: 4.608111768960953
# Peer 14  is  honest reputation: 8.324601262807846
# Peer 18  is  honest reputation: 5.279207170009613
# Peer 7  is  honest reputation: 5.396040886640549
# Average of peers' local losses: 0.000791
# Mixing took 3.1879
# -> Update reputation
# [0.99999999 0.99998804 0.99999712 0.99999742 0.94075205 0.99340788
#  0.99999978 0.99999681 0.99991756 0.99999933]
# Aggregation took 1.9938
#
# Average test loss: 1.1279, Test accuracy: 7853/10000 (78.53%)
#
# Class      - Accuracy
# Plane      - 83.2
# Car        - 89.6
# Bird       - 68.6
# Cat        - 59.8
# Deer       - 75.7
# Dog        - 66.7
# Frog       - 83.6
# Horse      - 83.9
# Ship       - 87.5
# Truck      - 86.7
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 1.0843, Test accuracy: 7866/10000 (78.66%)
#
# ***********************************************************************************
# Class      - Accuracy
# Plane      - 83.4
# Car        - 89.7
# Bird       - 68.4
# Cat        - 61.1
# Deer       - 75.9
# Dog        - 65.5
# Frog       - 84.0
# Horse      - 84.0
# Ship       - 87.8
# Truck      - 86.8
# Global accuracies:  [10.35, 27.14, 36.72, 44.68, 48.02, 52.68, 56.77, 57.29, 61.59, 63.89, 67.88, 68.22, 70.65, 71.62, 72.46, 73.56, 73.55, 73.77, 74.72, 74.99, 75.12, 75.52, 75.5, 75.67, 76.21, 76.42, 76.41, 76.28, 76.58, 76.96, 76.81, 76.98, 76.84, 76.74, 77.48, 77.3, 77.3, 77.35, 77.6, 77.44, 77.76, 77.84, 77.92, 77.71, 77.67, 77.56, 77.53, 77.86, 77.92, 77.98, 78.02, 77.99, 78.0, 77.78, 78.0, 77.95, 77.97, 77.72, 78.0, 77.79, 77.6, 77.58, 77.4, 77.12, 77.63, 77.63, 78.06, 77.76, 77.89, 77.76, 77.87, 78.29, 78.25, 78.18, 78.28, 78.43, 78.29, 77.96, 77.77, 78.24, 78.22, 78.42, 78.56, 78.58, 78.56, 78.37, 78.49, 78.55, 78.34, 77.82, 77.35, 78.04, 77.86, 78.26, 78.35, 78.49, 78.6, 78.84, 78.7, 78.62, 78.51, 78.51, 78.66, 78.76, 78.68, 78.6, 78.57, 78.53, 78.59, 78.53, 78.66]
# Class 5 accuracies:  [0.0, 1.7, 0.0, 10.3, 0.0, 9.7, 21.3, 0.1, 38.8, 30.4, 46.7, 44.1, 50.8, 56.4, 55.9, 65.4, 58.9, 60.1, 58.6, 61.9, 67.2, 65.0, 67.9, 58.7, 63.8, 63.6, 61.4, 68.0, 63.7, 66.4, 66.5, 66.2, 66.1, 63.7, 67.8, 66.7, 64.8, 67.5, 67.1, 65.9, 66.7, 61.9, 67.1, 69.0, 64.9, 66.7, 65.4, 66.6, 66.5, 67.3, 65.9, 67.3, 63.2, 59.5, 66.5, 66.6, 66.4, 62.9, 61.8, 61.0, 62.5, 63.2, 63.2, 63.7, 65.6, 64.4, 69.1, 65.3, 67.8, 66.4, 69.1, 65.8, 68.2, 67.2, 67.4, 67.5, 66.5, 65.8, 66.0, 66.0, 62.4, 63.6, 63.9, 65.7, 66.6, 65.9, 64.7, 64.8, 66.4, 57.6, 71.0, 68.8, 59.0, 67.2, 67.1, 64.4, 66.0, 67.5, 67.0, 66.6, 63.0, 61.6, 63.1, 66.4, 66.5, 66.9, 66.7, 66.4, 66.9, 66.7, 65.5]
# Test loss: [2.313, 1.9291, 1.6613, 1.4962, 1.3953, 1.3035, 1.2087, 1.1789, 1.1116, 1.0682, 0.9767, 0.9888, 0.9458, 0.9363, 0.9429, 0.9269, 0.9082, 0.9364, 0.9365, 0.9542, 0.9426, 0.973, 0.9445, 0.9284, 0.9275, 0.935, 0.9294, 0.9634, 0.9842, 0.9453, 0.9817, 0.9799, 1.0032, 0.9683, 0.9731, 1.0492, 0.9783, 1.0694, 1.0973, 1.1233, 1.1246, 1.1076, 1.0122, 0.9517, 0.9872, 1.0191, 1.0259, 1.0497, 1.1027, 1.0563, 1.0815, 1.1123, 1.1086, 1.1107, 1.1201, 1.1324, 1.13, 1.0913, 1.099, 1.0488, 1.0092, 0.9047, 0.8781, 0.9097, 0.8974, 1.0197, 0.9929, 0.9401, 1.0396, 1.0199, 0.9861, 1.0451, 1.0139, 0.9945, 1.0275, 1.0466, 1.0456, 1.0327, 0.8634, 0.9205, 0.9834, 0.967, 0.9975, 0.977, 1.0493, 1.0208, 1.0091, 1.0379, 1.0723, 0.9729, 0.9182, 0.871, 0.9207, 0.9178, 1.0443, 0.9878, 0.9432, 1.0056, 1.0437, 1.0748, 1.0663, 1.0624, 1.0607, 1.0502, 1.0748, 1.0863, 1.1038, 1.1137, 1.1229, 1.1279, 1.0843]
# Label-flipping attack succes rate: 17.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 1.879
# --> End of Experiment.

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating VGG16 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/110 [00:00<?, ?it/s]
#  | Global training round : 1/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.119860
# Mixing took 2.8206
# -> Update reputation
# Aggregation took 3.1168
#
# Average test loss: 2.3554, Test accuracy: 1016/10000 (10.16%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 0.0
# Bird       - 0.0
# Cat        - 0.0
# Deer       - 1.7
# Dog        - 0.0
# Frog       - 99.9
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/110 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: 0.0
# Peer 19  is  honest reputation: 0.012695252895355225
# Peer 18  is  honest reputation: 0.04062134027481079
# Peer 7  is  honest reputation: 0.007317066192626953
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: -0.0024390220642089844
# Peer 3  is  honest reputation: 0.026305317878723145
# Peer 16  is  honest reputation: -0.010765790939331055
# Peer 1  is  honest reputation: 0.05337339639663696
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 1.919090
# Mixing took 3.1328
# -> Update reputation
# Aggregation took 3.0338
#
# Average test loss: 1.9921, Test accuracy: 2377/10000 (23.77%)
#
# Class      - Accuracy
# Plane      - 28.7
# Car        - 17.7
# Bird       - 12.1
# Cat        - 3.9
# Deer       - 9.6
# Dog        - 0.2
# Frog       - 88.4
# Horse      - 18.5
# Ship       - 45.9
# Truck      - 12.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.06910836696624756
# Peer 4  is  honest reputation: -0.07865369319915771
# Peer 12  is  attacker reputation: -0.009137094020843506
# Peer 5  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: 0.02202051877975464
# Peer 2  is  attacker reputation: -0.29394882917404175
# Peer 15  is  honest reputation: 0.03711748123168945
# Peer 3  is  honest reputation: 0.08141040802001953
# Peer 17  is  honest reputation: 0.047238826751708984
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 1.702099
# Mixing took 2.9697
# -> Update reputation
# Aggregation took 3.1268
#
# Average test loss: 1.7450, Test accuracy: 3400/10000 (34.00%)
#
# Class      - Accuracy
# Plane      - 52.9
# Car        - 46.0
# Bird       - 12.3
# Cat        - 23.5
# Deer       - 13.8
# Dog        - 0.0
# Frog       - 87.8
# Horse      - 30.9
# Ship       - 34.1
# Truck      - 38.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.21193653345108032
# Peer 6  is  honest reputation: 0.07310980558395386
# Peer 8  is  honest reputation: 0.0
# Peer 15  is  honest reputation: 0.11980420351028442
# Peer 18  is  honest reputation: 0.1741011142730713
# Peer 12  is  attacker reputation: 0.036895573139190674
# Peer 13  is  honest reputation: 0.01826721429824829
# Peer 5  is  attacker reputation: -0.045741140842437744
# Peer 11  is  honest reputation: -0.08426874876022339
# Peer 10  is  honest reputation: 0.0
# Average of peers' local losses: 1.562197
# Mixing took 3.0948
# -> Update reputation
# Aggregation took 3.0678
#
# Average test loss: 1.5016, Test accuracy: 4343/10000 (43.43%)
#
# Class      - Accuracy
# Plane      - 45.6
# Car        - 66.5
# Bird       - 20.3
# Cat        - 39.5
# Deer       - 51.1
# Dog        - 0.5
# Frog       - 65.8
# Horse      - 52.3
# Ship       - 52.4
# Truck      - 40.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.11668843030929565
# Peer 13  is  honest reputation: 0.1665906310081482
# Peer 2  is  attacker reputation: -0.2826889753341675
# Peer 3  is  honest reputation: 0.3245214819908142
# Peer 12  is  attacker reputation: -0.07545995712280273
# Peer 16  is  honest reputation: -0.07901787757873535
# Peer 0  is  attacker reputation: 0.0
# Peer 14  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.1333187222480774
# Peer 19  is  honest reputation: 0.2461693286895752
# Average of peers' local losses: 1.407002
# Mixing took 3.0137
# -> Update reputation
# Aggregation took 3.1138
#
# Average test loss: 1.3802, Test accuracy: 4794/10000 (47.94%)
#
# Class      - Accuracy
# Plane      - 35.3
# Car        - 75.8
# Bird       - 18.4
# Cat        - 44.7
# Deer       - 49.3
# Dog        - 0.2
# Frog       - 78.9
# Horse      - 56.2
# Ship       - 74.2
# Truck      - 46.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.16464722156524658
# Peer 14  is  honest reputation: 0.05180102586746216
# Peer 7  is  honest reputation: 0.03472822904586792
# Peer 18  is  honest reputation: 0.3494558334350586
# Peer 8  is  honest reputation: 0.1740480661392212
# Peer 6  is  honest reputation: 0.17930442094802856
# Peer 5  is  attacker reputation: -0.07595998048782349
# Peer 11  is  honest reputation: 0.027437865734100342
# Peer 2  is  attacker reputation: -0.27416664361953735
# Peer 3  is  honest reputation: 0.44139957427978516
# Average of peers' local losses: 1.300776
# Mixing took 3.0588
# -> Update reputation
# Aggregation took 3.0568
#
# Average test loss: 1.2736, Test accuracy: 5190/10000 (51.90%)
#
# Class      - Accuracy
# Plane      - 44.8
# Car        - 73.3
# Bird       - 31.0
# Cat        - 39.2
# Deer       - 53.5
# Dog        - 3.3
# Frog       - 77.1
# Horse      - 60.1
# Ship       - 75.5
# Truck      - 61.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.0523257851600647
# Peer 2  is  attacker reputation: -0.3721214532852173
# Peer 7  is  honest reputation: 0.08499795198440552
# Peer 5  is  attacker reputation: -0.09271657466888428
# Peer 19  is  honest reputation: 0.3463524580001831
# Peer 11  is  honest reputation: 0.08332467079162598
# Peer 16  is  honest reputation: 0.02269655466079712
# Peer 6  is  honest reputation: 0.12135487794876099
# Peer 8  is  honest reputation: 0.3320236802101135
# Peer 13  is  honest reputation: 0.23745542764663696
# Average of peers' local losses: 1.189856
# Mixing took 3.0177
# -> Update reputation
# Aggregation took 3.0998
#
# Average test loss: 1.2393, Test accuracy: 5537/10000 (55.37%)
#
# Class      - Accuracy
# Plane      - 44.0
# Car        - 75.6
# Bird       - 29.2
# Cat        - 47.2
# Deer       - 63.6
# Dog        - 13.6
# Frog       - 81.3
# Horse      - 57.5
# Ship       - 78.6
# Truck      - 63.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/110 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -0.4287184476852417
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.49553436040878296
# Peer 11  is  honest reputation: 0.06345522403717041
# Peer 0  is  attacker reputation: -0.002840757369995117
# Peer 10  is  honest reputation: -0.014947652816772461
# Peer 4  is  honest reputation: 0.2212039828300476
# Peer 12  is  attacker reputation: -0.24239319562911987
# Peer 18  is  honest reputation: 0.47846806049346924
# Peer 5  is  attacker reputation: -0.1782209277153015
# Average of peers' local losses: 1.063083
# Mixing took 3.1759
# -> Update reputation
# Aggregation took 3.1899
#
# Average test loss: 1.3838, Test accuracy: 5673/10000 (56.73%)
#
# Class      - Accuracy
# Plane      - 54.9
# Car        - 79.5
# Bird       - 39.4
# Cat        - 53.9
# Deer       - 55.9
# Dog        - 0.0
# Frog       - 80.8
# Horse      - 59.0
# Ship       - 78.3
# Truck      - 65.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.6315665245056152
# Peer 8  is  honest reputation: 0.4900214672088623
# Peer 15  is  honest reputation: 0.2992267608642578
# Peer 3  is  honest reputation: 0.49557703733444214
# Peer 0  is  attacker reputation: 0.16102701425552368
# Peer 17  is  honest reputation: 0.2367863655090332
# Peer 11  is  honest reputation: 0.030607640743255615
# Peer 6  is  honest reputation: 0.2366091012954712
# Peer 9  is  honest reputation: 0.10725349187850952
# Peer 10  is  honest reputation: -0.03582882881164551
# Average of peers' local losses: 1.009176
# Mixing took 3.1659
# -> Update reputation
# Aggregation took 3.0898
#
# Average test loss: 1.1136, Test accuracy: 6107/10000 (61.07%)
#
# Class      - Accuracy
# Plane      - 57.2
# Car        - 79.8
# Bird       - 53.7
# Cat        - 35.8
# Deer       - 59.6
# Dog        - 34.7
# Frog       - 82.8
# Horse      - 58.5
# Ship       - 79.2
# Truck      - 69.4
#
# Backdoor ASR 0.0
#  | Global training round : 10/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.2135135531425476
# Peer 11  is  honest reputation: 0.09335201978683472
# Peer 2  is  attacker reputation: -0.4121798276901245
# Peer 12  is  attacker reputation: -0.059969186782836914
# Peer 1  is  honest reputation: 0.21380770206451416
# Peer 13  is  honest reputation: 0.29706376791000366
# Peer 4  is  honest reputation: 0.3188817501068115
# Peer 18  is  honest reputation: 0.7783850431442261
# Peer 16  is  honest reputation: 0.10973155498504639
# Peer 10  is  honest reputation: 0.000277101993560791
# Average of peers' local losses: 0.912691
# Mixing took 3.1849
# -> Update reputation
# Aggregation took 3.1559
#
# Average test loss: 1.0608, Test accuracy: 6350/10000 (63.50%)
#
# Class      - Accuracy
# Plane      - 61.5
# Car        - 81.5
# Bird       - 49.0
# Cat        - 53.9
# Deer       - 62.4
# Dog        - 24.6
# Frog       - 81.1
# Horse      - 67.9
# Ship       - 81.5
# Truck      - 71.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.142225444316864
# Peer 17  is  honest reputation: 0.19827544689178467
# Peer 13  is  honest reputation: 0.43758058547973633
# Peer 4  is  honest reputation: 0.46081429719924927
# Peer 8  is  honest reputation: 0.5515692830085754
# Peer 18  is  honest reputation: 0.907525897026062
# Peer 9  is  honest reputation: 0.26187020540237427
# Peer 19  is  honest reputation: 0.539530873298645
# Peer 15  is  honest reputation: 0.2871914505958557
# Peer 3  is  honest reputation: 0.6543911099433899
# Average of peers' local losses: 0.852735
# Mixing took 3.2339
# -> Update reputation
# [0.6125749  0.24713401 0.32907999 0.06897524 0.64462877 0.33308944
#  0.13765845 0.49167608 0.25268531 0.51044199]
# Aggregation took 2.0389
#
# Average test loss: 0.9968, Test accuracy: 6691/10000 (66.91%)
#
# Class      - Accuracy
# Plane      - 67.9
# Car        - 85.6
# Bird       - 54.7
# Cat        - 38.7
# Deer       - 61.4
# Dog        - 54.9
# Frog       - 78.2
# Horse      - 69.1
# Ship       - 84.3
# Truck      - 74.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.6503523588180542
# Peer 4  is  honest reputation: 0.4538801312446594
# Peer 7  is  honest reputation: 0.19265198707580566
# Peer 18  is  honest reputation: 0.878137469291687
# Peer 9  is  honest reputation: 0.18116891384124756
# Peer 1  is  honest reputation: 0.20400792360305786
# Peer 15  is  honest reputation: 0.37036317586898804
# Peer 16  is  honest reputation: 0.13104945421218872
# Peer 13  is  honest reputation: 0.4583832025527954
# Peer 3  is  honest reputation: 0.8251164555549622
# Average of peers' local losses: 0.785968
# Mixing took 3.0588
# -> Update reputation
# [0.26872797 0.43283045 0.30219905 0.56873365 0.68100281 0.36842448
#  0.12891983 0.68369258 0.00329323 0.08994669]
# Aggregation took 2.0589
#
# Average test loss: 1.0017, Test accuracy: 6825/10000 (68.25%)
#
# Class      - Accuracy
# Plane      - 65.3
# Car        - 85.8
# Bird       - 55.8
# Cat        - 39.0
# Deer       - 66.7
# Dog        - 58.7
# Frog       - 79.7
# Horse      - 71.0
# Ship       - 83.9
# Truck      - 76.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.19470852613449097
# Peer 15  is  honest reputation: 0.3770051598548889
# Peer 13  is  honest reputation: 0.5284416675567627
# Peer 10  is  honest reputation: 0.2506219744682312
# Peer 8  is  honest reputation: 0.6754112839698792
# Peer 7  is  honest reputation: 0.1552577018737793
# Peer 16  is  honest reputation: 0.06836050748825073
# Peer 14  is  honest reputation: 0.17096388339996338
# Peer 1  is  honest reputation: 0.34055954217910767
# Peer 6  is  honest reputation: 0.3569808006286621
# Average of peers' local losses: 0.748691
# Mixing took 3.1198
# -> Update reputation
# [0.52389438 0.21412338 0.09092766 0.10876955 0.2905076  0.2213747
#  0.24248059 0.03915323 0.24014324 0.02480262]
# Aggregation took 1.9898
#
# Average test loss: 0.9897, Test accuracy: 6927/10000 (69.27%)
#
# Class      - Accuracy
# Plane      - 62.8
# Car        - 87.0
# Bird       - 56.1
# Cat        - 44.9
# Deer       - 70.4
# Dog        - 52.0
# Frog       - 86.7
# Horse      - 67.9
# Ship       - 85.2
# Truck      - 79.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/110 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.37701863050460815
# Peer 16  is  honest reputation: 0.15441834926605225
# Peer 4  is  honest reputation: 0.4516661763191223
# Peer 17  is  honest reputation: 0.36444205045700073
# Peer 15  is  honest reputation: 0.3547118306159973
# Peer 9  is  honest reputation: 0.23881220817565918
# Peer 14  is  honest reputation: 0.16878390312194824
# Peer 10  is  honest reputation: 0.37453675270080566
# Peer 1  is  honest reputation: 0.34709954261779785
# Peer 13  is  honest reputation: 0.42873120307922363
# Average of peers' local losses: 0.669194
# Mixing took 2.9457
# -> Update reputation
# [0.29297007 0.25374491 0.47363614 0.36419225 0.29433327 0.36721779
#  0.26113587 0.01081979 0.35445517 0.09488467]
# Aggregation took 2.0118
#
# Average test loss: 0.9541, Test accuracy: 7127/10000 (71.27%)
#
# Class      - Accuracy
# Plane      - 69.1
# Car        - 86.2
# Bird       - 59.1
# Cat        - 43.5
# Deer       - 73.7
# Dog        - 57.7
# Frog       - 82.3
# Horse      - 73.4
# Ship       - 85.5
# Truck      - 82.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.34705954790115356
# Peer 7  is  honest reputation: 0.22079014778137207
# Peer 13  is  honest reputation: 0.39095211029052734
# Peer 3  is  honest reputation: 0.9010822772979736
# Peer 15  is  honest reputation: 0.4581781029701233
# Peer 4  is  honest reputation: 0.6023958921432495
# Peer 6  is  honest reputation: 0.47285157442092896
# Peer 16  is  honest reputation: 0.18281912803649902
# Peer 14  is  honest reputation: 0.0984683632850647
# Peer 17  is  honest reputation: 0.354975163936615
# Average of peers' local losses: 0.609303
# Mixing took 3.1198
# -> Update reputation
# [0.         0.10352224 0.35246939 0.3428873  0.74228634 0.4204286
#  0.29248273 0.1423537  0.58908392 0.50878463]
# Aggregation took 1.9918
#
# Average test loss: 0.9468, Test accuracy: 7205/10000 (72.05%)
#
# Class      - Accuracy
# Plane      - 72.1
# Car        - 85.4
# Bird       - 55.0
# Cat        - 48.5
# Deer       - 73.3
# Dog        - 54.5
# Frog       - 83.4
# Horse      - 75.7
# Ship       - 87.7
# Truck      - 84.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.40750592947006226
# Peer 10  is  honest reputation: 0.4693589210510254
# Peer 7  is  honest reputation: 0.15403950214385986
# Peer 9  is  honest reputation: 0.4184057116508484
# Peer 3  is  honest reputation: 1.005697250366211
# Peer 15  is  honest reputation: 0.4983575940132141
# Peer 6  is  honest reputation: 0.6112335920333862
# Peer 1  is  honest reputation: 0.3894602656364441
# Peer 18  is  honest reputation: 0.8960490226745605
# Peer 4  is  honest reputation: 0.7264070510864258
# Average of peers' local losses: 0.546327
# Mixing took 2.9717
# -> Update reputation
# [0.02164089 0.59622669 0.35167267 0.73434416 0.5880633  0.47730227
#  0.42267215 0.42903617 0.38554861 0.71902819]
# Aggregation took 1.9968
#
# Average test loss: 0.9529, Test accuracy: 7234/10000 (72.34%)
#
# Class      - Accuracy
# Plane      - 71.7
# Car        - 86.2
# Bird       - 58.9
# Cat        - 47.0
# Deer       - 73.2
# Dog        - 60.5
# Frog       - 83.5
# Horse      - 72.2
# Ship       - 89.0
# Truck      - 81.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.7107163071632385
# Peer 6  is  honest reputation: 0.7248454689979553
# Peer 4  is  honest reputation: 0.7374171614646912
# Peer 3  is  honest reputation: 0.9882365465164185
# Peer 9  is  honest reputation: 0.4174962639808655
# Peer 10  is  honest reputation: 0.5696298480033875
# Peer 15  is  honest reputation: 0.5010859966278076
# Peer 17  is  honest reputation: 0.3514241576194763
# Peer 7  is  honest reputation: 0.07178932428359985
# Peer 1  is  honest reputation: 0.5088598728179932
# Average of peers' local losses: 0.491812
# Mixing took 3.0308
# -> Update reputation
# [0.42974217 0.46593385 0.         0.5482556  0.3083209  0.55101061
#  0.67318894 0.65653543 0.53016799 0.79993197]
# Aggregation took 1.9998
#
# Average test loss: 0.9487, Test accuracy: 7330/10000 (73.30%)
# Class      - Accuracy
# Plane      - 71.9
# Car        - 85.0
# Bird       - 59.5
# Cat        - 50.5
# Deer       - 75.9
# Dog        - 58.7
# Frog       - 84.4
# Horse      - 76.2
# Ship       - 86.2
# Truck      - 84.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.3422958254814148
# Peer 16  is  honest reputation: 0.19347220659255981
# Peer 1  is  honest reputation: 0.6139857769012451
# Peer 11  is  honest reputation: 0.05518752336502075
# Peer 8  is  honest reputation: 0.7113029956817627
# Peer 3  is  honest reputation: 1.1220303177833557
# Peer 14  is  honest reputation: 0.03501766920089722
# Peer 18  is  honest reputation: 0.9557750821113586
# Peer 10  is  honest reputation: 0.6434383392333984
# Peer 19  is  honest reputation: 0.6394907832145691
# Average of peers' local losses: 0.504330
# Mixing took 3.0067
# -> Update reputation
# [0.58601096 0.77167086 0.66206438 0.75183073 0.07023111 0.45296618
#  0.34131543 0.01895609 0.53265754 0.25061449]
# Aggregation took 2.0048
#
# Average test loss: 0.8955, Test accuracy: 7403/10000 (74.03%)
#
# Class      - Accuracy
# Plane      - 74.0
# Car        - 88.5
# Bird       - 61.1
# Cat        - 57.8
# Deer       - 75.8
# Dog        - 59.1
# Frog       - 79.8
# Horse      - 74.2
# Ship       - 87.2
# Truck      - 82.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/110 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.3023183345794678
# Peer 11  is  honest reputation: 0.0652083158493042
# Peer 13  is  honest reputation: 0.45670586824417114
# Peer 18  is  honest reputation: 1.023402750492096
# Peer 17  is  honest reputation: 0.40183061361312866
# Peer 3  is  honest reputation: 1.0706950426101685
# Peer 1  is  honest reputation: 0.5346758365631104
# Peer 10  is  honest reputation: 0.6400980353355408
# Peer 19  is  honest reputation: 0.7178188562393188
# Peer 14  is  honest reputation: 0.11659687757492065
# Average of peers' local losses: 0.439651
# Mixing took 3.0698
# -> Update reputation
# [0.38618216 0.48994715 0.49447933 0.79837152 0.01260484 0.1058495
#  0.48607646 0.47492842 0.77809602 0.67476066]
# Aggregation took 1.9948
#
# Average test loss: 0.9400, Test accuracy: 7412/10000 (74.12%)
#
# Class      - Accuracy
# Plane      - 73.3
# Car        - 87.2
# Bird       - 61.3
# Cat        - 48.9
# Deer       - 74.8
# Dog        - 63.7
# Frog       - 83.0
# Horse      - 74.7
# Ship       - 88.6
# Truck      - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.5691635012626648
# Peer 8  is  honest reputation: 0.8427301049232483
# Peer 9  is  honest reputation: 0.48318737745285034
# Peer 16  is  honest reputation: 0.43449658155441284
# Peer 11  is  honest reputation: 0.03979688882827759
# Peer 10  is  honest reputation: 0.5631821751594543
# Peer 18  is  honest reputation: 1.1212964057922363
# Peer 17  is  honest reputation: 0.5581014752388
# Peer 4  is  honest reputation: 0.8103067874908447
# Peer 19  is  honest reputation: 0.8466234803199768
# Average of peers' local losses: 0.415585
# Mixing took 2.9987
# -> Update reputation
# [0.         0.6411886  0.81363923 0.70452444 0.51777339 0.70721559
#  0.53796404 0.57870853 0.47198365 0.56353029]
# Aggregation took 2.0008
#
# Average test loss: 0.9196, Test accuracy: 7475/10000 (74.75%)
#
# Class      - Accuracy
# Plane      - 74.6
# Car        - 87.8
# Bird       - 59.8
# Cat        - 54.1
# Deer       - 75.9
# Dog        - 61.9
# Frog       - 86.2
# Horse      - 75.1
# Ship       - 87.8
# Truck      - 84.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: -0.010625123977661133
# Peer 18  is  honest reputation: 1.1260185241699219
# Peer 9  is  honest reputation: 0.5896013975143433
# Peer 4  is  honest reputation: 0.8699066042900085
# Peer 1  is  honest reputation: 0.5436064600944519
# Peer 8  is  honest reputation: 0.7485049366950989
# Peer 19  is  honest reputation: 0.8645430207252502
# Peer 13  is  honest reputation: 0.6263066530227661
# Peer 17  is  honest reputation: 0.6488341093063354
# Peer 3  is  honest reputation: 1.0677182078361511
# Average of peers' local losses: 0.349011
# Mixing took 2.4012
# -> Update reputation
# [0.60286263 0.84540912 0.51947565 0.66206749 0.83302127 0.58129398
#  0.66940005 0.52048189]
# Aggregation took 1.6355
#
# Average test loss: 0.9318, Test accuracy: 7530/10000 (75.30%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 88.0
# Bird       - 63.9
# Cat        - 51.5
# Deer       - 73.8
# Dog        - 66.3
# Frog       - 82.6
# Horse      - 79.6
# Ship       - 86.9
# Truck      - 81.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.5616081357002258
# Peer 19  is  honest reputation: 0.8645430207252502
# Peer 16  is  honest reputation: 0.5009348392486572
# Peer 14  is  honest reputation: 0.13343888521194458
# Peer 1  is  honest reputation: 0.563936710357666
# Peer 4  is  honest reputation: 0.7848010659217834
# Peer 17  is  honest reputation: 0.6859474778175354
# Peer 18  is  honest reputation: 1.1862425804138184
# Peer 7  is  honest reputation: -0.010625123977661133
# Peer 8  is  honest reputation: 0.7979706525802612
# Average of peers' local losses: 0.362230
# Mixing took 2.4532
# -> Update reputation
# [0.54704715 0.84448612 0.69512859 0.55128972 0.37700989 0.01885611
#  0.69383015 0.65108315]
# Aggregation took 1.8227
#
# Average test loss: 0.9466, Test accuracy: 7480/10000 (74.80%)
#
# Class      - Accuracy
# Plane      - 76.3
# Car        - 87.8
# Bird       - 55.7
# Cat        - 50.7
# Deer       - 80.4
# Dog        - 64.6
# Frog       - 85.3
# Horse      - 75.4
# Ship       - 87.9
# Truck      - 83.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: -0.010625123977661133
# Peer 10  is  honest reputation: 0.6024730205535889
# Peer 13  is  honest reputation: 0.565315842628479
# Peer 9  is  honest reputation: 0.6527302265167236
# Peer 6  is  honest reputation: 0.8401591777801514
# Peer 4  is  honest reputation: 0.843619167804718
# Peer 14  is  honest reputation: 0.007173717021942139
# Peer 16  is  honest reputation: 0.38488489389419556
# Peer 18  is  honest reputation: 1.2249258756637573
# Peer 15  is  honest reputation: 0.5284709930419922
# Average of peers' local losses: 0.348758
# Mixing took 3.1028
# -> Update reputation
# [0.60124828 0.71967229 0.10550371 0.54924008 0.52607624 0.00085051
#  0.41632544 0.71218879 0.37709979 0.81107546]
# Aggregation took 2.0138
#
# Average test loss: 0.9104, Test accuracy: 7623/10000 (76.23%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 86.0
# Bird       - 64.7
# Cat        - 56.5
# Deer       - 77.2
# Dog        - 60.0
# Frog       - 85.0
# Horse      - 80.1
# Ship       - 86.5
# Truck      - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/110 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.8792999386787415
# Peer 3  is  honest reputation: 1.2281524538993835
# Peer 15  is  honest reputation: 0.5723927617073059
# Peer 17  is  honest reputation: 0.7654919624328613
# Peer 9  is  honest reputation: 0.6827883124351501
# Peer 13  is  honest reputation: 0.38436272740364075
# Peer 18  is  honest reputation: 1.1178526282310486
# Peer 19  is  honest reputation: 0.8645430207252502
# Peer 10  is  honest reputation: 0.6049808859825134
# Peer 16  is  honest reputation: 0.4309271574020386
# Average of peers' local losses: 0.269880
# Mixing took 2.9997
# -> Update reputation
# [0.53307823 0.67839989 0.66511784 0.40356756 0.46892808 0.72540479
#  0.87310057 0.4769849  0.69423473 0.80996267]
# Aggregation took 2.0038
#
# Average test loss: 0.9303, Test accuracy: 7606/10000 (76.06%)
#
# Class      - Accuracy
# Plane      - 77.1
# Car        - 86.8
# Bird       - 65.2
# Cat        - 55.5
# Deer       - 78.3
# Dog        - 62.2
# Frog       - 85.0
# Horse      - 77.1
# Ship       - 86.8
# Truck      - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.41559168696403503
# Peer 18  is  honest reputation: 1.114608883857727
# Peer 10  is  honest reputation: 0.5067622661590576
# Peer 19  is  honest reputation: 0.9066478610038757
# Peer 15  is  honest reputation: 0.5821239948272705
# Peer 9  is  honest reputation: 0.7896246314048767
# Peer 4  is  honest reputation: 0.8138320446014404
# Peer 1  is  honest reputation: 0.6085476279258728
# Peer 16  is  honest reputation: 0.49638378620147705
# Peer 6  is  honest reputation: 0.8946532607078552
# Average of peers' local losses: 0.261002
# Mixing took 2.4082
# -> Update reputation
# [0.71969967 0.67298836 0.5938185  0.64116933 0.7844699  0.56928313
#  0.68054199 0.49545792]
# Aggregation took 1.6275
#
# Average test loss: 0.9137, Test accuracy: 7601/10000 (76.01%)
#
# Class      - Accuracy
# Plane      - 74.6
# Car        - 88.8
# Bird       - 65.6
# Cat        - 51.9
# Deer       - 76.2
# Dog        - 65.2
# Frog       - 85.7
# Horse      - 76.9
# Ship       - 88.8
# Truck      - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: -0.011461079120635986
# Peer 18  is  honest reputation: 1.0445764660835266
# Peer 4  is  honest reputation: 0.8178113102912903
# Peer 16  is  honest reputation: 0.49638378620147705
# Peer 13  is  honest reputation: 0.5309566557407379
# Peer 15  is  honest reputation: 0.6341500282287598
# Peer 17  is  honest reputation: 0.8437727689743042
# Peer 3  is  honest reputation: 1.3336661458015442
# Peer 19  is  honest reputation: 0.8947100639343262
# Peer 9  is  honest reputation: 0.8038738965988159
# Average of peers' local losses: 0.226036
# Mixing took 3.0097
# -> Update reputation
# [0.67907331 0.7425301  0.73058483 0.5503521  0.70481881 0.52183279
#  0.50254055 0.69390797 0.00303032 0.87083673]
# Aggregation took 1.9898
#
# Average test loss: 0.9962, Test accuracy: 7649/10000 (76.49%)
#
# Class      - Accuracy
# Plane      - 82.8
# Car        - 88.6
# Bird       - 62.2
# Cat        - 53.9
# Deer       - 76.5
# Dog        - 65.7
# Frog       - 86.7
# Horse      - 76.2
# Ship       - 86.6
# Truck      - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: -0.0027418136596679688
# Peer 9  is  honest reputation: 0.8216201663017273
# Peer 19  is  honest reputation: 0.924208402633667
# Peer 4  is  honest reputation: 0.8496817350387573
# Peer 13  is  honest reputation: 0.5730829536914825
# Peer 18  is  honest reputation: 0.9503231644630432
# Peer 10  is  honest reputation: 0.6712323427200317
# Peer 1  is  honest reputation: 0.7478452324867249
# Peer 16  is  honest reputation: 0.5469271540641785
# Peer 8  is  honest reputation: 0.8461272716522217
# Average of peers' local losses: 0.228024
# Mixing took 3.0678
# -> Update reputation
# [0.69991728 0.5162832  0.69819359 0.5996304  0.47208002 0.59848112
#  0.01258763 0.70059867 0.61733677 0.72307808]
# Aggregation took 2.0058
#
# Average test loss: 0.9325, Test accuracy: 7673/10000 (76.73%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 87.2
# Bird       - 65.8
# Cat        - 55.3
# Deer       - 78.2
# Dog        - 61.7
# Frog       - 84.0
# Horse      - 79.4
# Ship       - 88.8
# Truck      - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/110 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.9369677305221558
# Peer 9  is  honest reputation: 0.8866690397262573
# Peer 13  is  honest reputation: 0.5356452167034149
# Peer 4  is  honest reputation: 0.8900400996208191
# Peer 10  is  honest reputation: 0.715471625328064
# Peer 14  is  honest reputation: 0.09358620643615723
# Peer 1  is  honest reputation: 0.7435921430587769
# Peer 16  is  honest reputation: 0.5941606163978577
# Peer 7  is  honest reputation: 0.03549003601074219
# Peer 17  is  honest reputation: 0.8710402250289917
# Average of peers' local losses: 0.219667
# Mixing took 3.0157
# -> Update reputation
# [0.61113413 0.59353479 0.51196524 0.01586583 0.0263834  0.61118368
#  0.52343395 0.70055791 0.68928457 0.72145626]
# Aggregation took 2.0008
#
# Average test loss: 0.9827, Test accuracy: 7624/10000 (76.24%)
#
# Class      - Accuracy
# Plane      - 80.2
# Car        - 87.3
# Bird       - 62.7
# Cat        - 53.1
# Deer       - 78.7
# Dog        - 61.0
# Frog       - 86.8
# Horse      - 80.5
# Ship       - 86.4
# Truck      - 85.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/110 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.059127867221832275
# Peer 1  is  honest reputation: 0.7434679269790649
# Peer 8  is  honest reputation: 0.8913770914077759
# Peer 16  is  honest reputation: 0.6137962937355042
# Peer 4  is  honest reputation: 0.7435470223426819
# Peer 10  is  honest reputation: 0.7158441543579102
# Peer 15  is  honest reputation: 0.6131141185760498
# Peer 18  is  honest reputation: 0.7136790454387665
# Peer 9  is  honest reputation: 0.90113365650177
# Peer 19  is  honest reputation: 0.9434137344360352
# Average of peers' local losses: 0.199345
# Mixing took 2.4032
# -> Update reputation
# [0.64712085 0.20317076 0.62421158 0.66205034 0.52663916 0.59425115
#  0.73377538 0.71671633]
# Aggregation took 1.6275
#
# Average test loss: 0.8975, Test accuracy: 7666/10000 (76.66%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 87.4
# Bird       - 65.3
# Cat        - 55.9
# Deer       - 78.6
# Dog        - 65.9
# Frog       - 84.5
# Horse      - 76.2
# Ship       - 87.6
# Truck      - 85.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.8030675649642944
# Peer 17  is  honest reputation: 0.8793298006057739
# Peer 16  is  honest reputation: 0.6182213425636292
# Peer 19  is  honest reputation: 0.9335982799530029
# Peer 15  is  honest reputation: 0.7646141052246094
# Peer 9  is  honest reputation: 0.829193502664566
# Peer 8  is  honest reputation: 0.9695964455604553
# Peer 18  is  honest reputation: 0.7169508635997772
# Peer 4  is  honest reputation: 0.7435470223426819
# Peer 3  is  honest reputation: 1.3307597637176514
# Average of peers' local losses: 0.136981
# Mixing took 3.0197
# -> Update reputation
# [0.88948714 0.71475174 0.73558776 0.61036073 0.67151752 0.75277112
#  0.60614564 0.69175444 0.61682657 0.62855638]
# Aggregation took 1.9948
#
# Average test loss: 0.9802, Test accuracy: 7711/10000 (77.11%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 88.0
# Bird       - 64.6
# Cat        - 58.7
# Deer       - 76.8
# Dog        - 63.8
# Frog       - 86.0
# Horse      - 78.4
# Ship       - 87.1
# Truck      - 85.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/110 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.8462401926517487
# Peer 15  is  honest reputation: 0.7526047825813293
# Peer 6  is  honest reputation: 0.8946532607078552
# Peer 8  is  honest reputation: 0.973534345626831
# Peer 16  is  honest reputation: 0.7355440258979797
# Peer 3  is  honest reputation: 1.4522027373313904
# Peer 4  is  honest reputation: 0.7422344088554382
# Peer 18  is  honest reputation: 0.7717644274234772
# Peer 13  is  honest reputation: 0.5981278121471405
# Peer 10  is  honest reputation: 0.8840506672859192
# Average of peers' local losses: 0.139362
# Mixing took 2.4082
# -> Update reputation
# [0.60787197 0.76510828 0.88776221 0.63846946 0.65453106 0.72803416
#  0.57802395 0.60124124]
# Aggregation took 1.6315
#
# Average test loss: 0.9702, Test accuracy: 7641/10000 (76.41%)
#
# Class      - Accuracy
# Plane      - 76.5
# Car        - 89.2
# Bird       - 66.8
# Cat        - 54.8
# Deer       - 78.4
# Dog        - 62.2
# Frog       - 87.1
# Horse      - 78.4
# Ship       - 87.6
# Truck      - 83.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.7278272211551666
# Peer 16  is  honest reputation: 0.7382775545120239
# Peer 6  is  honest reputation: 0.9572699666023254
# Peer 4  is  honest reputation: 0.7883239984512329
# Peer 17  is  honest reputation: 1.0120577216148376
# Peer 18  is  honest reputation: 0.815923422574997
# Peer 1  is  honest reputation: 0.7434679269790649
# Peer 8  is  honest reputation: 1.0411596894264221
# Peer 15  is  honest reputation: 0.7526047825813293
# Peer 3  is  honest reputation: 1.4440021514892578
# Average of peers' local losses: 0.139682
# Mixing took 3.1308
# -> Update reputation
# [0.90136769 0.64638114 0.7799772  0.60098893 0.61650535 0.61396681
#  0.77525508 0.59094649 0.63372194 0.74244969]
# Aggregation took 2.0939
#
# Average test loss: 0.9656, Test accuracy: 7727/10000 (77.27%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 87.9
# Bird       - 66.4
# Cat        - 56.3
# Deer       - 79.3
# Dog        - 61.5
# Frog       - 86.5
# Horse      - 80.8
# Ship       - 88.1
# Truck      - 85.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.048605501651763916
# Peer 13  is  honest reputation: 0.6922284066677094
# Peer 19  is  honest reputation: 0.929570198059082
# Peer 6  is  honest reputation: 0.9886544346809387
# Peer 10  is  honest reputation: 0.780349999666214
# Peer 1  is  honest reputation: 0.8017959594726562
# Peer 8  is  honest reputation: 1.078050673007965
# Peer 15  is  honest reputation: 0.7480018138885498
# Peer 9  is  honest reputation: 0.8462401926517487
# Peer 3  is  honest reputation: 1.5122032761573792
# Average of peers' local losses: 0.171237
# Mixing took 2.5223
# -> Update reputation
# [0.65835331 0.58755384 0.67919808 0.02853598 0.75709697 0.72878682
#  0.84893686 0.69375752]
# Aggregation took 1.6305
#
# Average test loss: 0.9667, Test accuracy: 7669/10000 (76.69%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 87.8
# Bird       - 62.0
# Cat        - 51.5
# Deer       - 81.7
# Dog        - 65.4
# Frog       - 86.2
# Horse      - 78.2
# Ship       - 88.5
# Truck      - 85.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.7480018138885498
# Peer 1  is  honest reputation: 0.8606696724891663
# Peer 10  is  honest reputation: 0.780349999666214
# Peer 4  is  honest reputation: 0.7118575572967529
# Peer 8  is  honest reputation: 0.9259318113327026
# Peer 9  is  honest reputation: 0.8983919322490692
# Peer 19  is  honest reputation: 0.9969030618667603
# Peer 18  is  honest reputation: 0.7274321615695953
# Peer 16  is  honest reputation: 0.7520864605903625
# Peer 17  is  honest reputation: 1.0661050081253052
# Average of peers' local losses: 0.125392
# Mixing took 2.6114
# -> Update reputation
# [0.68912396 0.76808314 0.59922545 0.59898995 0.5678792  0.54358585
#  0.64415962 0.61036601]
# Aggregation took 2.1099
#
# Average test loss: 0.9381, Test accuracy: 7713/10000 (77.13%)
#
# Class      - Accuracy
# Plane      - 81.1
# Car        - 88.4
# Bird       - 64.3
# Cat        - 56.1
# Deer       - 77.5
# Dog        - 66.4
# Frog       - 83.7
# Horse      - 81.3
# Ship       - 88.0
# Truck      - 84.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.09931176900863647
# Peer 1  is  honest reputation: 0.9170535802841187
# Peer 3  is  honest reputation: 1.3231021463871002
# Peer 15  is  honest reputation: 0.7623385190963745
# Peer 8  is  honest reputation: 0.7151550352573395
# Peer 10  is  honest reputation: 0.8360192477703094
# Peer 19  is  honest reputation: 0.9969030618667603
# Peer 4  is  honest reputation: 0.6799994707107544
# Peer 13  is  honest reputation: 0.7446900308132172
# Peer 6  is  honest reputation: 1.0601460337638855
# Average of peers' local losses: 0.123277
# Mixing took 2.5003
# -> Update reputation
# [0.54081727 0.83599412 0.6825218  0.76337308 0.75222462 0.65093813
#  0.74777534 0.76805493]
# Aggregation took 1.6285
#
# Average test loss: 1.0008, Test accuracy: 7735/10000 (77.35%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 89.3
# Bird       - 67.5
# Cat        - 56.6
# Deer       - 73.9
# Dog        - 64.1
# Frog       - 86.2
# Horse      - 80.1
# Ship       - 88.8
# Truck      - 85.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/110 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 1.0488274693489075
# Peer 9  is  honest reputation: 0.8983919322490692
# Peer 19  is  honest reputation: 1.0863354206085205
# Peer 14  is  honest reputation: 0.23877596855163574
# Peer 15  is  honest reputation: 0.7623385190963745
# Peer 7  is  honest reputation: 0.09931176900863647
# Peer 10  is  honest reputation: 1.0386574566364288
# Peer 6  is  honest reputation: 1.0750175714492798
# Peer 4  is  honest reputation: 0.904587984085083
# Peer 16  is  honest reputation: 0.7627058625221252
# Average of peers' local losses: 0.146280
# Mixing took 2.4642
# -> Update reputation
# [0.55962061 0.74611145 0.82005442 0.76832832 0.68633761 0.82413448
#  0.84262172 0.65725542]
# Aggregation took 1.6335
#
# Average test loss: 1.0274, Test accuracy: 7773/10000 (77.73%)
#
# Class      - Accuracy
# Plane      - 82.2
# Car        - 87.8
# Bird       - 63.0
# Cat        - 56.6
# Deer       - 78.1
# Dog        - 67.8
# Frog       - 86.3
# Horse      - 81.5
# Ship       - 87.3
# Truck      - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.6760780513286591
# Peer 14  is  honest reputation: 0.23877596855163574
# Peer 19  is  honest reputation: 1.300914227962494
# Peer 9  is  honest reputation: 0.9117666184902191
# Peer 15  is  honest reputation: 0.7030486762523651
# Peer 10  is  honest reputation: 1.2277516424655914
# Peer 1  is  honest reputation: 1.240338683128357
# Peer 8  is  honest reputation: 0.8476929366588593
# Peer 6  is  honest reputation: 1.0348936319351196
# Peer 4  is  honest reputation: 1.0870023965835571
# Average of peers' local losses: 0.098638
# Mixing took 2.5203
# -> Update reputation
# [0.74533756 0.16168375 0.81051578 0.81853651 0.63058839 0.76895808
#  0.82931001 0.68695146]
# Aggregation took 1.6235
#
# Average test loss: 1.0046, Test accuracy: 7793/10000 (77.93%)
#
# Class      - Accuracy
# Plane      - 82.5
# Car        - 89.5
# Bird       - 64.7
# Cat        - 58.5
# Deer       - 77.3
# Dog        - 67.3
# Frog       - 86.5
# Horse      - 80.2
# Ship       - 85.3
# Truck      - 87.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.2231344878673553
# Peer 6  is  honest reputation: 1.1992986798286438
# Peer 16  is  honest reputation: 0.8587343692779541
# Peer 17  is  honest reputation: 1.0864042043685913
# Peer 1  is  honest reputation: 1.2566906213760376
# Peer 13  is  honest reputation: 0.8131603896617889
# Peer 14  is  honest reputation: 0.23388320207595825
# Peer 9  is  honest reputation: 1.0331502258777618
# Peer 8  is  honest reputation: 0.9129280745983124
# Peer 7  is  honest reputation: 0.09931176900863647
# Average of peers' local losses: 0.094954
# Mixing took 3.0898
# -> Update reputation
# [0.78125038 0.13677206 0.01521985 0.73624645 0.88557844 0.75684943
#  0.89430557 0.8983912  0.79646083 0.85158804]
# Aggregation took 1.9948
#
# Average test loss: 1.0570, Test accuracy: 7820/10000 (78.20%)
#
# Class      - Accuracy
# Plane      - 83.3
# Car        - 88.3
# Bird       - 67.3
# Cat        - 56.6
# Deer       - 77.6
# Dog        - 67.8
# Frog       - 85.9
# Horse      - 80.6
# Ship       - 87.7
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.2784875929355621
# Peer 8  is  honest reputation: 1.0793714821338654
# Peer 19  is  honest reputation: 1.300914227962494
# Peer 7  is  honest reputation: 0.0460209846496582
# Peer 13  is  honest reputation: 0.9730328023433685
# Peer 15  is  honest reputation: 0.7030486762523651
# Peer 14  is  honest reputation: 0.16843456029891968
# Peer 16  is  honest reputation: 1.1196576356887817
# Peer 6  is  honest reputation: 1.4738276600837708
# Peer 17  is  honest reputation: 1.0195982158184052
# Average of peers' local losses: 0.129012
# Mixing took 2.4642
# -> Update reputation
# [0.8081838  0.76083976 0.85641414 0.86728795 0.93220255 0.87535083
#  0.83949597 0.54320123]
# Aggregation took 1.6435
#
# Average test loss: 1.0054, Test accuracy: 7765/10000 (77.65%)
#
# Class      - Accuracy
# Plane      - 81.3
# Car        - 87.0
# Bird       - 65.1
# Cat        - 57.1
# Deer       - 77.7
# Dog        - 68.4
# Frog       - 85.9
# Horse      - 79.7
# Ship       - 86.7
# Truck      - 87.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/110 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 1.4318501353263855
# Peer 18  is  honest reputation: 0.780272513628006
# Peer 17  is  honest reputation: 1.0290061235427856
# Peer 19  is  honest reputation: 1.3863238990306854
# Peer 6  is  honest reputation: 1.7057456076145172
# Peer 14  is  honest reputation: 0.16843456029891968
# Peer 8  is  honest reputation: 1.3105343580245972
# Peer 15  is  honest reputation: 0.6394855976104736
# Peer 9  is  honest reputation: 1.2927034795284271
# Peer 13  is  honest reputation: 1.1525702476501465
# Average of peers' local losses: 0.055987
# Mixing took 2.4793
# -> Update reputation
# [0.89368624 0.90535971 0.92692401 0.85379525 0.         0.39096988
#  0.96213505 0.93538179]
# Aggregation took 1.6275
#
# Average test loss: 1.1011, Test accuracy: 7756/10000 (77.56%)
#
# Class      - Accuracy
# Plane      - 83.2
# Car        - 89.0
# Bird       - 65.6
# Cat        - 57.8
# Deer       - 76.0
# Dog        - 66.5
# Frog       - 84.7
# Horse      - 79.6
# Ship       - 86.2
# Truck      - 87.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.4946159422397614
# Peer 7  is  honest reputation: 0.0460209846496582
# Peer 18  is  honest reputation: 0.39434683322906494
# Peer 9  is  honest reputation: 1.4213453829288483
# Peer 4  is  honest reputation: 1.0885414481163025
# Peer 8  is  honest reputation: 1.4825738072395325
# Peer 6  is  honest reputation: 1.9552837312221527
# Peer 5  is  attacker reputation: -0.014863133430480957
# Peer 16  is  honest reputation: 1.3528302609920502
# Peer 13  is  honest reputation: 1.1525702476501465
# Average of peers' local losses: 0.116298
# Mixing took 2.4572
# -> Update reputation
# [9.74834175e-01 2.97158948e-04 8.41137545e-01 3.97767755e-01
#  9.14839170e-01 7.55402188e-02 9.13549953e-01 9.09866146e-01]
# Aggregation took 1.6505
#
# Average test loss: 1.0005, Test accuracy: 7758/10000 (77.58%)
#
# Class      - Accuracy
# Plane      - 83.2
# Car        - 88.9
# Bird       - 67.6
# Cat        - 62.1
# Deer       - 77.2
# Dog        - 61.2
# Frog       - 83.6
# Horse      - 78.8
# Ship       - 87.9
# Truck      - 85.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/110 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.2502638697624207
# Peer 15  is  honest reputation: 0.6394855976104736
# Peer 18  is  honest reputation: 0.39208489656448364
# Peer 8  is  honest reputation: 1.4978368878364563
# Peer 5  is  attacker reputation: -0.028612256050109863
# Peer 10  is  honest reputation: 1.4946159422397614
# Peer 1  is  honest reputation: 1.6811842322349548
# Peer 16  is  honest reputation: 1.5196649134159088
# Peer 7  is  honest reputation: 0.046774983406066895
# Peer 6  is  honest reputation: 2.152466982603073
# Average of peers' local losses: 0.113508
# Mixing took 3.1248
# -> Update reputation
# [0.58666605 0.94645557 0.95082467 0.         0.98404616 0.07190177
#  0.94635033 0.91615069 0.58910659 0.91312195]
# Aggregation took 1.9848
#
# Average test loss: 1.0209, Test accuracy: 7761/10000 (77.61%)
#
# Class      - Accuracy
# Plane      - 82.9
# Car        - 88.3
# Bird       - 65.5
# Cat        - 59.5
# Deer       - 76.2
# Dog        - 62.3
# Frog       - 84.3
# Horse      - 82.2
# Ship       - 88.3
# Truck      - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/110 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: -0.029800891876220703
# Peer 10  is  honest reputation: 1.5083376467227936
# Peer 6  is  honest reputation: 2.373941332101822
# Peer 13  is  honest reputation: 1.1525702476501465
# Peer 3  is  honest reputation: 1.5268706679344177
# Peer 8  is  honest reputation: 1.7589712738990784
# Peer 9  is  honest reputation: 1.52751424908638
# Peer 16  is  honest reputation: 1.7579624354839325
# Peer 18  is  honest reputation: 0.6386411786079407
# Peer 4  is  honest reputation: 1.1961406469345093
# Average of peers' local losses: 0.064621
# Mixing took 2.4853
# -> Update reputation
# [0.70695534 0.9894431  0.94407616 0.94300739 0.90279872 0.
#  0.93414021 0.88686143]
# Aggregation took 1.6325
#
# Average test loss: 1.0948, Test accuracy: 7783/10000 (77.83%)
#
# Class      - Accuracy
# Plane      - 83.5
# Car        - 88.4
# Bird       - 65.8
# Cat        - 61.7
# Deer       - 75.2
# Dog        - 63.2
# Frog       - 83.9
# Horse      - 81.1
# Ship       - 87.6
# Truck      - 87.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.6349116861820221
# Peer 8  is  honest reputation: 1.7589712738990784
# Peer 3  is  honest reputation: 1.696033239364624
# Peer 1  is  honest reputation: 1.8026521801948547
# Peer 19  is  honest reputation: 1.6174926459789276
# Peer 7  is  honest reputation: 0.0343705415725708
# Peer 9  is  honest reputation: 1.7057735621929169
# Peer 4  is  honest reputation: 1.3385262489318848
# Peer 6  is  honest reputation: 2.5509130656719208
# Peer 17  is  honest reputation: 1.2513935565948486
# Average of peers' local losses: 0.060823
# Mixing took 1.9147
# -> Update reputation
# [0.8991442  0.95030536 0.99305123 0.96579604 0.67075277 0.03748893]
# Aggregation took 1.2101
#
# Average test loss: 1.0809, Test accuracy: 7815/10000 (78.15%)
#
# Class      - Accuracy
# Plane      - 83.5
# Car        - 88.1
# Bird       - 67.1
# Cat        - 57.2
# Deer       - 76.6
# Dog        - 67.8
# Frog       - 85.4
# Horse      - 81.6
# Ship       - 87.8
# Truck      - 86.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/110 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: -0.06121939420700073
# Peer 18  is  honest reputation: 0.8125686645507812
# Peer 6  is  honest reputation: 2.760926753282547
# Peer 10  is  honest reputation: 1.6214429438114166
# Peer 16  is  honest reputation: 1.4186464846134186
# Peer 19  is  honest reputation: 1.6174926459789276
# Peer 9  is  honest reputation: 1.7057735621929169
# Peer 4  is  honest reputation: 1.3385262489318848
# Peer 1  is  honest reputation: 1.7664200067520142
# Peer 15  is  honest reputation: 0.7436082065105438
# Average of peers' local losses: 0.076693
# Mixing took 2.4592
# -> Update reputation
# [0.96673483 0.98105772 0.96074925 0.89158647 0.95606385 0.
#  0.99456935 0.92947121]
# Aggregation took 1.6145
#
# Average test loss: 1.0754, Test accuracy: 7801/10000 (78.01%)
#
# Class      - Accuracy
# Plane      - 84.4
# Car        - 87.8
# Bird       - 68.4
# Cat        - 58.6
# Deer       - 75.5
# Dog        - 67.1
# Frog       - 82.1
# Horse      - 81.7
# Ship       - 87.8
# Truck      - 86.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/110 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: -0.030995607376098633
# Peer 10  is  honest reputation: 1.6214429438114166
# Peer 4  is  honest reputation: 1.8476393818855286
# Peer 19  is  honest reputation: 1.5465737581253052
# Peer 8  is  honest reputation: 1.9571534395217896
# Peer 16  is  honest reputation: 1.9318931996822357
# Peer 3  is  honest reputation: 1.696033239364624
# Peer 17  is  honest reputation: 1.3992313146591187
# Peer 0  is  attacker reputation: -0.09035027027130127
# Peer 18  is  honest reputation: 1.3216927647590637
# Average of peers' local losses: 0.131504
# Mixing took 3.0918
# -> Update reputation
# [0.82498749 0.94378831 0.96965747 0.91044141 0.03131857 0.94421702
#  0.95973334 0.95128599 0.94595765 0.05849372]
# Aggregation took 2.0048
#
# Average test loss: 0.9576, Test accuracy: 7788/10000 (77.88%)
#
# Class      - Accuracy
# Plane      - 81.2
# Car        - 86.0
# Bird       - 68.3
# Cat        - 58.9
# Deer       - 79.9
# Dog        - 59.9
# Frog       - 86.3
# Horse      - 81.9
# Ship       - 87.8
# Truck      - 88.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/110 |
#
#
# Selected Peers:
# ...
# Peer 6  is  honest reputation: 5.773509532213211
# Peer 18  is  honest reputation: 6.477589309215546
# Peer 15  is  honest reputation: 3.126348316669464
# Average of peers' local losses: 0.045392
# Mixing took 2.5193
# -> Update reputation
# [0.99993903 0.99999994 0.99999333 0.99999239 0.99999996 0.99999966
#  0.99999685 0.99999988]
# Aggregation took 1.6225
#
# Average test loss: 1.0441, Test accuracy: 7908/10000 (79.08%)
#
# Class      - Accuracy
# Plane      - 84.3
# Car        - 90.3
# Bird       - 68.8
# Cat        - 59.4
# Deer       - 77.2
# Dog        - 67.1
# Frog       - 84.4
# Horse      - 83.3
# Ship       - 88.1
# Truck      - 87.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/110 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: -2.0269933342933655
# Peer 15  is  honest reputation: 3.103300154209137
# Peer 11  is  honest reputation: -2.0302045941352844
# Peer 16  is  honest reputation: 6.77507346868515
# Peer 8  is  honest reputation: 4.585209667682648
# Peer 10  is  honest reputation: 6.805234104394913
# Peer 17  is  honest reputation: 5.04354402422905
# Peer 4  is  honest reputation: 4.143826961517334
# Peer 19  is  honest reputation: 5.058472543954849
# Peer 6  is  honest reputation: 5.701359659433365
# Average of peers' local losses: 0.081314
# Mixing took 2.4462
# -> Update reputation
# [0.99999839 0.99999935 0.99999998 0.99999612 0.99996738 0.99999998
#  0.99999838 0.        ]
# Aggregation took 1.6325
#
# Average test loss: 1.0341, Test accuracy: 7921/10000 (79.21%)
#
# Class      - Accuracy
# Plane      - 84.2
# Car        - 90.4
# Bird       - 68.8
# Cat        - 59.4
# Deer       - 77.8
# Dog        - 67.1
# Frog       - 84.6
# Horse      - 83.5
# Ship       - 88.4
# Truck      - 87.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/110 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 4.2096487283706665
# Peer 15  is  honest reputation: 3.2167806029319763
# Peer 4  is  honest reputation: 4.2807135581970215
# Peer 8  is  honest reputation: 4.721673846244812
# Peer 9  is  honest reputation: 6.712221145629883
# Peer 0  is  attacker reputation: -2.2926404774188995
# Peer 6  is  honest reputation: 5.701359659433365
# Peer 1  is  honest reputation: 8.879639357328415
# Peer 14  is  honest reputation: -2.0269933342933655
# Peer 10  is  honest reputation: 6.9488551914691925
# Average of peers' local losses: 0.108721
# Mixing took 3.0798
# -> Update reputation
# [0.99997455 0.         0.99999998 1.         0.99999774 0.99999999
#  0.99999881 0.99999978 0.99999612 0.17866027]
# Aggregation took 1.9998
#
# Average test loss: 0.9449, Test accuracy: 7925/10000 (79.25%)
#
# Class      - Accuracy
# Plane      - 85.0
# Car        - 90.9
# Bird       - 68.6
# Cat        - 63.9
# Deer       - 77.3
# Dog        - 64.1
# Frog       - 85.0
# Horse      - 82.4
# Ship       - 87.6
# Truck      - 87.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 101/110 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 3.3041516542434692
# Peer 18  is  honest reputation: 6.55081582069397
# Peer 2  is  attacker reputation: -2.3023295998573303
# Peer 10  is  honest reputation: 7.190378934144974
# Peer 3  is  honest reputation: 6.21636763215065
# Peer 9  is  honest reputation: 6.914097249507904
# Peer 4  is  honest reputation: 4.514242231845856
# Peer 6  is  honest reputation: 5.689688891172409
# Peer 1  is  honest reputation: 9.060839384794235
# Peer 8  is  honest reputation: 4.836515486240387
# Average of peers' local losses: 0.049316
# Mixing took 3.0728
# -> Update reputation
# [1.         0.         1.         0.9999993  0.99999985 0.99999997
#  0.99999999 0.99999964 0.99999998 0.99999226]
# Aggregation took 2.0028
#
# Average test loss: 0.9495, Test accuracy: 7916/10000 (79.16%)
#
# Class      - Accuracy
# Plane      - 82.5
# Car        - 90.3
# Bird       - 70.0
# Cat        - 62.4
# Deer       - 77.3
# Dog        - 63.5
# Frog       - 85.4
# Horse      - 84.4
# Ship       - 88.3
# Truck      - 87.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 102/110 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: -2.420058697462082
# Peer 1  is  honest reputation: 9.025783568620682
# Peer 14  is  honest reputation: -2.1511634290218353
# Peer 4  is  honest reputation: 5.003099262714386
# Peer 8  is  honest reputation: 5.337405323982239
# Peer 9  is  honest reputation: 7.41479218006134
# Peer 15  is  honest reputation: 3.8026925921440125
# Peer 3  is  honest reputation: 6.709106594324112
# Peer 10  is  honest reputation: 7.6869222819805145
# Peer 18  is  honest reputation: 6.5225043296813965
# Average of peers' local losses: 0.093318
# Mixing took 2.4472
# -> Update reputation
# [0.         0.16117702 0.99999999 0.99999999 1.         0.99999969
#  0.99999978 1.        ]
# Aggregation took 1.6325
#
# Average test loss: 0.9523, Test accuracy: 7950/10000 (79.50%)
#
# Class      - Accuracy
# Plane      - 84.3
# Car        - 90.2
# Bird       - 70.7
# Cat        - 59.4
# Deer       - 77.2
# Dog        - 64.8
# Frog       - 87.2
# Horse      - 83.6
# Ship       - 89.5
# Truck      - 88.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 103/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 7.077264130115509
# Peer 13  is  honest reputation: 4.244660973548889
# Peer 17  is  honest reputation: 5.176176756620407
# Peer 9  is  honest reputation: 7.41479218006134
# Peer 14  is  honest reputation: -2.2966363728046417
# Peer 0  is  attacker reputation: -2.452569156885147
# Peer 15  is  honest reputation: 3.8026925921440125
# Peer 3  is  honest reputation: 7.2624485194683075
# Peer 19  is  honest reputation: 4.718031197786331
# Peer 6  is  honest reputation: 5.774623423814774
# Average of peers' local losses: 0.129022
# Mixing took 2.4923
# -> Update reputation
# [0.99999999 0.99999284 0.99999999 1.         0.99999906 0.
#  0.99999989 0.99999714]
# Aggregation took 1.6305
#
# Average test loss: 0.9221, Test accuracy: 7922/10000 (79.22%)
#
# Class      - Accuracy
# Plane      - 84.7
# Car        - 89.9
# Bird       - 69.4
# Cat        - 60.5
# Deer       - 79.5
# Dog        - 64.3
# Frog       - 85.9
# Horse      - 81.4
# Ship       - 89.6
# Truck      - 87.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 104/110 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 7.186020314693451
# Peer 15  is  honest reputation: 3.7896878719329834
# Peer 8  is  honest reputation: 5.385896295309067
# Peer 19  is  honest reputation: 4.80751171708107
# Peer 6  is  honest reputation: 5.898032158613205
# Peer 11  is  honest reputation: -2.479217529296875
# Peer 17  is  honest reputation: 5.176176756620407
# Peer 13  is  honest reputation: 4.248995840549469
# Peer 16  is  honest reputation: 6.905014932155609
# Peer 14  is  honest reputation: -2.2966363728046417
# Average of peers' local losses: 0.124789
# Mixing took 3.1869
# -> Update reputation
# [0.99999921 0.99999957 0.16384394 0.99999746 0.99999999 0.99999977
#  0.99999311 0.99999999 0.         0.99999991]
# Aggregation took 2.0028
#
# Average test loss: 0.8704, Test accuracy: 7909/10000 (79.09%)
#
# Class      - Accuracy
# Plane      - 84.5
# Car        - 88.7
# Bird       - 67.6
# Cat        - 58.0
# Deer       - 79.0
# Dog        - 68.6
# Frog       - 85.6
# Horse      - 82.2
# Ship       - 88.9
# Truck      - 87.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 105/110 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: -2.330690413713455
# Peer 16  is  honest reputation: 6.920280992984772
# Peer 3  is  honest reputation: 7.343378573656082
# Peer 6  is  honest reputation: 5.973485201597214
# Peer 4  is  honest reputation: 5.55182409286499
# Peer 9  is  honest reputation: 7.504713296890259
# Peer 13  is  honest reputation: 4.2922399044036865
# Peer 7  is  honest reputation: -2.482753962278366
# Peer 19  is  honest reputation: 4.878249973058701
# Peer 8  is  honest reputation: 5.495932728052139
# Average of peers' local losses: 0.138140
# Mixing took 3.1529
# -> Update reputation
# [0.9999998  0.99999999 0.99999999 0.01318997 0.99999986 0.99999952
#  0.99999849 0.99999995 0.05665429 0.99999999]
# Aggregation took 2.0168
#
# Average test loss: 0.8862, Test accuracy: 7927/10000 (79.27%)
#
# Class      - Accuracy
# Plane      - 82.2
# Car        - 89.7
# Bird       - 66.0
# Cat        - 58.1
# Deer       - 80.1
# Dog        - 69.7
# Frog       - 86.9
# Horse      - 83.2
# Ship       - 89.8
# Truck      - 87.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 106/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 5.175036281347275
# Peer 18  is  honest reputation: 7.1928733587265015
# Peer 7  is  honest reputation: -2.48307341337204
# Peer 9  is  honest reputation: 7.393681615591049
# Peer 16  is  honest reputation: 7.112434804439545
# Peer 8  is  honest reputation: 5.740921884775162
# Peer 15  is  honest reputation: 3.793109357357025
# Peer 6  is  honest reputation: 6.2742675840854645
# Peer 14  is  honest reputation: -2.4395491182804108
# Peer 19  is  honest reputation: 5.129962474107742
# Average of peers' local losses: 0.112425
# Mixing took 3.1769
# -> Update reputation
# [1.         0.9999998  0.99999977 0.99999998 0.         0.
#  0.99999992 0.99999999 0.99999999 0.99999356]
# Aggregation took 2.0158
#
# Average test loss: 0.9211, Test accuracy: 7934/10000 (79.34%)
#
# Class      - Accuracy
# Plane      - 83.1
# Car        - 89.6
# Bird       - 66.7
# Cat        - 58.2
# Deer       - 80.0
# Dog        - 69.2
# Frog       - 88.1
# Horse      - 82.2
# Ship       - 88.3
# Truck      - 88.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 107/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 8.240750104188919
# Peer 4  is  honest reputation: 5.569535613059998
# Peer 6  is  honest reputation: 6.606513351202011
# Peer 11  is  honest reputation: -2.535836338996887
# Peer 5  is  attacker reputation: -2.5417660027742386
# Peer 16  is  honest reputation: 7.294530212879181
# Peer 1  is  honest reputation: 9.206993848085403
# Peer 19  is  honest reputation: 5.457478255033493
# Peer 13  is  honest reputation: 4.551654398441315
# Peer 18  is  honest reputation: 7.229014128446579
# Average of peers' local losses: 0.144443
# Mixing took 2.5263
# -> Update reputation
# [1.         0.99999999 0.         0.99999842 1.         0.99999984
#  0.99999994 1.        ]
# Aggregation took 1.6305
#
# Average test loss: 0.9210, Test accuracy: 7943/10000 (79.43%)
#
# Class      - Accuracy
# Plane      - 85.1
# Car        - 90.0
# Bird       - 69.8
# Cat        - 57.1
# Deer       - 80.4
# Dog        - 69.5
# Frog       - 84.0
# Horse      - 84.3
# Ship       - 86.8
# Truck      - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 108/110 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 5.508743494749069
# Peer 1  is  honest reputation: 9.206993848085403
# Peer 15  is  honest reputation: 3.781062424182892
# Peer 13  is  honest reputation: 4.471011579036713
# Peer 3  is  honest reputation: 7.3443368673324585
# Peer 19  is  honest reputation: 5.611828714609146
# Peer 18  is  honest reputation: 7.768608003854752
# Peer 4  is  honest reputation: 6.104838192462921
# Peer 10  is  honest reputation: 8.26763105392456
# Peer 14  is  honest reputation: -2.542583703994751
# Average of peers' local losses: 0.088314
# Mixing took 2.5863
# -> Update reputation
# [9.99999877e-01 1.00000000e+00 1.00000000e+00 9.99999911e-01
#  9.99999995e-01 9.99999999e-01 9.99998879e-01 5.21659804e-04]
# Aggregation took 1.6415
#
# Average test loss: 0.9099, Test accuracy: 7926/10000 (79.26%)
#
# Class      - Accuracy
# Plane      - 85.3
# Car        - 88.1
# Bird       - 68.6
# Cat        - 56.5
# Deer       - 78.4
# Dog        - 68.8
# Frog       - 86.7
# Horse      - 83.9
# Ship       - 88.7
# Truck      - 87.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 109/110 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 9.201619297266006
# Peer 3  is  honest reputation: 7.34612837433815
# Peer 8  is  honest reputation: 5.972240597009659
# Peer 5  is  attacker reputation: -2.5417660027742386
# Peer 10  is  honest reputation: 8.518801391124725
# Peer 13  is  honest reputation: 4.604093253612518
# Peer 15  is  honest reputation: 3.781062424182892
# Peer 16  is  honest reputation: 7.856317400932312
# Peer 6  is  honest reputation: 7.167742103338242
# Peer 4  is  honest reputation: 6.104838192462921
# Average of peers' local losses: 0.135987
# Mixing took 1.3062
# -> Update reputation
# [1.         0.99999996 1.         0.99999904]
# Aggregation took 0.8668
#
# Average test loss: 0.8905, Test accuracy: 7834/10000 (78.34%)
#
# Class      - Accuracy
# Plane      - 85.3
# Car        - 90.4
# Bird       - 68.4
# Cat        - 57.6
# Deer       - 80.7
# Dog        - 60.3
# Frog       - 86.1
# Horse      - 83.2
# Ship       - 86.0
# Truck      - 85.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 110/110 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 8.518801391124725
# Peer 4  is  honest reputation: 6.221430659294128
# Peer 13  is  honest reputation: 4.681654751300812
# Peer 5  is  attacker reputation: -2.5417660027742386
# Peer 3  is  honest reputation: 7.34612837433815
# Peer 9  is  honest reputation: 7.731338232755661
# Peer 1  is  honest reputation: 9.218330353498459
# Peer 17  is  honest reputation: 5.707391649484634
# Peer 8  is  honest reputation: 5.972240597009659
# Peer 16  is  honest reputation: 7.80618417263031
# Average of peers' local losses: 0.176113
# Mixing took 2.6904
# -> Update reputation
# [0.99999996 0.15576798 1.         1.         1.         0.99999993
#  0.99999991 1.        ]
# Aggregation took 1.6335
#
# Average test loss: 0.8638, Test accuracy: 7910/10000 (79.10%)
#
# Class      - Accuracy
# Plane      - 80.5
# Car        - 90.8
# Bird       - 70.9
# Cat        - 60.7
# Deer       - 78.2
# Dog        - 65.2
# Frog       - 87.3
# Horse      - 81.6
# Ship       - 89.9
# Truck      - 85.9
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.8881, Test accuracy: 7981/10000 (79.81%)
#
# ***********************************************************************************
# Class      - Accuracy
# Plane      - 84.6
# Car        - 90.0
# Bird       - 69.1
# Cat        - 59.0
# Deer       - 80.4
# Dog        - 67.4
# Frog       - 87.3
# Horse      - 83.7
# Ship       - 88.9
# Truck      - 87.7
# Global accuracies:  [10.16, 23.77, 34.0, 43.43, 47.94, 51.9, 55.37, 56.73, 61.07, 63.5, 66.91, 68.25, 69.27, 71.27, 72.05, 72.34, 73.3, 74.03, 74.12, 74.75, 75.3, 74.8, 76.23, 76.06, 76.01, 76.49, 76.73, 76.24, 76.66, 77.11, 76.41, 77.27, 76.69, 77.13, 77.35, 77.73, 77.93, 78.2, 77.65, 77.56, 77.58, 77.61, 77.83, 78.15, 78.01, 77.88, 78.13, 78.14, 78.22, 77.99, 78.07, 77.99, 77.88, 78.32, 77.74, 78.3, 78.34, 78.37, 78.36, 78.56, 78.43, 78.74, 78.57, 78.51, 78.46, 78.74, 78.44, 78.75, 78.69, 78.62, 78.7, 78.77, 78.61, 78.86, 78.6, 78.81, 78.72, 78.86, 78.94, 78.61, 78.93, 78.41, 78.44, 78.55, 78.28, 78.59, 78.84, 78.88, 79.32, 78.73, 78.84, 78.79, 78.89, 79.12, 79.25, 79.19, 79.19, 79.08, 79.21, 79.25, 79.16, 79.5, 79.22, 79.09, 79.27, 79.34, 79.43, 79.26, 78.34, 79.1, 79.81]
# Class 5 accuracies:  [0.0, 0.2, 0.0, 0.5, 0.2, 3.3, 13.6, 0.0, 34.7, 24.6, 54.9, 58.7, 52.0, 57.7, 54.5, 60.5, 58.7, 59.1, 63.7, 61.9, 66.3, 64.6, 60.0, 62.2, 65.2, 65.7, 61.7, 61.0, 65.9, 63.8, 62.2, 61.5, 65.4, 66.4, 64.1, 67.8, 67.3, 67.8, 68.4, 66.5, 61.2, 62.3, 63.2, 67.8, 67.1, 59.9, 63.3, 65.8, 67.5, 66.3, 66.4, 66.0, 53.8, 64.3, 62.0, 61.1, 62.2, 64.9, 69.9, 61.1, 67.6, 68.1, 67.9, 63.4, 62.3, 66.9, 65.1, 68.0, 63.8, 62.8, 66.5, 67.2, 58.6, 66.1, 60.7, 62.6, 66.1, 62.6, 67.7, 62.7, 68.8, 66.7, 62.9, 64.3, 65.0, 65.9, 65.3, 63.2, 68.7, 66.9, 66.7, 62.9, 64.0, 63.5, 67.4, 61.7, 66.5, 67.1, 67.1, 64.1, 63.5, 64.8, 64.3, 68.6, 69.7, 69.2, 69.5, 68.8, 60.3, 65.2, 67.4]
# Test loss: [2.3554, 1.9921, 1.745, 1.5016, 1.3802, 1.2736, 1.2393, 1.3838, 1.1136, 1.0608, 0.9968, 1.0017, 0.9897, 0.9541, 0.9468, 0.9529, 0.9487, 0.8955, 0.94, 0.9196, 0.9318, 0.9466, 0.9104, 0.9303, 0.9137, 0.9962, 0.9325, 0.9827, 0.8975, 0.9802, 0.9702, 0.9656, 0.9667, 0.9381, 1.0008, 1.0274, 1.0046, 1.057, 1.0054, 1.1011, 1.0005, 1.0209, 1.0948, 1.0809, 1.0754, 0.9576, 0.985, 0.9838, 1.0303, 1.0863, 1.051, 1.0813, 1.0919, 0.969, 0.9114, 0.8341, 0.9352, 0.9306, 0.9213, 0.932, 0.9077, 1.0216, 0.9947, 0.9809, 1.021, 1.0325, 0.9735, 0.9763, 1.0102, 1.0342, 1.0342, 1.0374, 1.0288, 1.0296, 1.0388, 1.0023, 1.0215, 1.0343, 1.0126, 0.9984, 0.9422, 0.8846, 0.7858, 0.8192, 0.8629, 0.884, 0.8247, 0.9043, 0.9882, 0.9537, 1.0171, 0.9813, 1.0024, 0.9515, 0.9777, 1.0089, 1.0204, 1.0441, 1.0341, 0.9449, 0.9495, 0.9523, 0.9221, 0.8704, 0.8862, 0.9211, 0.921, 0.9099, 0.8905, 0.8638, 0.8881]
# Label-flipping attack succes rate: 14.7
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 1.91
# --> End of Experiment.
