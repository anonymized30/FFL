# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "CIFAR10"
MODEL_NAME = "VGG16"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 100
LOCAL_BS = 32 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Plane':0,
               'Car':1, 
               'Bird':2, 
               'Cat':3, 
               'Deer':4,
               'Dog':5, 
               'Frog':6, 
               'Horse':7, 
               'Ship':8, 
               'Truck':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 5 # the source class
TARGET_CLASS = 3 # the target class 

CLASS_PER_PEER = 1
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = True)

# %%
RULE = 'median'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating VGG16 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: gaussian_noise
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.278400
# Mixing took 3.277
# -> Update reputation
# Aggregation took 3.2249
#
# Average test loss: 2.2832, Test accuracy: 1275/10000 (12.75%)
#
# Class      - Accuracy
# Plane      - 1.9
# Car        - 10.6
# Bird       - 0.0
# Cat        - 0.0
# Deer       - 96.2
# Dog        - 0.0
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 14.1
# Truck      - 4.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: -0.00038552284240722656
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.0
# Peer 5  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: -0.3424331843852997
# Peer 2  is  attacker reputation: -0.39806225895881653
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0011565685272216797
# Peer 17  is  honest reputation: 0.082730233669281
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 2.169849
# Mixing took 3.3851
# -> Update reputation
# Aggregation took 3.2219
#
# Average test loss: 2.1401, Test accuracy: 1917/10000 (19.17%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 13.5
# Bird       - 1.1
# Cat        - 0.0
# Deer       - 6.0
# Dog        - 0.0
# Frog       - 92.3
# Horse      - 16.2
# Ship       - 15.1
# Truck      - 47.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.05854886770248413
# Peer 4  is  honest reputation: 0.17446589469909668
# Peer 0  is  attacker reputation: 0.0
# Peer 12  is  attacker reputation: -0.023787498474121094
# Peer 17  is  honest reputation: 0.24304324388504028
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.09070229530334473
# Peer 19  is  honest reputation: 0.13624393939971924
# Peer 5  is  attacker reputation: -0.022501468658447266
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 2.057185
# Mixing took 3.4511
# -> Update reputation
# Aggregation took 3.282
#
# Average test loss: 2.0535, Test accuracy: 1944/10000 (19.44%)
#
# Class      - Accuracy
# Plane      - 0.1
# Car        - 1.0
# Bird       - 5.8
# Cat        - 0.0
# Deer       - 88.6
# Dog        - 6.0
# Frog       - 0.0
# Horse      - 13.8
# Ship       - 74.3
# Truck      - 4.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: -0.272878497838974
# Peer 18  is  honest reputation: 0.06983202695846558
# Peer 15  is  honest reputation: 0.18237435817718506
# Peer 2  is  attacker reputation: -0.4212125837802887
# Peer 17  is  honest reputation: 0.30685800313949585
# Peer 9  is  honest reputation: 0.06324416399002075
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.06866085529327393
# Peer 8  is  honest reputation: 0.07089656591415405
# Average of peers' local losses: 1.952735
# Mixing took 3.5252
# -> Update reputation
# Aggregation took 3.254
#
# Average test loss: 1.8527, Test accuracy: 3000/10000 (30.00%)
#
# Class      - Accuracy
# Plane      - 32.0
# Car        - 38.8
# Bird       - 5.3
# Cat        - 2.1
# Deer       - 1.4
# Dog        - 17.6
# Frog       - 84.3
# Horse      - 33.6
# Ship       - 66.5
# Truck      - 18.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.27689242362976074
# Peer 0  is  attacker reputation: -0.02115720510482788
# Peer 19  is  honest reputation: 0.20165151357650757
# Peer 2  is  attacker reputation: -0.8175003230571747
# Peer 18  is  honest reputation: 0.13473862409591675
# Peer 7  is  honest reputation: 0.19486117362976074
# Peer 13  is  honest reputation: -0.2777844965457916
# Peer 5  is  attacker reputation: -0.04358285665512085
# Peer 10  is  honest reputation: 0.014717936515808105
# Peer 3  is  honest reputation: 0.12755966186523438
# Average of peers' local losses: 1.870784
# Mixing took 3.3601
# -> Update reputation
# Aggregation took 3.28
#
# Average test loss: 1.7749, Test accuracy: 3269/10000 (32.69%)
#
# Class      - Accuracy
# Plane      - 27.2
# Car        - 71.4
# Bird       - 3.3
# Cat        - 0.2
# Deer       - 73.8
# Dog        - 31.8
# Frog       - 16.1
# Horse      - 38.2
# Ship       - 52.6
# Truck      - 12.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.08783966302871704
# Peer 17  is  honest reputation: 0.3253345489501953
# Peer 19  is  honest reputation: 0.2661691904067993
# Peer 9  is  honest reputation: 0.07818925380706787
# Peer 3  is  honest reputation: 0.20128512382507324
# Peer 12  is  attacker reputation: -0.04580962657928467
# Peer 14  is  honest reputation: -0.3418791592121124
# Peer 1  is  honest reputation: 0.08528327941894531
# Peer 18  is  honest reputation: 0.18909955024719238
# Peer 0  is  attacker reputation: -0.030601799488067627
# Average of peers' local losses: 1.792780
# Mixing took 3.4661
# -> Update reputation
# Aggregation took 3.259
#
# Average test loss: 1.7107, Test accuracy: 3622/10000 (36.22%)
#
# Class      - Accuracy
# Plane      - 55.7
# Car        - 60.7
# Bird       - 6.2
# Cat        - 0.2
# Deer       - 57.9
# Dog        - 36.5
# Frog       - 45.5
# Horse      - 34.7
# Ship       - 34.2
# Truck      - 30.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.08455854654312134
# Peer 4  is  honest reputation: 0.34921348094940186
# Peer 18  is  honest reputation: 0.5265063941478729
# Peer 17  is  honest reputation: 0.6462650001049042
# Peer 10  is  honest reputation: 0.08854663372039795
# Peer 7  is  honest reputation: 0.21994704008102417
# Peer 11  is  honest reputation: 0.06871539354324341
# Peer 12  is  attacker reputation: -0.09830746054649353
# Peer 15  is  honest reputation: 0.24057608842849731
# Peer 13  is  honest reputation: -0.22611954808235168
# Average of peers' local losses: 1.742550
# Mixing took 3.5472
# -> Update reputation
# Aggregation took 3.28
#
# Average test loss: 1.6350, Test accuracy: 3894/10000 (38.94%)
#
# Class      - Accuracy
# Plane      - 56.7
# Car        - 72.8
# Bird       - 7.0
# Cat        - 5.7
# Deer       - 53.7
# Dog        - 39.0
# Frog       - 57.1
# Horse      - 44.0
# Ship       - 30.2
# Truck      - 23.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.10803502798080444
# Peer 14  is  honest reputation: -0.005582034587860107
# Peer 5  is  attacker reputation: -0.051944851875305176
# Peer 6  is  honest reputation: 0.10150271654129028
# Peer 10  is  honest reputation: 0.11705315113067627
# Peer 15  is  honest reputation: 0.2564530372619629
# Peer 1  is  honest reputation: 0.38772979378700256
# Peer 3  is  honest reputation: 0.5315521657466888
# Peer 12  is  attacker reputation: -0.4068976640701294
# Peer 7  is  honest reputation: 0.2651420831680298
# Average of peers' local losses: 1.685682
# Mixing took 3.3871
# -> Update reputation
# Aggregation took 3.2439
#
# Average test loss: 1.4979, Test accuracy: 4279/10000 (42.79%)
#
# Class      - Accuracy
# Plane      - 52.9
# Car        - 73.6
# Bird       - 10.6
# Cat        - 18.0
# Deer       - 22.2
# Dog        - 40.0
# Frog       - 64.2
# Horse      - 60.6
# Ship       - 49.3
# Truck      - 36.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: -0.4546627700328827
# Peer 11  is  honest reputation: 0.06342309713363647
# Peer 6  is  honest reputation: 0.3813571333885193
# Peer 9  is  honest reputation: 0.42661556601524353
# Peer 13  is  honest reputation: -0.20343360304832458
# Peer 1  is  honest reputation: 0.38739731907844543
# Peer 18  is  honest reputation: 0.2707684338092804
# Peer 5  is  attacker reputation: -0.10023704171180725
# Peer 8  is  honest reputation: 0.3933218717575073
# Peer 14  is  honest reputation: -0.0045847296714782715
# Average of peers' local losses: 1.654691
# Mixing took 3.4501
# -> Update reputation
# Aggregation took 3.281
#
# Average test loss: 1.5258, Test accuracy: 4149/10000 (41.49%)
#
# Class      - Accuracy
# Plane      - 61.5
# Car        - 78.6
# Bird       - 16.1
# Cat        - 14.5
# Deer       - 18.5
# Dog        - 43.5
# Frog       - 78.1
# Horse      - 41.2
# Ship       - 39.6
# Truck      - 23.3
#
# Backdoor ASR 0.0
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.5384120345115662
# Peer 18  is  honest reputation: 0.30842843651771545
# Peer 11  is  honest reputation: 0.0914108157157898
# Peer 16  is  honest reputation: 0.1455543041229248
# Peer 19  is  honest reputation: 0.2659335434436798
# Peer 13  is  honest reputation: -0.20728430151939392
# Peer 0  is  attacker reputation: -0.0815441906452179
# Peer 10  is  honest reputation: 0.39101094007492065
# Peer 9  is  honest reputation: 0.4381677210330963
# Peer 12  is  attacker reputation: -0.7108899354934692
# Average of peers' local losses: 1.609090
# Mixing took 3.4722
# -> Update reputation
# Aggregation took 3.268
#
# Average test loss: 1.4635, Test accuracy: 4653/10000 (46.53%)
#
# Class      - Accuracy
# Plane      - 45.5
# Car        - 67.4
# Bird       - 23.1
# Cat        - 11.4
# Deer       - 50.0
# Dog        - 44.7
# Frog       - 59.0
# Horse      - 48.0
# Ship       - 65.6
# Truck      - 50.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.40606844425201416
# Peer 11  is  honest reputation: 0.3720558285713196
# Peer 14  is  honest reputation: 0.04050225019454956
# Peer 15  is  honest reputation: 0.5514471530914307
# Peer 7  is  honest reputation: 0.5380581617355347
# Peer 18  is  honest reputation: 0.5932196080684662
# Peer 19  is  honest reputation: 0.5630050003528595
# Peer 3  is  honest reputation: 0.844051331281662
# Peer 16  is  honest reputation: 0.39146530628204346
# Peer 17  is  honest reputation: 0.678365558385849
# Average of peers' local losses: 1.560754
# Mixing took 3.298
# -> Update reputation
# [0.59093188 0.51172046 0.50870757 0.         0.75617703 0.4215459
#  0.40356845 0.46288158 0.35554389 0.56751085]
# Aggregation took 2.0358
#
# Average test loss: 1.4327, Test accuracy: 4658/10000 (46.58%)
#
# Class      - Accuracy
# Plane      - 40.7
# Car        - 75.6
# Bird       - 20.0
# Cat        - 33.4
# Deer       - 44.9
# Dog        - 20.7
# Frog       - 75.5
# Horse      - 38.3
# Ship       - 69.8
# Truck      - 46.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.6783082187175751
# Peer 3  is  honest reputation: 1.0216908156871796
# Peer 11  is  honest reputation: 0.4840352535247803
# Peer 9  is  honest reputation: 0.7192038595676422
# Peer 6  is  honest reputation: 0.4114786386489868
# Peer 7  is  honest reputation: 0.5354371666908264
# Peer 19  is  honest reputation: 0.7135615050792694
# Peer 16  is  honest reputation: 0.46236908435821533
# Peer 4  is  honest reputation: 0.3889147639274597
# Peer 18  is  honest reputation: 0.595449298620224
# Average of peers' local losses: 1.519566
# Mixing took 3.4481
# -> Update reputation
# [0.34346459 0.29239083 0.54100159 0.57930855 0.4699624  0.62568909
#  0.39887157 0.60175306 0.76855365 0.35524497]
# Aggregation took 2.163
#
# Average test loss: 1.3704, Test accuracy: 4965/10000 (49.65%)
#
# Class      - Accuracy
# Plane      - 48.6
# Car        - 73.1
# Bird       - 25.9
# Cat        - 19.2
# Deer       - 51.4
# Dog        - 48.8
# Frog       - 64.5
# Horse      - 56.3
# Ship       - 66.1
# Truck      - 42.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.5444868206977844
# Peer 8  is  honest reputation: 0.40624040365219116
# Peer 3  is  honest reputation: 1.0512493550777435
# Peer 18  is  honest reputation: 0.6400353014469147
# Peer 6  is  honest reputation: 0.33564335107803345
# Peer 15  is  honest reputation: 0.5995225310325623
# Peer 17  is  honest reputation: 0.695886105298996
# Peer 5  is  attacker reputation: -0.3575112521648407
# Peer 19  is  honest reputation: 0.7303555905818939
# Peer 9  is  honest reputation: 0.7687648832798004
# Average of peers' local losses: 1.462241
# Mixing took 3.4061
# -> Update reputation
# [0.35170396 0.55024795 0.3290906  0.77837892 0.45320083 0.
#  0.60330252 0.49553544 0.6336909  0.52878549]
# Aggregation took 2.0819
#
# Average test loss: 1.3690, Test accuracy: 5054/10000 (50.54%)
#
# Class      - Accuracy
# Plane      - 46.5
# Car        - 77.8
# Bird       - 47.4
# Cat        - 25.1
# Deer       - 17.0
# Dog        - 48.1
# Frog       - 64.9
# Horse      - 64.4
# Ship       - 67.0
# Truck      - 47.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.40303751826286316
# Peer 4  is  honest reputation: 0.4058982729911804
# Peer 9  is  honest reputation: 0.7820245325565338
# Peer 10  is  honest reputation: 0.3920724391937256
# Peer 11  is  honest reputation: 0.577835738658905
# Peer 18  is  honest reputation: 0.6532016098499298
# Peer 14  is  honest reputation: 0.0037536025047302246
# Peer 17  is  honest reputation: 0.7327881753444672
# Peer 15  is  honest reputation: 0.6229224801063538
# Peer 16  is  honest reputation: 0.45677101612091064
# Average of peers' local losses: 1.524928
# Mixing took 3.5012
# -> Update reputation
# [0.5376872  0.59906545 0.4520706  0.         0.55230173 0.40455971
#  0.62721759 0.38430358 0.44908403 0.59430115]
# Aggregation took 2.0689
#
# Average test loss: 1.3687, Test accuracy: 5029/10000 (50.29%)
#
# Class      - Accuracy
# Plane      - 30.1
# Car        - 69.1
# Bird       - 22.4
# Cat        - 10.7
# Deer       - 55.1
# Dog        - 52.9
# Frog       - 79.5
# Horse      - 54.4
# Ship       - 74.4
# Truck      - 54.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.39247995615005493
# Peer 18  is  honest reputation: 0.723596841096878
# Peer 6  is  honest reputation: 0.3762727975845337
# Peer 17  is  honest reputation: 0.6328051388263702
# Peer 8  is  honest reputation: 0.4018516540527344
# Peer 14  is  honest reputation: -0.006470859050750732
# Peer 3  is  honest reputation: 1.075708955526352
# Peer 10  is  honest reputation: 0.4370078444480896
# Peer 9  is  honest reputation: 0.7687245905399323
# Peer 15  is  honest reputation: 0.6535959243774414
# Average of peers' local losses: 1.452560
# Mixing took 3.5552
# -> Update reputation
# [0.56846408 0.3422206  0.35690583 0.40326513 0.64736214 0.34146375
#  0.         0.41585722 0.7898846  0.61354015]
# Aggregation took 2.0449
#
# Average test loss: 1.2676, Test accuracy: 5387/10000 (53.87%)
#
# Class      - Accuracy
# Plane      - 44.7
# Car        - 71.3
# Bird       - 33.9
# Cat        - 24.7
# Deer       - 41.1
# Dog        - 48.4
# Frog       - 75.5
# Horse      - 65.9
# Ship       - 70.8
# Truck      - 62.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.102091759443283
# Peer 19  is  honest reputation: 0.5231858789920807
# Peer 7  is  honest reputation: 0.40430253744125366
# Peer 18  is  honest reputation: 0.7455459535121918
# Peer 15  is  honest reputation: 0.6762176752090454
# Peer 17  is  honest reputation: 0.45850905776023865
# Peer 1  is  honest reputation: 0.5154609382152557
# Peer 8  is  honest reputation: 0.38671553134918213
# Peer 10  is  honest reputation: 0.47363948822021484
# Peer 9  is  honest reputation: 0.8017114698886871
# Average of peers' local losses: 1.392112
# Mixing took 3.4111
# -> Update reputation
# [0.4566148  0.82813359 0.53736674 0.66610458 0.5909179  0.38892335
#  0.5564628  0.4732822  0.66096503 0.39402366]
# Aggregation took 2.0719
#
# Average test loss: 1.2223, Test accuracy: 5533/10000 (55.33%)
#
# Class      - Accuracy
# Plane      - 58.2
# Car        - 76.5
# Bird       - 34.1
# Cat        - 42.1
# Deer       - 50.6
# Dog        - 34.5
# Frog       - 71.0
# Horse      - 56.8
# Ship       - 68.4
# Truck      - 61.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.8346748650074005
# Peer 10  is  honest reputation: 0.4414978623390198
# Peer 4  is  honest reputation: 0.46099764108657837
# Peer 8  is  honest reputation: 0.5452585220336914
# Peer 6  is  honest reputation: 0.3875725269317627
# Peer 13  is  honest reputation: 0.04470178484916687
# Peer 11  is  honest reputation: 0.7161984443664551
# Peer 14  is  honest reputation: -0.010237395763397217
# Peer 19  is  honest reputation: 0.6586616933345795
# Peer 15  is  honest reputation: 0.8254923820495605
# Average of peers' local losses: 1.350124
# Mixing took 3.349
# -> Update reputation
# [0.62264484 0.55964018 0.61220985 0.4007344  0.54042794 0.67312593
#  0.         0.0147315  0.33121555 0.27574005]
# Aggregation took 2.0959
#
# Average test loss: 1.2111, Test accuracy: 5582/10000 (55.82%)
#
# Class      - Accuracy
# Plane      - 39.5
# Car        - 70.4
# Bird       - 31.8
# Cat        - 24.6
# Deer       - 50.5
# Dog        - 47.8
# Frog       - 82.5
# Horse      - 59.3
# Ship       - 78.5
# Truck      - 73.3
#
# Backdoor ASR 0.0
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.9028910994529724
# Peer 19  is  honest reputation: 0.691213995218277
# Peer 1  is  honest reputation: 0.6314128339290619
# Peer 11  is  honest reputation: 0.8157670497894287
# Peer 17  is  honest reputation: 0.44752129912376404
# Peer 13  is  honest reputation: 0.10118666291236877
# Peer 3  is  honest reputation: 1.2131336629390717
# Peer 9  is  honest reputation: 0.7989024817943573
# Peer 16  is  honest reputation: 0.5192083120346069
# Peer 8  is  honest reputation: 0.7187632322311401
# Average of peers' local losses: 1.332343
# Mixing took 3.4421
# -> Update reputation
# [0.65207118 0.46181511 0.68068798 0.8474484  0.69296563 0.62872064
#  0.         0.62851967 0.57279916 0.44847539]
# Aggregation took 2.0268
#
# Average test loss: 1.1768, Test accuracy: 5691/10000 (56.91%)
#
# Class      - Accuracy
# Plane      - 40.5
# Car        - 79.1
# Bird       - 42.6
# Cat        - 28.2
# Deer       - 46.2
# Dog        - 40.1
# Frog       - 79.2
# Horse      - 65.3
# Ship       - 81.8
# Truck      - 66.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.6905486285686493
# Peer 7  is  honest reputation: 0.5239929556846619
# Peer 8  is  honest reputation: 0.7781673073768616
# Peer 4  is  honest reputation: 0.5109776258468628
# Peer 15  is  honest reputation: 0.892508327960968
# Peer 0  is  attacker reputation: -0.1310710906982422
# Peer 1  is  honest reputation: 0.7778350412845612
# Peer 13  is  honest reputation: 0.028709322214126587
# Peer 17  is  honest reputation: 0.5216598212718964
# Peer 3  is  honest reputation: 1.2858985364437103
# Average of peers' local losses: 1.278971
# Mixing took 3.4431
# -> Update reputation
# [0.006257   0.46883006 0.         0.4689086  0.84289763 0.6236191
#  0.45391106 0.68015633 0.57932479 0.45726144]
# Aggregation took 2.0669
#
# Average test loss: 1.1986, Test accuracy: 5694/10000 (56.94%)
#
# Class      - Accuracy
# Plane      - 62.8
# Car        - 84.9
# Bird       - 39.5
# Cat        - 16.7
# Deer       - 41.6
# Dog        - 60.9
# Frog       - 79.6
# Horse      - 61.8
# Ship       - 58.2
# Truck      - 63.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.5506429672241211
# Peer 11  is  honest reputation: 0.8177632093429565
# Peer 9  is  honest reputation: 0.8692645132541656
# Peer 15  is  honest reputation: 0.8904325366020203
# Peer 1  is  honest reputation: 0.5696980655193329
# Peer 4  is  honest reputation: 0.5548709034919739
# Peer 10  is  honest reputation: 0.430647075176239
# Peer 3  is  honest reputation: 1.2921260297298431
# Peer 18  is  honest reputation: 0.710042268037796
# Peer 8  is  honest reputation: 0.7919332981109619
# Average of peers' local losses: 1.361427
# Mixing took 3.5622
# -> Update reputation
# [0.52507684 0.72990682 0.521759   0.70446567 0.57063969 0.64877709
#  0.83946688 0.28890364 0.69862214 0.62604813]
# Aggregation took 2.1339
#
# Average test loss: 1.2289, Test accuracy: 5502/10000 (55.02%)
#
# Class      - Accuracy
# Plane      - 38.3
# Car        - 76.4
# Bird       - 31.2
# Cat        - 38.4
# Deer       - 71.6
# Dog        - 27.8
# Frog       - 74.1
# Horse      - 52.9
# Ship       - 81.5
# Truck      - 58.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.7224734723567963
# Peer 9  is  honest reputation: 0.9895555675029755
# Peer 7  is  honest reputation: 0.6443511843681335
# Peer 18  is  honest reputation: 0.834211677312851
# Peer 0  is  attacker reputation: -0.3860718011856079
# Peer 14  is  honest reputation: 0.04225641489028931
# Peer 6  is  honest reputation: 0.36951977014541626
# Peer 17  is  honest reputation: 0.5695973932743073
# Peer 11  is  honest reputation: 0.7959180474281311
# Peer 4  is  honest reputation: 0.6397813558578491
# Average of peers' local losses: 1.293745
# Mixing took 3.4381
# -> Update reputation
# [0.52877819 0.63523865 0.65425876 0.3202629  0.34767905 0.
#  0.739915   0.00439663 0.56558183 0.45589042]
# Aggregation took 2.0919
#
# Average test loss: 1.1313, Test accuracy: 5947/10000 (59.47%)
#
# Class      - Accuracy
# Plane      - 58.2
# Car        - 82.6
# Bird       - 45.6
# Cat        - 37.9
# Deer       - 60.9
# Dog        - 45.2
# Frog       - 65.7
# Horse      - 55.7
# Ship       - 78.2
# Truck      - 64.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.7214772999286652
# Peer 8  is  honest reputation: 0.9371386170387268
# Peer 18  is  honest reputation: 0.8631835281848907
# Peer 4  is  honest reputation: 0.44327592849731445
# Peer 6  is  honest reputation: 0.4124147295951843
# Peer 10  is  honest reputation: 0.35839730501174927
# Peer 3  is  honest reputation: 1.2803930342197418
# Peer 14  is  honest reputation: 0.08487135171890259
# Peer 15  is  honest reputation: 0.925631582736969
# Peer 7  is  honest reputation: 0.6689223051071167
# Average of peers' local losses: 1.299001
# Mixing took 3.4581
# -> Update reputation
# [0.49091632 0.27650573 0.66540619 0.84354214 0.66892424 0.59721084
#  0.64541041 0.02194953 0.39238145 0.31216894]
# Aggregation took 2.0399
#
# Average test loss: 1.1771, Test accuracy: 5813/10000 (58.13%)
#
# Class      - Accuracy
# Plane      - 48.9
# Car        - 79.9
# Bird       - 33.6
# Cat        - 38.1
# Deer       - 60.0
# Dog        - 37.5
# Frog       - 84.9
# Horse      - 57.0
# Ship       - 79.2
# Truck      - 62.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.6704107820987701
# Peer 8  is  honest reputation: 0.9355974197387695
# Peer 9  is  honest reputation: 1.0307662189006805
# Peer 15  is  honest reputation: 0.9005359411239624
# Peer 16  is  honest reputation: 0.5384856462478638
# Peer 18  is  honest reputation: 0.9419375360012054
# Peer 10  is  honest reputation: 0.45609062910079956
# Peer 4  is  honest reputation: 0.5477556586265564
# Peer 13  is  honest reputation: 0.0672847330570221
# Peer 6  is  honest reputation: 0.4170384407043457
# Average of peers' local losses: 1.258357
# Mixing took 3.34
# -> Update reputation
# [0.         0.24064352 0.68188319 0.69004284 0.37118325 0.67677929
#  0.36463344 0.31789332 0.52419364 0.68418232]
# Aggregation took 2.0519
#
# Average test loss: 1.1089, Test accuracy: 6056/10000 (60.56%)
#
# Class      - Accuracy
# Plane      - 51.6
# Car        - 81.0
# Bird       - 44.1
# Cat        - 27.4
# Deer       - 60.0
# Dog        - 57.7
# Frog       - 77.3
# Horse      - 62.6
# Ship       - 78.5
# Truck      - 65.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.15509694814682007
# Peer 19  is  honest reputation: 0.7335850298404694
# Peer 8  is  honest reputation: 0.9884153008460999
# Peer 10  is  honest reputation: 0.5412748456001282
# Peer 11  is  honest reputation: 0.830625057220459
# Peer 18  is  honest reputation: 0.9841054975986481
# Peer 6  is  honest reputation: 0.4807819724082947
# Peer 15  is  honest reputation: 0.9746274948120117
# Peer 7  is  honest reputation: 0.8219443559646606
# Peer 13  is  honest reputation: 0.1406296193599701
# Average of peers' local losses: 1.201534
# Mixing took 3.3841
# -> Update reputation
# [0.6100411  0.47365426 0.69171047 0.00258909 0.40268029 0.64524538
#  0.42731767 0.68661462 0.57964436 0.        ]
# Aggregation took 2.0919
#
# Average test loss: 1.0579, Test accuracy: 6191/10000 (61.91%)
#
# Class      - Accuracy
# Plane      - 57.9
# Car        - 83.1
# Bird       - 41.4
# Cat        - 27.9
# Deer       - 64.3
# Dog        - 44.3
# Frog       - 82.8
# Horse      - 62.4
# Ship       - 79.4
# Truck      - 75.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.3664725720882416
# Peer 6  is  honest reputation: 0.5940834879875183
# Peer 15  is  honest reputation: 1.0087621212005615
# Peer 7  is  honest reputation: 0.9343488812446594
# Peer 14  is  honest reputation: 0.15947234630584717
# Peer 16  is  honest reputation: 0.39693719148635864
# Peer 10  is  honest reputation: 0.6238501667976379
# Peer 13  is  honest reputation: 0.16982874274253845
# Peer 18  is  honest reputation: 0.8762264549732208
# Peer 1  is  honest reputation: 0.7094985544681549
# Average of peers' local losses: 1.178485
# Mixing took 3.4541
# -> Update reputation
# [0.60673193 0.01329021 0.         0.65223354 0.85584726 0.41053829
#  0.19826345 0.70326205 0.52484092 0.3135623 ]
# Aggregation took 2.1229
# Average test loss: 1.0695, Test accuracy: 6187/10000 (61.87%)
#
# Class      - Accuracy
# Plane      - 62.9
# Car        - 80.6
# Bird       - 32.1
# Cat        - 35.3
# Deer       - 67.5
# Dog        - 54.7
# Frog       - 81.3
# Horse      - 62.0
# Ship       - 76.8
# Truck      - 65.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.773130863904953
# Peer 8  is  honest reputation: 1.018467664718628
# Peer 4  is  honest reputation: 0.533699631690979
# Peer 15  is  honest reputation: 1.0638585686683655
# Peer 16  is  honest reputation: 0.3910573124885559
# Peer 19  is  honest reputation: 0.6820107400417328
# Peer 9  is  honest reputation: 0.9995176494121552
# Peer 7  is  honest reputation: 0.9693090915679932
# Peer 11  is  honest reputation: 0.82916659116745
# Peer 13  is  honest reputation: 0.20342400670051575
# Average of peers' local losses: 1.146639
# Mixing took 3.3791
# -> Update reputation
# [0.37967367 0.4128146  0.59874963 0.54195976 0.69868045 0.73217499
#  0.69005001 0.67381322 0.16039945 0.01197597]
# Aggregation took 2.0789
#
# Average test loss: 1.0026, Test accuracy: 6416/10000 (64.16%)
#
# Class      - Accuracy
# Plane      - 55.4
# Car        - 82.4
# Bird       - 46.6
# Cat        - 45.3
# Deer       - 64.4
# Dog        - 43.2
# Frog       - 77.2
# Horse      - 64.1
# Ship       - 84.9
# Truck      - 78.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.1195893287658691
# Peer 14  is  honest reputation: 0.15026003122329712
# Peer 18  is  honest reputation: 0.8938660323619843
# Peer 9  is  honest reputation: 1.0509075224399567
# Peer 4  is  honest reputation: 0.625188946723938
# Peer 6  is  honest reputation: 0.6263914704322815
# Peer 13  is  honest reputation: 0.19816622138023376
# Peer 3  is  honest reputation: 1.467744618654251
# Peer 10  is  honest reputation: 0.514624297618866
# Peer 16  is  honest reputation: 0.3479863405227661
# Average of peers' local losses: 1.109518
# Mixing took 2.8296
# -> Update reputation
# [0.42800704 0.06349978 0.85842865 0.         0.02179214 0.70975918
#  0.63120045 0.2577747 ]
# Aggregation took 1.6995
#
# Average test loss: 0.9925, Test accuracy: 6465/10000 (64.65%)
#
# Class      - Accuracy
# Plane      - 65.7
# Car        - 83.5
# Bird       - 47.3
# Cat        - 31.0
# Deer       - 56.2
# Dog        - 57.8
# Frog       - 84.5
# Horse      - 61.1
# Ship       - 84.1
# Truck      - 75.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.793115884065628
# Peer 11  is  honest reputation: 0.8773854374885559
# Peer 10  is  honest reputation: 0.514624297618866
# Peer 8  is  honest reputation: 1.0342409014701843
# Peer 7  is  honest reputation: 1.0038844347000122
# Peer 3  is  honest reputation: 1.5775167047977448
# Peer 15  is  honest reputation: 1.1768737435340881
# Peer 9  is  honest reputation: 1.0335844457149506
# Peer 4  is  honest reputation: 0.7476295232772827
# Peer 5  is  attacker reputation: -0.6118301153182983
# Average of peers' local losses: 1.068860
# Mixing took 2.7085
# -> Update reputation
# [0.         0.49580445 0.68780865 0.59937559 0.48693283 0.74309706
#  0.8726301  0.66779604]
# Aggregation took 1.7326
#
# Average test loss: 0.9923, Test accuracy: 6441/10000 (64.41%)
#
# Class      - Accuracy
# Plane      - 75.0
# Car        - 83.4
# Bird       - 36.0
# Cat        - 42.0
# Deer       - 66.1
# Dog        - 39.4
# Frog       - 77.8
# Horse      - 71.2
# Ship       - 71.1
# Truck      - 82.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.793115884065628
# Peer 3  is  honest reputation: 1.634177178144455
# Peer 19  is  honest reputation: 0.5858679711818695
# Peer 11  is  honest reputation: 0.9823474287986755
# Peer 9  is  honest reputation: 1.133960336446762
# Peer 18  is  honest reputation: 0.8938660323619843
# Peer 13  is  honest reputation: 0.31197091937065125
# Peer 15  is  honest reputation: 1.247535526752472
# Peer 8  is  honest reputation: 1.096929907798767
# Peer 16  is  honest reputation: 0.35376065969467163
# Average of peers' local losses: 1.209437
# Mixing took 3.4641
# -> Update reputation
# [0.90027453 0.80673611 0.019871   0.57168151 0.15046746 0.64067544
#  0.68385764 0.32849141 0.72530946 0.58504903]
# Aggregation took 2.0729
#
# Average test loss: 1.1155, Test accuracy: 6095/10000 (60.95%)
#
# Class      - Accuracy
# Plane      - 55.2
# Car        - 74.3
# Bird       - 44.9
# Cat        - 17.8
# Deer       - 71.5
# Dog        - 42.3
# Frog       - 85.2
# Horse      - 55.1
# Ship       - 86.1
# Truck      - 77.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.8339029550552368
# Peer 1  is  honest reputation: 0.9545145332813263
# Peer 15  is  honest reputation: 1.402019739151001
# Peer 19  is  honest reputation: 0.6255456507205963
# Peer 3  is  honest reputation: 1.7580756843090057
# Peer 14  is  honest reputation: 0.22478854656219482
# Peer 8  is  honest reputation: 1.2031676769256592
# Peer 18  is  honest reputation: 1.0437280237674713
# Peer 10  is  honest reputation: 0.514624297618866
# Peer 9  is  honest reputation: 1.1207344233989716
# Average of peers' local losses: 1.100669
# Mixing took 2.6304
# -> Update reputation
# [0.77719955 0.52866269 0.64433994 0.57259998 0.63577035 0.91205539
#  0.30011497 0.36400878]
# Aggregation took 1.6935
#
# Average test loss: 0.9926, Test accuracy: 6517/10000 (65.17%)
#
# Class      - Accuracy
# Plane      - 64.8
# Car        - 83.2
# Bird       - 47.9
# Cat        - 41.1
# Deer       - 61.0
# Dog        - 44.4
# Frog       - 85.1
# Horse      - 65.7
# Ship       - 83.0
# Truck      - 75.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 1.322668194770813
# Peer 1  is  honest reputation: 0.9357919991016388
# Peer 3  is  honest reputation: 1.8240228593349457
# Peer 18  is  honest reputation: 1.0499688684940338
# Peer 9  is  honest reputation: 1.0354516804218292
# Peer 16  is  honest reputation: 0.3042830228805542
# Peer 6  is  honest reputation: 0.5538985729217529
# Peer 10  is  honest reputation: 0.5940553545951843
# Peer 14  is  honest reputation: 0.22478854656219482
# Peer 12  is  attacker reputation: -0.7608820199966431
# Average of peers' local losses: 1.072323
# Mixing took 2.7995
# -> Update reputation
# [0.91379736 0.77982219 0.         0.40136442 0.63264379 0.
#  0.24511667 0.01823392]
# Aggregation took 1.6785
#
# Average test loss: 1.0693, Test accuracy: 6217/10000 (62.17%)
#
# Class      - Accuracy
# Plane      - 77.9
# Car        - 87.8
# Bird       - 43.5
# Cat        - 28.5
# Deer       - 47.1
# Dog        - 50.6
# Frog       - 70.8
# Horse      - 73.7
# Ship       - 59.3
# Truck      - 82.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.0499688684940338
# Peer 13  is  honest reputation: 0.4360280930995941
# Peer 17  is  honest reputation: 0.5725858509540558
# Peer 6  is  honest reputation: 0.6056060194969177
# Peer 14  is  honest reputation: 0.3006875514984131
# Peer 3  is  honest reputation: 1.905467301607132
# Peer 1  is  honest reputation: 0.7806696593761444
# Peer 9  is  honest reputation: 1.1012073457241058
# Peer 16  is  honest reputation: 0.3736312985420227
# Peer 8  is  honest reputation: 1.4003120064735413
# Average of peers' local losses: 1.341790
# Mixing took 3.3741
# -> Update reputation
# [0.04299579 0.45878482 0.34602717 0.01328725 0.32701148 0.69223505
#  0.75507809 0.         0.90035658 0.64676835]
# Aggregation took 2.0328
#
# Average test loss: 1.2627, Test accuracy: 5683/10000 (56.83%)
#
# Class      - Accuracy
# Plane      - 53.2
# Car        - 64.5
# Bird       - 45.2
# Cat        - 30.4
# Deer       - 72.4
# Dog        - 34.0
# Frog       - 84.4
# Horse      - 47.7
# Ship       - 79.7
# Truck      - 56.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 1.2491080462932587
# Peer 1  is  honest reputation: 0.8926445543766022
# Peer 7  is  honest reputation: 0.8726966977119446
# Peer 18  is  honest reputation: 1.1665965020656586
# Peer 16  is  honest reputation: 0.4398958086967468
# Peer 13  is  honest reputation: 0.4101615250110626
# Peer 15  is  honest reputation: 1.402019739151001
# Peer 11  is  honest reputation: 0.9344265460968018
# Peer 4  is  honest reputation: 0.8222073316574097
# Peer 17  is  honest reputation: 0.7363516986370087
# Average of peers' local losses: 1.162604
# Mixing took 3.342
# -> Update reputation
# [0.56138792 0.7328788  0.45801944 0.48416075 0.01248045 0.30153738
#  0.71107877 0.82158782 0.55798301 0.18506569]
# Aggregation took 2.0869
#
# Average test loss: 1.0116, Test accuracy: 6479/10000 (64.79%)
#
# Class      - Accuracy
# Plane      - 56.0
# Car        - 81.8
# Bird       - 49.6
# Cat        - 29.7
# Deer       - 66.0
# Dog        - 54.4
# Frog       - 84.9
# Horse      - 60.9
# Ship       - 85.7
# Truck      - 78.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.5816756784915924
# Peer 4  is  honest reputation: 0.8892547488212585
# Peer 7  is  honest reputation: 1.0243521928787231
# Peer 17  is  honest reputation: 0.7056625783443451
# Peer 8  is  honest reputation: 1.3815380930900574
# Peer 3  is  honest reputation: 1.870972901582718
# Peer 11  is  honest reputation: 0.9228574633598328
# Peer 19  is  honest reputation: 0.6659086644649506
# Peer 14  is  honest reputation: 0.3570094108581543
# Peer 1  is  honest reputation: 1.0293101966381073
# Average of peers' local losses: 1.083597
# Mixing took 3.3921
# -> Update reputation
# [0.62360561 0.1488874  0.54781508 0.52227433 0.48765713 0.32495852
#  0.80137096 0.91702194 0.40797578 0.        ]
# Aggregation took 2.0659
#
# Average test loss: 0.9864, Test accuracy: 6617/10000 (66.17%)
#
# Class      - Accuracy
# Plane      - 63.0
# Car        - 81.9
# Bird       - 46.2
# Cat        - 42.6
# Deer       - 63.9
# Dog        - 47.1
# Frog       - 85.9
# Horse      - 66.9
# Ship       - 83.8
# Truck      - 80.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.5940553545951843
# Peer 8  is  honest reputation: 1.4948870539665222
# Peer 15  is  honest reputation: 1.5561363697052002
# Peer 2  is  attacker reputation: -0.8268373906612396
# Peer 13  is  honest reputation: 0.5424573123455048
# Peer 4  is  honest reputation: 0.9254367351531982
# Peer 1  is  honest reputation: 0.9719169437885284
# Peer 18  is  honest reputation: 1.3293711245059967
# Peer 6  is  honest reputation: 0.7577969431877136
# Peer 3  is  honest reputation: 1.962430864572525
# Average of peers' local losses: 1.059460
# Mixing took 3.1409
# -> Update reputation
# [0.80400288 0.52328551 0.21677863 0.82720158 0.16006673 0.
#  0.91694813 0.50269365 0.74689896 0.15985988]
# Aggregation took 2.0198
#
# Average test loss: 0.9539, Test accuracy: 6697/10000 (66.97%)
#
# Class      - Accuracy
# Plane      - 56.9
# Car        - 85.4
# Bird       - 54.4
# Cat        - 38.6
# Deer       - 65.4
# Dog        - 56.6
# Frog       - 85.0
# Horse      - 65.1
# Ship       - 83.2
# Truck      - 79.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.8256352841854095
# Peer 7  is  honest reputation: 1.1233384609222412
# Peer 13  is  honest reputation: 0.553697794675827
# Peer 3  is  honest reputation: 1.9619670808315277
# Peer 1  is  honest reputation: 0.9733084142208099
# Peer 11  is  honest reputation: 1.0077090859413147
# Peer 18  is  honest reputation: 1.3583592474460602
# Peer 8  is  honest reputation: 1.5022865533828735
# Peer 15  is  honest reputation: 1.5716624855995178
# Peer 14  is  honest reputation: 0.3490182161331177
# Average of peers' local losses: 1.042042
# Mixing took 3.0658
# -> Update reputation
# [0.81400418 0.73904044 0.20288707 0.00674142 0.61648648 0.89428094
#  0.40726254 0.8069563  0.38504551 0.56078048]
# Aggregation took 2.0699
#
# Average test loss: 0.9374, Test accuracy: 6802/10000 (68.02%)
#
# Class      - Accuracy
# Plane      - 66.6
# Car        - 84.1
# Bird       - 52.7
# Cat        - 33.5
# Deer       - 64.0
# Dog        - 62.6
# Frog       - 87.0
# Horse      - 64.9
# Ship       - 84.5
# Truck      - 80.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.9453590512275696
# Peer 18  is  honest reputation: 1.375520020723343
# Peer 3  is  honest reputation: 1.8700630366802216
# Peer 7  is  honest reputation: 1.1464760303497314
# Peer 17  is  honest reputation: 0.7296360433101654
# Peer 13  is  honest reputation: 0.6329000890254974
# Peer 8  is  honest reputation: 1.5453996062278748
# Peer 15  is  honest reputation: 1.5659422278404236
# Peer 19  is  honest reputation: 0.859483391046524
# Peer 16  is  honest reputation: 0.4069337844848633
# Average of peers' local losses: 0.977044
# Mixing took 2.4462
# -> Update reputation
# [0.7411732  0.60763889 0.90714785 0.84360114 0.38029199 0.34032298
#  0.42938412 0.55165561]
# Aggregation took 1.6395
#
# Average test loss: 0.9076, Test accuracy: 6856/10000 (68.56%)
#
# Class      - Accuracy
# Plane      - 68.2
# Car        - 86.4
# Bird       - 46.4
# Cat        - 47.4
# Deer       - 73.2
# Dog        - 56.0
# Frog       - 81.6
# Horse      - 63.6
# Ship       - 82.3
# Truck      - 80.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.7816161215305328
# Peer 8  is  honest reputation: 1.6606916189193726
# Peer 19  is  honest reputation: 0.8275593221187592
# Peer 16  is  honest reputation: 0.4069337844848633
# Peer 15  is  honest reputation: 1.5659422278404236
# Peer 3  is  honest reputation: 1.9383362233638763
# Peer 18  is  honest reputation: 1.3802359998226166
# Peer 6  is  honest reputation: 0.5539100766181946
# Peer 1  is  honest reputation: 0.8331283628940582
# Peer 14  is  honest reputation: 0.4338998794555664
# Average of peers' local losses: 0.979018
# Mixing took 3.0568
# -> Update reputation
# [0.02647517 0.02035238 0.22052364 0.77165764 0.70218869 0.33270153
#  0.83050699 0.3919951  0.         0.89346916]
# Aggregation took 1.9998
#
# Average test loss: 0.9033, Test accuracy: 6858/10000 (68.58%)
#
# Class      - Accuracy
# Plane      - 68.5
# Car        - 83.7
# Bird       - 52.4
# Cat        - 46.8
# Deer       - 70.7
# Dog        - 44.9
# Frog       - 84.0
# Horse      - 68.1
# Ship       - 84.3
# Truck      - 82.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.5492106676101685
# Peer 18  is  honest reputation: 1.3943343460559845
# Peer 8  is  honest reputation: 1.712497591972351
# Peer 7  is  honest reputation: 1.1323279738426208
# Peer 16  is  honest reputation: 0.46166372299194336
# Peer 17  is  honest reputation: 0.8862996995449066
# Peer 15  is  honest reputation: 1.5471417307853699
# Peer 19  is  honest reputation: 0.9368844926357269
# Peer 3  is  honest reputation: 1.9615950286388397
# Peer 9  is  honest reputation: 1.2838152945041656
# Average of peers' local losses: 0.941565
# Mixing took 1.8427
# -> Update reputation
# [0.11986427 0.83886301 0.57718526 0.82540922 0.88622795 0.46788893]
# Aggregation took 1.2832
#
# Average test loss: 0.9064, Test accuracy: 6869/10000 (68.69%)
#
# Class      - Accuracy
# Plane      - 65.7
# Car        - 82.3
# Bird       - 56.1
# Cat        - 39.9
# Deer       - 64.9
# Dog        - 57.3
# Frog       - 86.4
# Horse      - 65.8
# Ship       - 88.0
# Truck      - 80.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 1.2838152945041656
# Peer 1  is  honest reputation: 0.7469357550144196
# Peer 15  is  honest reputation: 1.7400532364845276
# Peer 19  is  honest reputation: 0.9368844926357269
# Peer 3  is  honest reputation: 1.926798015832901
# Peer 13  is  honest reputation: 0.8685922920703888
# Peer 4  is  honest reputation: 1.0479164123535156
# Peer 7  is  honest reputation: 1.180960774421692
# Peer 16  is  honest reputation: 0.46166372299194336
# Peer 8  is  honest reputation: 1.6962866187095642
# Average of peers' local losses: 0.933071
# Mixing took 2.4232
# -> Update reputation
# [0.61984201 0.87944858 0.81588363 0.5382872  0.56571515 0.2083926
#  0.2865369  0.00655536]
# Aggregation took 1.6255
#
# Average test loss: 0.8954, Test accuracy: 6936/10000 (69.36%)
#
# Class      - Accuracy
# Plane      - 61.7
# Car        - 82.2
# Bird       - 50.0
# Cat        - 45.2
# Deer       - 67.7
# Dog        - 55.9
# Frog       - 88.7
# Horse      - 66.8
# Ship       - 88.5
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 1.203949511051178
# Peer 11  is  honest reputation: 1.0611293315887451
# Peer 16  is  honest reputation: 0.5693063139915466
# Peer 19  is  honest reputation: 0.9368844926357269
# Peer 15  is  honest reputation: 1.936079502105713
# Peer 7  is  honest reputation: 1.1644917726516724
# Peer 6  is  honest reputation: 0.6431726217269897
# Peer 3  is  honest reputation: 1.926798015832901
# Peer 17  is  honest reputation: 1.0300934612751007
# Peer 14  is  honest reputation: 0.5430845022201538
# Average of peers' local losses: 0.930631
# Mixing took 2.5293
# -> Update reputation
# [0.4711437  0.84329211 0.37429396 0.48988165 0.06321363 0.
#  0.61134709 0.03042591]
# Aggregation took 1.6195
#
# Average test loss: 0.8678, Test accuracy: 7021/10000 (70.21%)
#
# Class      - Accuracy
# Plane      - 68.9
# Car        - 84.4
# Bird       - 57.3
# Cat        - 48.1
# Deer       - 59.3
# Dog        - 56.8
# Frog       - 87.3
# Horse      - 68.1
# Ship       - 86.8
# Truck      - 85.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.936079502105713
# Peer 18  is  honest reputation: 1.3943343460559845
# Peer 11  is  honest reputation: 1.0611293315887451
# Peer 3  is  honest reputation: 1.8382644951343536
# Peer 4  is  honest reputation: 1.3168715834617615
# Peer 6  is  honest reputation: 0.6691000461578369
# Peer 9  is  honest reputation: 1.287499338388443
# Peer 17  is  honest reputation: 1.1417066156864166
# Peer 13  is  honest reputation: 0.8575401604175568
# Peer 10  is  honest reputation: 0.6127282977104187
# Average of peers' local losses: 0.885399
# Mixing took 2.5593
# -> Update reputation
# [0.69362652 0.41191518 0.12441014 0.86963677 0.64613696 0.86523426
#  0.59006614 0.52715793]
# Aggregation took 1.7536
#
# Average test loss: 0.8656, Test accuracy: 7093/10000 (70.93%)
#
# Class      - Accuracy
# Plane      - 71.3
# Car        - 87.0
# Bird       - 52.0
# Cat        - 43.0
# Deer       - 71.9
# Dog        - 58.3
# Frog       - 88.1
# Horse      - 70.4
# Ship       - 84.6
# Truck      - 82.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.7742412388324738
# Peer 9  is  honest reputation: 1.2835695445537567
# Peer 16  is  honest reputation: 0.5850231647491455
# Peer 19  is  honest reputation: 0.9992093741893768
# Peer 17  is  honest reputation: 1.1920031607151031
# Peer 13  is  honest reputation: 1.0437175929546356
# Peer 18  is  honest reputation: 1.3744403421878815
# Peer 15  is  honest reputation: 1.9373894333839417
# Peer 8  is  honest reputation: 1.7071306109428406
# Peer 14  is  honest reputation: 0.6362373232841492
# Average of peers' local losses: 0.898061
# Mixing took 1.9808
# -> Update reputation
# [0.44211718 0.01857846 0.30462161 0.81915789 0.03836606 0.51677724]
# Aggregation took 1.3362
#
# Average test loss: 0.8760, Test accuracy: 7035/10000 (70.35%)
#
# Class      - Accuracy
# Plane      - 62.2
# Car        - 84.2
# Bird       - 59.7
# Cat        - 56.4
# Deer       - 75.6
# Dog        - 49.4
# Frog       - 78.9
# Horse      - 66.8
# Ship       - 88.8
# Truck      - 81.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.3744403421878815
# Peer 19  is  honest reputation: 0.9830761849880219
# Peer 13  is  honest reputation: 1.1433294117450714
# Peer 17  is  honest reputation: 1.2404027879238129
# Peer 15  is  honest reputation: 1.8227224349975586
# Peer 6  is  honest reputation: 0.7308600544929504
# Peer 4  is  honest reputation: 1.460713267326355
# Peer 1  is  honest reputation: 0.7742412388324738
# Peer 7  is  honest reputation: 1.1173413395881653
# Peer 9  is  honest reputation: 1.2835695445537567
# Average of peers' local losses: 0.862527
# Mixing took 3.2409
# -> Update reputation
# [0.48449403 0.30819815 0.52360667 0.72326873 0.06099842 0.83480966
#  0.58864152 0.45366789 0.20505768 0.6374955 ]
# Aggregation took 2.0619
#
# Average test loss: 0.8177, Test accuracy: 7221/10000 (72.21%)
#
# Class      - Accuracy
# Plane      - 67.7
# Car        - 87.2
# Bird       - 61.0
# Cat        - 48.0
# Deer       - 74.4
# Dog        - 58.2
# Frog       - 86.4
# Horse      - 70.6
# Ship       - 87.0
# Truck      - 81.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.6870507001876831
# Peer 7  is  honest reputation: 1.2497659921646118
# Peer 14  is  honest reputation: 0.7068549990653992
# Peer 19  is  honest reputation: 0.9870233237743378
# Peer 15  is  honest reputation: 1.8722689151763916
# Peer 1  is  honest reputation: 0.8764766752719879
# Peer 13  is  honest reputation: 1.157779186964035
# Peer 9  is  honest reputation: 1.4224132597446442
# Peer 8  is  honest reputation: 1.7071306109428406
# Peer 4  is  honest reputation: 1.5829357504844666
# Average of peers' local losses: 0.833837
# Mixing took 3.1829
# -> Update reputation
# [0.21835665 0.72518433 0.63883979 0.0232031  0.09693725 0.59282483
#  0.51173538 0.83175732 0.22708394 0.76394007]
# Aggregation took 2.217
#
# Average test loss: 0.8027, Test accuracy: 7275/10000 (72.75%)
#
# Class      - Accuracy
# Plane      - 68.7
# Car        - 85.2
# Bird       - 56.7
# Cat        - 46.7
# Deer       - 77.2
# Dog        - 65.3
# Frog       - 84.3
# Horse      - 73.0
# Ship       - 86.7
# Truck      - 83.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.3440548479557037
# Peer 8  is  honest reputation: 1.6879598498344421
# Peer 9  is  honest reputation: 1.4385611712932587
# Peer 10  is  honest reputation: 0.6127282977104187
# Peer 13  is  honest reputation: 1.2474280893802643
# Peer 4  is  honest reputation: 1.600844383239746
# Peer 15  is  honest reputation: 1.8761618733406067
# Peer 1  is  honest reputation: 0.9042799174785614
# Peer 3  is  honest reputation: 1.9196039736270905
# Peer 7  is  honest reputation: 1.364360511302948
# Average of peers' local losses: 0.784073
# Mixing took 2.5163
# -> Update reputation
# [0.57044228 0.64183509 0.76601894 0.44474717 0.87089502 0.19369592
#  0.         0.76742539]
# Aggregation took 1.7626
#
# Average test loss: 0.8084, Test accuracy: 7255/10000 (72.55%)
#
# Class      - Accuracy
# Plane      - 73.2
# Car        - 87.1
# Bird       - 48.9
# Cat        - 53.1
# Deer       - 73.1
# Dog        - 58.3
# Frog       - 87.9
# Horse      - 71.5
# Ship       - 85.5
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 1.8761618733406067
# ...
# Peer 19  is  honest reputation: 2.1955101788043976
# Peer 3  is  honest reputation: 3.5878345668315887
# Peer 18  is  honest reputation: 2.1598967015743256
# Peer 4  is  honest reputation: 3.3503528237342834
# Peer 9  is  honest reputation: 3.0566838681697845
# Peer 8  is  honest reputation: 2.586876630783081
# Average of peers' local losses: 0.383654
# Mixing took 2.3551
# -> Update reputation
# [0.91990352 0.10629422 0.94887258 0.93556384 0.91983818 0.99258226
#  0.98894272 0.71243499]
# Aggregation took 1.7055
#
# Average test loss: 0.7764, Test accuracy: 7743/10000 (77.43%)
#
# Class      - Accuracy
# Plane      - 79.7
# Car        - 87.8
# Bird       - 63.0
# Cat        - 55.5
# Deer       - 82.7
# Dog        - 65.1
# Frog       - 87.3
# Horse      - 77.7
# Ship       - 88.7
# Truck      - 86.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 89/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.5878345668315887
# Peer 8  is  honest reputation: 2.55297315120697
# Peer 16  is  honest reputation: 2.4338698983192444
# Peer 18  is  honest reputation: 2.320604830980301
# Peer 9  is  honest reputation: 3.0566838681697845
# Peer 17  is  honest reputation: 3.3287653028964996
# Peer 15  is  honest reputation: 2.7150042057037354
# Peer 7  is  honest reputation: 1.5761908292770386
# Peer 6  is  honest reputation: 1.6247417330741882
# Peer 4  is  honest reputation: 3.529286503791809
# Average of peers' local losses: 0.404386
# Mixing took 2.7765
# -> Update reputation
# [0.93629514 0.91955561 0.68324937 0.71513221 0.98540211 0.99147787
#  0.99382082 0.94009341 0.99345499 0.9679195 ]
# Aggregation took 1.9828
#
# Average test loss: 0.7535, Test accuracy: 7733/10000 (77.33%)
#
# Class      - Accuracy
# Plane      - 77.8
# Car        - 89.0
# Bird       - 66.1
# Cat        - 52.2
# Deer       - 79.1
# Dog        - 67.6
# Frog       - 89.4
# Horse      - 77.7
# Ship       - 86.7
# Truck      - 87.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 90/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 2.4714828729629517
# Peer 9  is  honest reputation: 3.188980132341385
# Peer 15  is  honest reputation: 2.790872275829315
# Peer 16  is  honest reputation: 2.4397658109664917
# Peer 17  is  honest reputation: 3.4596135318279266
# Peer 11  is  honest reputation: 3.0875901579856873
# Peer 7  is  honest reputation: 1.5678136944770813
# Peer 13  is  honest reputation: 0.8393276929855347
# Peer 19  is  honest reputation: 2.3210295736789703
# Peer 4  is  honest reputation: 3.592091202735901
# Average of peers' local losses: 0.345960
# Mixing took 2.247
# -> Update reputation
# [0.98896836 0.71153824 0.92763183 0.0882943  0.99503058 0.94688316
#  0.98837105 0.99361153]
# Aggregation took 1.6125
#
# Average test loss: 0.8150, Test accuracy: 7747/10000 (77.47%)
#
# Class      - Accuracy
# Plane      - 81.2
# Car        - 88.9
# Bird       - 63.1
# Cat        - 54.3
# Deer       - 74.1
# Dog        - 68.5
# Frog       - 87.5
# Horse      - 81.0
# Ship       - 87.5
# Truck      - 88.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 91/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 3.6756691932678223
# Peer 6  is  honest reputation: 1.630240559577942
# Peer 3  is  honest reputation: 3.620941311120987
# Peer 15  is  honest reputation: 2.790872275829315
# Peer 9  is  honest reputation: 3.2754149734973907
# Peer 17  is  honest reputation: 3.5497171580791473
# Peer 11  is  honest reputation: 3.248899757862091
# Peer 8  is  honest reputation: 2.478858530521393
# Peer 10  is  honest reputation: 1.2318816184997559
# Peer 1  is  honest reputation: 1.4798361361026764
# Average of peers' local losses: 0.414138
# Mixing took 2.7695
# -> Update reputation
# [0.99451957 0.96797334 0.99043198 0.99105883 0.99209302 0.78652281
#  0.94668775 0.68989312 0.99529492 0.55016163]
# Aggregation took 1.9748
#
# Average test loss: 0.7418, Test accuracy: 7795/10000 (77.95%)
#
# Class      - Accuracy
# Plane      - 77.6
# Car        - 88.8
# Bird       - 60.9
# Cat        - 56.0
# Deer       - 80.0
# Dog        - 69.1
# Frog       - 89.6
# Horse      - 83.1
# Ship       - 88.2
# Truck      - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 92/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 3.70306533575058
# Peer 8  is  honest reputation: 2.476972281932831
# Peer 15  is  honest reputation: 2.7372084856033325
# Peer 9  is  honest reputation: 3.3809904754161835
# Peer 11  is  honest reputation: 3.3469534516334534
# Peer 1  is  honest reputation: 1.5258648097515106
# Peer 7  is  honest reputation: 1.5684056878089905
# Peer 16  is  honest reputation: 2.4397658109664917
# Peer 18  is  honest reputation: 2.318771868944168
# Peer 6  is  honest reputation: 1.7403612732887268
# Average of peers' local losses: 0.349095
# Mixing took 1.6695
# -> Update reputation
# [0.9711771  0.93209109 0.94373075 0.93160983 0.70997868 0.99154164]
# Aggregation took 1.1851
#
# Average test loss: 0.7732, Test accuracy: 7768/10000 (77.68%)
#
# Class      - Accuracy
# Plane      - 77.2
# Car        - 89.8
# Bird       - 63.0
# Cat        - 52.7
# Deer       - 79.0
# Dog        - 70.7
# Frog       - 87.5
# Horse      - 83.1
# Ship       - 89.3
# Truck      - 84.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 93/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 3.3469534516334534
# Peer 16  is  honest reputation: 2.449221134185791
# Peer 10  is  honest reputation: 1.296726107597351
# Peer 18  is  honest reputation: 2.352208524942398
# Peer 7  is  honest reputation: 1.5652539134025574
# Peer 9  is  honest reputation: 3.4088678061962128
# Peer 3  is  honest reputation: 3.626600056886673
# Peer 17  is  honest reputation: 3.442710727453232
# Peer 14  is  honest reputation: 0.4125385880470276
# Peer 19  is  honest reputation: 2.319253534078598
# Average of peers' local losses: 0.454181
# Mixing took 2.7805
# -> Update reputation
# [0.         0.94312942 0.990609   0.61420526 0.94112518 0.99265704
#  0.93785732 0.99541397 0.9929798  0.76398416]
# Aggregation took 1.9748
#
# Average test loss: 0.7243, Test accuracy: 7787/10000 (77.87%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 89.4
# Bird       - 63.0
# Cat        - 55.4
# Deer       - 77.9
# Dog        - 71.3
# Frog       - 89.0
# Horse      - 77.1
# Ship       - 88.8
# Truck      - 87.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 94/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 2.418555825948715
# Peer 8  is  honest reputation: 2.3485530018806458
# Peer 3  is  honest reputation: 3.708546668291092
# Peer 4  is  honest reputation: 3.70306533575058
# Peer 13  is  honest reputation: 0.7666378617286682
# Peer 17  is  honest reputation: 3.3489732444286346
# Peer 11  is  honest reputation: 3.472491979598999
# Peer 18  is  honest reputation: 2.3907035887241364
# Peer 16  is  honest reputation: 2.436389446258545
# Peer 14  is  honest reputation: 0.3830905556678772
# Average of peers' local losses: 0.327346
# Mixing took 2.234
# -> Update reputation
# [0.99271514 0.9912484  0.94719549 0.         0.95556239 0.99601358
#  0.99590092 0.09051277]
# Aggregation took 1.6035
#
# Average test loss: 0.8047, Test accuracy: 7703/10000 (77.03%)
#
# Class      - Accuracy
# Plane      - 82.9
# Car        - 89.7
# Bird       - 65.5
# Cat        - 57.4
# Deer       - 79.0
# Dog        - 58.9
# Frog       - 87.0
# Horse      - 78.3
# Ship       - 87.9
# Truck      - 83.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 95/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 2.5503951609134674
# Peer 18  is  honest reputation: 2.4619960486888885
# Peer 4  is  honest reputation: 3.752266228199005
# Peer 7  is  honest reputation: 1.676466703414917
# Peer 13  is  honest reputation: 0.748982846736908
# Peer 3  is  honest reputation: 3.766228884458542
# Peer 14  is  honest reputation: 0.3859381675720215
# Peer 17  is  honest reputation: 3.3718616664409637
# Peer 9  is  honest reputation: 3.4950479567050934
# Peer 6  is  honest reputation: 1.7403612732887268
# Average of peers' local losses: 0.387207
# Mixing took 2.7865
# -> Update reputation
# [0.96609127 0.99679949 0.95497344 0.81570272 0.         0.99638132
#  0.772993   0.07522962 0.98958523 0.99345895]
# Aggregation took 2.0118
#
# Average test loss: 0.7924, Test accuracy: 7793/10000 (77.93%)
#
# Class      - Accuracy
# Plane      - 75.1
# Car        - 89.3
# Bird       - 64.0
# Cat        - 55.6
# Deer       - 80.9
# Dog        - 67.9
# Frog       - 90.5
# Horse      - 82.3
# Ship       - 87.7
# Truck      - 86.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 96/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.8633753955364227
# Peer 4  is  honest reputation: 3.801871418952942
# Peer 1  is  honest reputation: 1.5258648097515106
# Peer 19  is  honest reputation: 2.6754447519779205
# Peer 8  is  honest reputation: 2.3485530018806458
# Peer 10  is  honest reputation: 1.3863973021507263
# Peer 14  is  honest reputation: 0.4192636013031006
# Peer 11  is  honest reputation: 3.463949203491211
# Peer 16  is  honest reputation: 2.436389446258545
# Peer 9  is  honest reputation: 3.5051439106464386
# Average of peers' local losses: 0.354399
# Mixing took 2.2591
# -> Update reputation
# [0.94961631 0.71561356 0.97690275 0.95697781 0.99306653 0.9966052
#  0.62983998 0.        ]
# Aggregation took 1.6105
#
# Average test loss: 0.7741, Test accuracy: 7822/10000 (78.22%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 88.5
# Bird       - 69.0
# Cat        - 57.0
# Deer       - 79.1
# Dog        - 69.6
# Frog       - 86.9
# Horse      - 77.9
# Ship       - 86.4
# Truck      - 89.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 97/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 2.473182737827301
# Peer 4  is  honest reputation: 3.801871418952942
# Peer 14  is  honest reputation: 0.4190351366996765
# Peer 17  is  honest reputation: 3.2716077864170074
# Peer 6  is  honest reputation: 1.789218544960022
# Peer 18  is  honest reputation: 2.53081938624382
# Peer 8  is  honest reputation: 2.554042875766754
# Peer 3  is  honest reputation: 3.8338012993335724
# Peer 10  is  honest reputation: 1.3864734172821045
# Peer 19  is  honest reputation: 2.870109111070633
# Average of peers' local losses: 0.348970
# Mixing took 2.215
# -> Update reputation
# [0.82121499 0.9493967  0.         0.99695914 0.97622071 0.99593121
#  0.95694848 0.65920337]
# Aggregation took 1.6095
#
# Average test loss: 0.7962, Test accuracy: 7809/10000 (78.09%)
#
# Class      - Accuracy
# Plane      - 75.2
# Car        - 89.7
# Bird       - 69.3
# Cat        - 52.3
# Deer       - 83.3
# Dog        - 65.7
# Frog       - 87.5
# Horse      - 83.9
# Ship       - 86.7
# Truck      - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 98/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 3.5051439106464386
# Peer 17  is  honest reputation: 3.2716077864170074
# Peer 1  is  honest reputation: 1.5439185798168182
# Peer 16  is  honest reputation: 2.476305842399597
# Peer 6  is  honest reputation: 1.8112142086029053
# Peer 11  is  honest reputation: 3.475857436656952
# Peer 8  is  honest reputation: 2.5590487122535706
# Peer 19  is  honest reputation: 2.8607398569583893
# Peer 7  is  honest reputation: 1.6731014251708984
# Peer 18  is  honest reputation: 2.53081938624382
# Average of peers' local losses: 0.321251
# Mixing took 2.8686
# -> Update reputation
# [0.96041235 0.95799284 0.99317511 0.9466783  0.99062416 0.72101714
#  0.81976913 0.76899302 0.9943113  0.97795829]
# Aggregation took 1.9878
#
# Average test loss: 0.7359, Test accuracy: 7828/10000 (78.28%)
#
# Class      - Accuracy
# Plane      - 79.1
# Car        - 90.3
# Bird       - 63.6
# Cat        - 56.4
# Deer       - 78.6
# Dog        - 69.9
# Frog       - 90.0
# Horse      - 80.4
# Ship       - 87.6
# Truck      - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 99/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.44045156240463257
# Peer 7  is  honest reputation: 1.668535590171814
# Peer 18  is  honest reputation: 2.601873129606247
# Peer 9  is  honest reputation: 3.5804629027843475
# Peer 6  is  honest reputation: 1.8067898154258728
# Peer 17  is  honest reputation: 3.329710215330124
# Peer 8  is  honest reputation: 2.449444890022278
# Peer 16  is  honest reputation: 2.5715941786766052
# Peer 4  is  honest reputation: 3.8942965269088745
# Peer 15  is  honest reputation: 2.79072105884552
# Average of peers' local losses: 0.300690
# Mixing took 2.2631
# -> Update reputation
# [0.97135243 0.99771524 0.         0.99470174 0.96348523 0.81894979
#  0.99182955 0.95395194]
# Aggregation took 1.6155
#
# Average test loss: 0.8193, Test accuracy: 7824/10000 (78.24%)
#
# Class      - Accuracy
# Plane      - 82.1
# Car        - 88.5
# Bird       - 68.8
# Cat        - 58.3
# Deer       - 77.3
# Dog        - 68.3
# Frog       - 87.0
# Horse      - 77.3
# Ship       - 89.2
# Truck      - 85.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 100/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 2.740266114473343
# Peer 6  is  honest reputation: 1.7781829237937927
# Peer 19  is  honest reputation: 2.8991185128688812
# Peer 1  is  honest reputation: 1.560436874628067
# Peer 3  is  honest reputation: 3.7484362423419952
# Peer 9  is  honest reputation: 3.5899985134601593
# Peer 13  is  honest reputation: 0.7207517027854919
# Peer 14  is  honest reputation: 0.33599621057510376
# Peer 11  is  honest reputation: 3.4891305565834045
# Peer 4  is  honest reputation: 4.011311948299408
# Average of peers' local losses: 0.331663
# Mixing took 2.3031
# -> Update reputation
# [0.         0.98562895 0.99546238 0.97879463 0.99827509 0.10742566
#  0.83239149 0.99706062]
# Aggregation took 1.6135
#
# Average test loss: 0.8329, Test accuracy: 7867/10000 (78.67%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 89.4
# Bird       - 67.4
# Cat        - 61.3
# Deer       - 78.8
# Dog        - 66.2
# Frog       - 85.0
# Horse      - 82.8
# Ship       - 87.9
# Truck      - 88.6
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.7539, Test accuracy: 7896/10000 (78.96%)
#
# ***********************************************************************************
# Class      - Accuracy
# Plane      - 79.6
# Car        - 89.7
# Bird       - 66.8
# Cat        - 58.1
# Deer       - 80.2
# Dog        - 68.7
# Frog       - 88.7
# Horse      - 82.3
# Ship       - 88.3
# Truck      - 87.2
# Global accuracies:  [12.75, 19.17, 19.44, 30.0, 32.69, 36.22, 38.94, 42.79, 41.49, 46.53, 46.58, 49.65, 50.54, 50.29, 53.87, 55.33, 55.82, 56.91, 56.94, 55.02, 59.47, 58.13, 60.56, 61.91, 61.87, 64.16, 64.65, 64.41, 60.95, 65.17, 62.17, 56.83, 64.79, 66.17, 66.97, 68.02, 68.56, 68.58, 68.69, 69.36, 70.21, 70.93, 70.35, 72.21, 72.75, 72.55, 73.53, 55.88, 13.91, 67.79, 68.48, 70.47, 69.96, 71.24, 72.54, 72.94, 73.16, 72.18, 41.95, 70.05, 71.3, 71.26, 73.16, 73.09, 72.84, 73.41, 73.81, 74.13, 74.31, 75.45, 75.65, 75.89, 75.87, 75.74, 76.05, 76.49, 75.88, 75.53, 76.91, 76.67, 77.21, 76.73, 76.97, 77.59, 77.14, 77.5, 77.65, 77.43, 77.33, 77.47, 77.95, 77.68, 77.87, 77.03, 77.93, 78.22, 78.09, 78.28, 78.24, 78.67, 78.96]
# Class 5 accuracies:  [0.0, 0.0, 6.0, 17.6, 31.8, 36.5, 39.0, 40.0, 43.5, 44.7, 20.7, 48.8, 48.1, 52.9, 48.4, 34.5, 47.8, 40.1, 60.9, 27.8, 45.2, 37.5, 57.7, 44.3, 54.7, 43.2, 57.8, 39.4, 42.3, 44.4, 50.6, 34.0, 54.4, 47.1, 56.6, 62.6, 56.0, 44.9, 57.3, 55.9, 56.8, 58.3, 49.4, 58.2, 65.3, 58.3, 58.6, 60.3, 0.0, 65.7, 51.5, 53.2, 51.0, 57.2, 64.3, 54.9, 65.1, 61.7, 9.6, 53.2, 58.1, 57.2, 60.2, 61.3, 50.0, 60.5, 59.2, 62.5, 62.7, 62.2, 66.5, 67.7, 65.1, 66.9, 66.8, 66.3, 63.2, 62.7, 64.9, 65.9, 70.1, 67.8, 67.3, 70.6, 61.4, 65.8, 63.1, 65.1, 67.6, 68.5, 69.1, 70.7, 71.3, 58.9, 67.9, 69.6, 65.7, 69.9, 68.3, 66.2, 68.7]
# Test loss: [2.2832, 2.1401, 2.0535, 1.8527, 1.7749, 1.7107, 1.635, 1.4979, 1.5258, 1.4635, 1.4327, 1.3704, 1.369, 1.3687, 1.2676, 1.2223, 1.2111, 1.1768, 1.1986, 1.2289, 1.1313, 1.1771, 1.1089, 1.0579, 1.0695, 1.0026, 0.9925, 0.9923, 1.1155, 0.9926, 1.0693, 1.2627, 1.0116, 0.9864, 0.9539, 0.9374, 0.9076, 0.9033, 0.9064, 0.8954, 0.8678, 0.8656, 0.876, 0.8177, 0.8027, 0.8084, 0.8038, 1.3598, 2.3572, 0.9401, 0.9232, 0.8786, 0.8956, 0.8473, 0.8208, 0.811, 0.8074, 0.8246, 1.7415, 0.8908, 0.8613, 0.8563, 0.8166, 0.8091, 0.8264, 0.8049, 0.7999, 0.7886, 0.791, 0.7489, 0.7502, 0.7558, 0.7343, 0.7327, 0.7461, 0.7251, 0.7665, 0.7736, 0.7158, 0.7412, 0.7175, 0.7632, 0.7421, 0.7429, 0.709, 0.7654, 0.7229, 0.7764, 0.7535, 0.815, 0.7418, 0.7732, 0.7243, 0.8047, 0.7924, 0.7741, 0.7962, 0.7359, 0.8193, 0.8329, 0.7539]
# Label-flipping attack succes rate: 13.5
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 2.007
#
# --> End of Experiment.

# %%
RULE = 'ffl'
ATTACK_TYPE='gaussian_noise'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating VGG16 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: gaussian_noise
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s2
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.278925
# Mixing took 2.7775
# -> Update reputation
# Aggregation took 2.8936
#
# Average test loss: 2.2858, Test accuracy: 1279/10000 (12.79%)
#
# Class      - Accuracy
# Plane      - 12.4
# Car        - 8.5
# Bird       - 0.0
# Cat        - 0.0
# Deer       - 96.8
# Dog        - 0.0
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 6.6
# Truck      - 3.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: -0.00030809640884399414
# Peer 4  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.0
# Peer 5  is  attacker reputation: 0.0
# Peer 13  is  honest reputation: -0.29497116804122925
# Peer 2  is  attacker reputation: -0.3780009150505066
# Peer 15  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0009243488311767578
# Peer 17  is  honest reputation: 0.08135318756103516
# Peer 11  is  honest reputation: 0.0
# Average of peers' local losses: 2.171076
# Mixing took 2.7945
# -> Update reputation
# Aggregation took 3.0207
#
# Average test loss: 2.1993, Test accuracy: 1676/10000 (16.76%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 31.3
# Bird       - 2.9
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 89.0
# Frog       - 0.0
# Horse      - 0.5
# Ship       - 0.0
# Truck      - 43.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/100 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 0.05937010049819946
# Peer 4  is  honest reputation: -0.00015529990196228027
# Peer 0  is  attacker reputation: 0.0
# Peer 12  is  attacker reputation: 0.07619622349739075
# Peer 17  is  honest reputation: 0.07949218153953552
# Peer 8  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0802619457244873
# Peer 19  is  honest reputation: -0.0026207566261291504
# Peer 5  is  attacker reputation: 0.07560887932777405
# Peer 9  is  honest reputation: 0.0
# Average of peers' local losses: 2.092386
# Mixing took 2.8015
# -> Update reputation
# Aggregation took 3.0227
#
# Average test loss: 2.2062, Test accuracy: 1303/10000 (13.03%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 19.1
# Bird       - 0.5
# Cat        - 24.6
# Deer       - 0.0
# Dog        - 79.7
# Frog       - 0.0
# Horse      - 3.4
# Ship       - 3.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/100 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: -0.044514626264572144
# Peer 18  is  honest reputation: 0.0707806944847107
# Peer 15  is  honest reputation: 0.0004658699035644531
# Peer 2  is  attacker reputation: -0.30260321497917175
# Peer 17  is  honest reputation: 0.34304144978523254
# Peer 9  is  honest reputation: 0.2634434103965759
# Peer 14  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.252336710691452
# Peer 8  is  honest reputation: -0.0005292296409606934
# Average of peers' local losses: 2.013272
# Mixing took 2.8025
# -> Update reputation
# Aggregation took 3.0167
#
# Average test loss: 2.1907, Test accuracy: 1477/10000 (14.77%)
#
# Class      - Accuracy
# Plane      - 13.1
# Car        - 1.6
# Bird       - 9.1
# Cat        - 0.0
# Deer       - 0.4
# Dog        - 0.0
# Frog       - 98.4
# Horse      - 0.0
# Ship       - 24.8
# Truck      - 0.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.000506967306137085
# Peer 0  is  attacker reputation: 0.0891837477684021
# Peer 19  is  honest reputation: 0.2630839943885803
# Peer 2  is  attacker reputation: -0.6391778290271759
# Peer 18  is  honest reputation: 0.0874367356300354
# Peer 7  is  honest reputation: 0.08004119992256165
# Peer 13  is  honest reputation: -0.023027271032333374
# Peer 5  is  attacker reputation: 0.1645643413066864
# Peer 10  is  honest reputation: 0.007112264633178711
# Peer 3  is  honest reputation: 0.27077171206474304
# Average of peers' local losses: 1.946042
# Mixing took 2.7875
# -> Update reputation
# Aggregation took 3.0137
#
# Average test loss: 1.9163, Test accuracy: 2725/10000 (27.25%)
#
# Class      - Accuracy
# Plane      - 14.5
# Car        - 75.7
# Bird       - 3.3
# Cat        - 6.3
# Deer       - 71.7
# Dog        - 27.2
# Frog       - 5.4
# Horse      - 38.8
# Ship       - 29.4
# Truck      - 0.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.27126121520996094
# Peer 17  is  honest reputation: 0.34067073464393616
# Peer 19  is  honest reputation: 0.26109883189201355
# Peer 9  is  honest reputation: 0.27820098400115967
# Peer 3  is  honest reputation: 0.5367731750011444
# Peer 12  is  attacker reputation: 0.16528132557868958
# Peer 14  is  honest reputation: -0.2533479332923889
# Peer 1  is  honest reputation: 0.07896506786346436
# Peer 18  is  honest reputation: 0.08783984184265137
# Peer 0  is  attacker reputation: 0.18093442916870117
# Average of peers' local losses: 1.922471
# Mixing took 2.7835
# -> Update reputation
# Aggregation took 3.0197
#
# Average test loss: 2.3083, Test accuracy: 1291/10000 (12.91%)
#
# Class      - Accuracy
# Plane      - 9.6
# Car        - 0.3
# Bird       - 2.9
# Cat        - 0.0
# Deer       - 5.4
# Dog        - 0.0
# Frog       - 98.4
# Horse      - 0.0
# Ship       - 5.7
# Truck      - 6.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.08418405055999756
# Peer 4  is  honest reputation: 0.2675454318523407
# Peer 18  is  honest reputation: 0.2736714482307434
# Peer 17  is  honest reputation: 0.5266822874546051
# Peer 10  is  honest reputation: 0.2733649015426636
# Peer 7  is  honest reputation: 0.07811981439590454
# Peer 11  is  honest reputation: 0.24957093596458435
# Peer 12  is  attacker reputation: 0.08108383417129517
# Peer 15  is  honest reputation: 0.01184004545211792
# Peer 13  is  honest reputation: -0.023161619901657104
# Average of peers' local losses: 1.890353
# Mixing took 2.7825
# -> Update reputation
# Aggregation took 3.0087
#
# Average test loss: 2.0299, Test accuracy: 2218/10000 (22.18%)
#
# Class      - Accuracy
# Plane      - 51.9
# Car        - 0.4
# Bird       - 9.7
# Cat        - 0.8
# Deer       - 87.9
# Dog        - 4.7
# Frog       - 10.0
# Horse      - 7.3
# Ship       - 10.9
# Truck      - 38.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.02153831720352173
# Peer 14  is  honest reputation: -0.05973619222640991
# Peer 5  is  attacker reputation: 0.2549770176410675
# Peer 6  is  honest reputation: 0.09388428926467896
# Peer 10  is  honest reputation: 0.29212087392807007
# Peer 15  is  honest reputation: 0.044346511363983154
# Peer 1  is  honest reputation: 0.27457886934280396
# Peer 3  is  honest reputation: 0.7131143510341644
# Peer 12  is  attacker reputation: -0.17841845750808716
# Peer 7  is  honest reputation: 0.08665299415588379
# Average of peers' local losses: 1.800455
# Mixing took 2.8246
# -> Update reputation
# Aggregation took 3.0067
#
# Average test loss: 1.8097, Test accuracy: 3049/10000 (30.49%)
#
# Class      - Accuracy
# Plane      - 57.6
# Car        - 36.0
# Bird       - 16.7
# Cat        - 2.6
# Deer       - 11.1
# Dog        - 8.4
# Frog       - 83.1
# Horse      - 33.8
# Ship       - 18.4
# Truck      - 37.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/100 |
#
#
# Selected Peers:
# Peer 12  is  attacker reputation: -0.260230153799057
# Peer 11  is  honest reputation: 0.2721700966358185
# Peer 6  is  honest reputation: 0.29594171047210693
# Peer 9  is  honest reputation: 0.47163480520248413
# Peer 13  is  honest reputation: -0.0032627880573272705
# Peer 1  is  honest reputation: 0.2739158868789673
# Peer 18  is  honest reputation: 0.09513527154922485
# Peer 5  is  attacker reputation: 0.1710304319858551
# Peer 8  is  honest reputation: 0.2196577787399292
# Peer 14  is  honest reputation: -0.0577472448348999
# Average of peers' local losses: 1.744730
# Mixing took 2.8096
# -> Update reputation
# Aggregation took 3.0067
#
# Average test loss: 1.8475, Test accuracy: 2923/10000 (29.23%)
#
# Class      - Accuracy
# Plane      - 55.6
# Car        - 24.3
# Bird       - 17.1
# Cat        - 7.5
# Deer       - 3.3
# Dog        - 7.4
# Frog       - 94.2
# Horse      - 18.5
# Ship       - 22.0
# Truck      - 42.4
#
# Backdoor ASR 0.0
#  | Global training round : 10/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.2841570973396301
# Peer 18  is  honest reputation: 0.09670966863632202
# Peer 11  is  honest reputation: 0.27878478169441223
# Peer 16  is  honest reputation: 0.05863690376281738
# Peer 19  is  honest reputation: 0.2603975832462311
# Peer 13  is  honest reputation: -0.001163095235824585
# Peer 0  is  attacker reputation: 0.09870484471321106
# Peer 10  is  honest reputation: 0.47542572021484375
# Peer 9  is  honest reputation: 0.4847663640975952
# Peer 12  is  attacker reputation: -0.5466501414775848
# Average of peers' local losses: 1.725553
# Mixing took 2.7845
# -> Update reputation
# Aggregation took 3.0117
#
# Average test loss: 1.7766, Test accuracy: 3295/10000 (32.95%)
#
# Class      - Accuracy
# Plane      - 51.7
# Car        - 8.7
# Bird       - 18.8
# Cat        - 12.2
# Deer       - 48.3
# Dog        - 2.3
# Frog       - 65.1
# Horse      - 30.8
# Ship       - 39.6
# Truck      - 52.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.23429614305496216
# Peer 10  is  honest reputation: 0.47700047492980957
# Peer 13  is  honest reputation: 0.1741357147693634
# Peer 15  is  honest reputation: 0.272418737411499
# Peer 6  is  honest reputation: 0.2954168915748596
# Peer 7  is  honest reputation: 0.28363215923309326
# Peer 17  is  honest reputation: 0.5425948798656464
# Peer 18  is  honest reputation: 0.2562443017959595
# Peer 19  is  honest reputation: 0.41714993119239807
# Peer 1  is  honest reputation: 0.28372085094451904
# Average of peers' local losses: 1.668993
# Mixing took 2.2611
# -> Update reputation
# [0.45767595 0.24519564 0.16301971 0.48046189 0.2025813  0.10671659
#  0.12514607 0.10025868]
# Aggregation took 1.6455
#
# Average test loss: 1.5975, Test accuracy: 4014/10000 (40.14%)
#
# Class      - Accuracy
# Plane      - 57.8
# Car        - 28.3
# Bird       - 39.4
# Cat        - 12.2
# Deer       - 28.9
# Dog        - 35.6
# Frog       - 58.0
# Horse      - 40.3
# Ship       - 41.7
# Truck      - 59.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/100 |
#
#
# Selected Peers:
# Peer 0  is  attacker reputation: 0.016934365034103394
# Peer 3  is  honest reputation: 0.947797030210495
# Peer 4  is  honest reputation: 0.2647010385990143
# Peer 8  is  honest reputation: 0.24195986986160278
# Peer 17  is  honest reputation: 0.6584199965000153
# Peer 10  is  honest reputation: 0.6292028427124023
# Peer 6  is  honest reputation: 0.38513004779815674
# Peer 7  is  honest reputation: 0.2606409788131714
# Peer 13  is  honest reputation: 0.1741357147693634
# Peer 9  is  honest reputation: 0.6345680356025696
# Average of peers' local losses: 1.624932
# Mixing took 2.8086
# -> Update reputation
# [0.22398753 0.20282562 0.         0.0360194  0.7298123  0.54220983
#  0.1131471  0.53240028 0.54208521 0.34521527]
# Aggregation took 1.9883
#
# Average test loss: 1.5014, Test accuracy: 4327/10000 (43.27%)
#
# Class      - Accuracy
# Plane      - 37.5
# Car        - 51.1
# Bird       - 11.6
# Cat        - 32.6
# Deer       - 38.0
# Dog        - 17.0
# Frog       - 75.7
# Horse      - 46.7
# Ship       - 61.9
# Truck      - 60.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.26950138807296753
# Peer 19  is  honest reputation: 0.41714993119239807
# Peer 18  is  honest reputation: 0.2993226647377014
# Peer 11  is  honest reputation: 0.44116637110710144
# Peer 10  is  honest reputation: 0.6711040735244751
# Peer 1  is  honest reputation: 0.23543202877044678
# Peer 15  is  honest reputation: 0.34025824069976807
# Peer 3  is  honest reputation: 0.9921493828296661
# Peer 6  is  honest reputation: 0.42382514476776123
# Peer 7  is  honest reputation: 0.29167407751083374
# Average of peers' local losses: 1.594113
# Mixing took 2.2641
# -> Update reputation
# [0.4086253  0.65437575 0.25963184 0.34015864 0.36205807 0.24552415
#  0.25408608 0.35118915]
# Aggregation took 1.6035
#
# Average test loss: 1.5000, Test accuracy: 4471/10000 (44.71%)
#
# Class      - Accuracy
# Plane      - 37.2
# Car        - 64.1
# Bird       - 20.5
# Cat        - 19.6
# Deer       - 57.8
# Dog        - 34.1
# Frog       - 60.6
# Horse      - 36.2
# Ship       - 67.5
# Truck      - 49.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.4977836012840271
# Peer 10  is  honest reputation: 0.8467371463775635
# Peer 16  is  honest reputation: 0.23100018501281738
# Peer 15  is  honest reputation: 0.3144679665565491
# Peer 19  is  honest reputation: 0.41714993119239807
# Peer 4  is  honest reputation: 0.09985873103141785
# Peer 6  is  honest reputation: 0.4180956482887268
# Peer 9  is  honest reputation: 0.6709275841712952
# Peer 13  is  honest reputation: 0.17745742201805115
# Peer 1  is  honest reputation: 0.32359981536865234
# Average of peers' local losses: 1.557429
# Mixing took 2.7715
# -> Update reputation
# [0.37365384 0.32338391 0.42439288 0.24629241 0.60274122 0.25072792
#  0.1678195  0.05395179 0.51562467 0.21146201]
# Aggregation took 1.9768
#
# Average test loss: 1.4662, Test accuracy: 4709/10000 (47.09%)
#
# Class      - Accuracy
# Plane      - 51.0
# Car        - 48.2
# Bird       - 43.1
# Cat        - 36.8
# Deer       - 38.3
# Dog        - 35.1
# Frog       - 57.3
# Horse      - 51.0
# Ship       - 55.3
# Truck      - 54.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.43062329292297363
# Peer 16  is  honest reputation: 0.3691933751106262
# Peer 10  is  honest reputation: 0.8151728510856628
# Peer 9  is  honest reputation: 0.6880928874015808
# Peer 18  is  honest reputation: 0.4531530737876892
# Peer 8  is  honest reputation: 0.3295373320579529
# Peer 13  is  honest reputation: 0.17173567414283752
# Peer 3  is  honest reputation: 0.9921493828296661
# Peer 6  is  honest reputation: 0.5707692503929138
# Peer 19  is  honest reputation: 0.5103946030139923
# Average of peers' local losses: 1.519424
# Mixing took 2.228
# -> Update reputation
# [0.39064928 0.35678068 0.31440147 0.17247341 0.75939116 0.66786961
#  0.36075741 0.57524257]
# Aggregation took 1.6085
#
# Average test loss: 1.4396, Test accuracy: 4795/10000 (47.95%)
#
# Class      - Accuracy
# Plane      - 44.0
# Car        - 53.9
# Bird       - 22.7
# Cat        - 14.1
# Deer       - 53.6
# Dog        - 35.3
# Frog       - 76.1
# Horse      - 52.4
# Ship       - 64.3
# Truck      - 63.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/100 |
#
#
# Selected Peers:
# Peer 19  is  honest reputation: 0.5103946030139923
# Peer 17  is  honest reputation: 0.6573127210140228
# Peer 3  is  honest reputation: 1.1125067174434662
# Peer 8  is  honest reputation: 0.2919462323188782
# Peer 10  is  honest reputation: 0.9246188402175903
# Peer 0  is  attacker reputation: -0.2289905548095703
# Peer 6  is  honest reputation: 0.5302974581718445
# Peer 9  is  honest reputation: 0.7730545997619629
# Peer 13  is  honest reputation: 0.17173567414283752
# Peer 18  is  honest reputation: 0.49092358350753784
# Average of peers' local losses: 1.467552
# Mixing took 2.7885
# -> Update reputation
# [0.46733704 0.         0.50311467 0.37374809 0.18618201 0.39006009
#  0.05519361 0.67521728 0.75709697 0.39449997]
# Aggregation took 1.9858
#
# Average test loss: 1.3976, Test accuracy: 4875/10000 (48.75%)
#
# Class      - Accuracy
# Plane      - 67.0
# Car        - 71.2
# Bird       - 23.5
# Cat        - 30.2
# Deer       - 40.6
# Dog        - 46.1
# Frog       - 54.6
# Horse      - 52.0
# Ship       - 50.8
# Truck      - 51.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.33243274688720703
# Peer 9  is  honest reputation: 0.6281258463859558
# Peer 3  is  honest reputation: 1.1108460128307343
# Peer 10  is  honest reputation: 0.9417389035224915
# Peer 19  is  honest reputation: 0.5333389341831207
# Peer 1  is  honest reputation: 0.37392085790634155
# Peer 11  is  honest reputation: 0.44307616353034973
# Peer 17  is  honest reputation: 0.6749357283115387
# Peer 13  is  honest reputation: 0.17671778798103333
# Peer 5  is  attacker reputation: -0.11455464363098145
# Average of peers' local losses: 1.621232
# Mixing took 2.7725
# -> Update reputation
# [0.40778525 0.2232544  0.46607305 0.05556538 0.76278815 0.51433684
#  0.57786755 0.         0.25830292 0.3294128 ]
# Aggregation took 1.9938
#
# Average test loss: 1.5555, Test accuracy: 4460/10000 (44.60%)
#
# Class      - Accuracy
# Plane      - 37.9
# Car        - 55.3
# Bird       - 14.1
# Cat        - 38.6
# Deer       - 46.0
# Dog        - 40.2
# Frog       - 50.9
# Horse      - 58.8
# Ship       - 42.9
# Truck      - 61.3
#
# Backdoor ASR 0.0
#  | Global training round : 18/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.1254359781742096
# Peer 16  is  honest reputation: 0.4954878091812134
# Peer 7  is  honest reputation: 0.4431536793708801
# Peer 13  is  honest reputation: 0.17820945382118225
# Peer 17  is  honest reputation: 0.6911955773830414
# Peer 8  is  honest reputation: 0.3098471760749817
# Peer 4  is  honest reputation: 0.28715357184410095
# Peer 10  is  honest reputation: 0.7818419933319092
# Peer 11  is  honest reputation: 0.46475622057914734
# Peer 18  is  honest reputation: 0.5142407417297363
# Average of peers' local losses: 1.883473
# Mixing took 2.7755
# -> Update reputation
# [0.40342332 0.26142641 0.37167042 0.37889209 0.24152808 0.56368472
#  0.79045829 0.21130355 0.34201854 0.06091441]
# Aggregation took 1.9908
#
# Average test loss: 2.7504, Test accuracy: 1216/10000 (12.16%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 0.0
# Bird       - 1.6
# Cat        - 0.0
# Deer       - 24.8
# Dog        - 0.0
# Frog       - 95.2
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.5290483832359314
# Peer 9  is  honest reputation: 0.6276286244392395
# Peer 8  is  honest reputation: 0.38508474826812744
# Peer 3  is  honest reputation: 1.2113405764102936
# Peer 10  is  honest reputation: 0.7769061326980591
# Peer 19  is  honest reputation: 0.5555386245250702
# Peer 16  is  honest reputation: 0.40632736682891846
# Peer 15  is  honest reputation: 0.34966540336608887
# Peer 13  is  honest reputation: 0.1996784508228302
# Peer 11  is  honest reputation: 0.5374539196491241
# Average of peers' local losses: 1.725446
# Mixing took 2.225
# -> Update reputation
# [0.54991963 0.52232157 0.34071237 0.21936805 0.06987879 0.3533183
#  0.81083553 0.39444774]
# Aggregation took 1.6055
#
# Average test loss: 1.4946, Test accuracy: 4373/10000 (43.73%)
#
# Class      - Accuracy
# Plane      - 37.6
# Car        - 50.7
# Bird       - 41.3
# Cat        - 34.9
# Deer       - 53.5
# Dog        - 0.7
# Frog       - 62.2
# Horse      - 29.5
# Ship       - 62.8
# Truck      - 64.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 0.5827537775039673
# Peer 11  is  honest reputation: 0.5374539196491241
# Peer 18  is  honest reputation: 0.5349276661872864
# Peer 7  is  honest reputation: 0.49506521224975586
# Peer 3  is  honest reputation: 1.2951607406139374
# Peer 14  is  honest reputation: -0.0442812442779541
# Peer 19  is  honest reputation: 0.5205955803394318
# Peer 9  is  honest reputation: 0.7452243566513062
# Peer 17  is  honest reputation: 0.5664195120334625
# Peer 0  is  attacker reputation: -0.4556521475315094
# Average of peers' local losses: 1.533802
# Mixing took 2.8246
# -> Update reputation
# [0.53266131 0.39784135 0.39061169 0.         0.36071258 0.33363746
#  0.         0.18985137 0.37013496 0.8135318 ]
# Aggregation took 1.9788
#
# Average test loss: 1.4890, Test accuracy: 4472/10000 (44.72%)
#
# Class      - Accuracy
# Plane      - 41.0
# Car        - 48.2
# Bird       - 48.2
# Cat        - 23.6
# Deer       - 50.9
# Dog        - 14.0
# Frog       - 68.8
# Horse      - 30.0
# Ship       - 63.8
# Truck      - 58.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.3868759274482727
# Peer 18  is  honest reputation: 0.556220293045044
# Peer 14  is  honest reputation: -0.036507368087768555
# Peer 7  is  honest reputation: 0.5145565867424011
# Peer 9  is  honest reputation: 0.7614941596984863
# Peer 19  is  honest reputation: 0.5453456342220306
# Peer 11  is  honest reputation: 0.3598237931728363
# Peer 10  is  honest reputation: 0.7839634418487549
# Peer 8  is  honest reputation: 0.5801624655723572
# Peer 16  is  honest reputation: 0.38868945837020874
# Average of peers' local losses: 1.540050
# Mixing took 2.218
# -> Update reputation
# [0.31579474 0.51124072 0.46191633 0.47345999 0.         0.32301208
#  0.52780484 0.27895949]
# Aggregation took 1.6075
#
# Average test loss: 1.5759, Test accuracy: 3972/10000 (39.72%)
#
# Class      - Accuracy
# Plane      - 32.0
# Car        - 20.7
# Bird       - 38.2
# Cat        - 18.6
# Deer       - 69.1
# Dog        - 9.1
# Frog       - 56.5
# Horse      - 30.8
# Ship       - 65.4
# Truck      - 56.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.4834744334220886
# Peer 9  is  honest reputation: 0.7613291144371033
# Peer 4  is  honest reputation: 0.3532239496707916
# Peer 3  is  honest reputation: 1.3050262033939362
# Peer 19  is  honest reputation: 0.5453456342220306
# Peer 15  is  honest reputation: 0.34966540336608887
# Peer 16  is  honest reputation: 0.38868945837020874
# Peer 13  is  honest reputation: 0.23569020628929138
# Peer 18  is  honest reputation: 0.6966657042503357
# Peer 11  is  honest reputation: 0.5238901078701019
# Average of peers' local losses: 1.501498
# Mixing took 2.7775
# -> Update reputation
# [0.56452708 0.85062699 0.62653588 0.22380845 0.3899873  0.01994142
#  0.24559593 0.37605174 0.28262814 0.42283031]
# Aggregation took 1.9808
#
# Average test loss: 1.4670, Test accuracy: 4674/10000 (46.74%)
#
# Class      - Accuracy
# Plane      - 46.4
# Car        - 51.5
# Bird       - 34.5
# Cat        - 20.9
# Deer       - 67.3
# Dog        - 19.3
# Frog       - 71.5
# Horse      - 32.6
# Ship       - 62.6
# Truck      - 60.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/100 |
#
#
# Selected Peers:
# Peer 9  is  honest reputation: 0.8761386275291443
# Peer 19  is  honest reputation: 0.5358987748622894
# Peer 18  is  honest reputation: 0.7798988223075867
# Peer 4  is  honest reputation: 0.3911662995815277
# Peer 13  is  honest reputation: 0.1603897511959076
# Peer 8  is  honest reputation: 0.711441695690155
# Peer 10  is  honest reputation: 0.7840184569358826
# Peer 11  is  honest reputation: 0.5522307455539703
# Peer 3  is  honest reputation: 1.3988622725009918
# Peer 15  is  honest reputation: 0.43098175525665283
# Average of peers' local losses: 1.442092
# Mixing took 2.7855
# -> Update reputation
# [0.61974608 0.52201419 0.87584846 0.70007275 0.58712706 0.00424961
#  0.40358068 0.47372829 0.3369168  0.50560065]
# Aggregation took 1.9878
#
# Average test loss: 1.3895, Test accuracy: 4898/10000 (48.98%)
#
# Class      - Accuracy
# Plane      - 41.1
# Car        - 61.9
# Bird       - 27.3
# Cat        - 27.5
# Deer       - 70.1
# Dog        - 14.2
# Frog       - 72.9
# Horse      - 40.4
# Ship       - 71.1
# Truck      - 63.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/100 |
#
#
# Selected Peers:
# Peer 11  is  honest reputation: 0.6501642167568207
# Peer 16  is  honest reputation: 0.36810749769210815
# Peer 17  is  honest reputation: 0.5887225568294525
# Peer 10  is  honest reputation: 0.7666328549385071
# Peer 8  is  honest reputation: 0.8179551362991333
# Peer 7  is  honest reputation: 0.5915791988372803
# Peer 9  is  honest reputation: 0.9608055949211121
# Peer 3  is  honest reputation: 1.451019138097763
# Peer 1  is  honest reputation: 0.5319274663925171
# Peer 6  is  honest reputation: 0.5385863184928894
# Average of peers' local losses: 1.420707
# Mixing took 2.7865
# -> Update reputation
# [0.59673134 0.58218547 0.2512483  0.61275747 0.59680892 0.53488326
#  0.42796156 0.69753048 0.51193297 0.8847383 ]
# Aggregation took 1.9968
#
# Average test loss: 1.3129, Test accuracy: 5288/10000 (52.88%)
#
# Class      - Accuracy
# Plane      - 50.5
# Car        - 62.8
# Bird       - 36.3
# Cat        - 24.7
# Deer       - 56.3
# Dog        - 25.9
# Frog       - 80.7
# Horse      - 52.3
# Ship       - 77.4
# Truck      - 61.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.7815383672714233
# Peer 11  is  honest reputation: 0.7591247856616974
# Peer 3  is  honest reputation: 1.4905319511890411
# Peer 4  is  honest reputation: 0.4439728558063507
# Peer 6  is  honest reputation: 0.690322995185852
# Peer 18  is  honest reputation: 0.6724668145179749
# Peer 9  is  honest reputation: 0.955837070941925
# Peer 19  is  honest reputation: 0.6082289516925812
# Peer 1  is  honest reputation: 0.5507609248161316
# Peer 7  is  honest reputation: 0.6587081551551819
# Average of peers' local losses: 1.374710
# Mixing took 2.224
# -> Update reputation
# [0.57121859 0.43460408 0.63297783 0.69357316 0.89855839 0.74100446
#  0.51717762 0.44157311]
# Aggregation took 1.6055
#
# Average test loss: 1.3163, Test accuracy: 5205/10000 (52.05%)
# Class      - Accuracy
# Plane      - 40.6
# Car        - 79.0
# Bird       - 32.1
# Cat        - 24.9
# Deer       - 65.6
# Dog        - 25.9
# Frog       - 77.7
# Horse      - 49.8
# Ship       - 76.9
# Truck      - 48.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/100 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.521281361579895
# Peer 13  is  honest reputation: 0.09761205315589905
# Peer 18  is  honest reputation: 0.7426921725273132
# Peer 9  is  honest reputation: 1.0460657477378845
# Peer 4  is  honest reputation: 0.4439728558063507
# Peer 6  is  honest reputation: 0.6658415198326111
# Peer 11  is  honest reputation: 0.8397315442562103
# Peer 3  is  honest reputation: 1.5580457746982574
# Peer 10  is  honest reputation: 0.9481708407402039
# Peer 17  is  honest reputation: 0.7814178764820099
# Average of peers' local losses: 1.339005
# Mixing took 2.8116
# -> Update reputation
# [0.37042377 0.64476809 0.87275284 0.01310358 0.55331253 0.74623777
#  0.35264592 0.49735776 0.70077113 0.6364633 ]
# Aggregation took 1.9768
#
# Average test loss: 1.2837, Test accuracy: 5351/10000 (53.51%)
#
# Class      - Accuracy
# Plane      - 29.3
# Car        - 74.0
# Bird       - 38.2
# Cat        - 20.2
# Deer       - 62.4
# Dog        - 36.9
# Frog       - 77.3
# Horse      - 56.7
# Ship       - 78.9
# Truck      - 61.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 0.9887406229972839
# Peer 8  is  honest reputation: 0.8066871762275696
# Peer 7  is  honest reputation: 0.6587081551551819
# Peer 2  is  attacker reputation: -0.5473282039165497
# Peer 9  is  honest reputation: 1.084337055683136
# Peer 3  is  honest reputation: 1.464443176984787
# Peer 1  is  honest reputation: 0.5589213967323303
# Peer 4  is  honest reputation: 0.5088406503200531
# Peer 11  is  honest reputation: 0.8721326887607574
# Peer 16  is  honest reputation: 0.35010719299316406
# Average of peers' local losses: 1.325753
# Mixing took 2.7825
# -> Update reputation
# [0.37912372 0.87194647 0.24833186 0.75550191 0.61026097 0.71112179
#  0.43911216 0.5169339  0.54904741 0.        ]
# Aggregation took 1.9928
#
# Average test loss: 1.1853, Test accuracy: 5766/10000 (57.66%)
#
# Class      - Accuracy
# Plane      - 60.7
# Car        - 79.0
# Bird       - 48.7
# Cat        - 28.7
# Deer       - 43.3
# Dog        - 48.8
# Frog       - 65.8
# Horse      - 58.4
# Ship       - 78.7
# Truck      - 64.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/100 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.6920729279518127
# Peer 6  is  honest reputation: 0.6657158136367798
# Peer 3  is  honest reputation: 1.4610693156719208
# Peer 19  is  honest reputation: 0.5675456821918488
# Peer 17  is  honest reputation: 0.886218398809433
# Peer 8  is  honest reputation: 0.8292635679244995
# Peer 10  is  honest reputation: 1.0093761086463928
# Peer 1  is  honest reputation: 0.5910568237304688
# Peer 14  is  honest reputation: 0.08061349391937256
# Peer 18  is  honest reputation: 0.7430694103240967
# Average of peers' local losses: 1.443013
# Mixing took 2.7745
# -> Update reputation
# [0.62704066 0.45411679 0.54439867 0.         0.71402653 0.53720294
#  0.45063093 0.48517096 0.87274539 0.54315776]
# Aggregation took 1.9878
#
# Average test loss: 1.5720, Test accuracy: 4506/10000 (45.06%)
#
# Class      - Accuracy
# Plane      - 38.6
# Car        - 51.9
# Bird       - 37.9
# Cat        - 12.7
# Deer       - 62.6
# Dog        - 20.2
# Frog       - 85.8
# Horse      - 35.9
# Ship       - 69.5
# Truck      - 35.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/100 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 1.4756244122982025
# Peer 6  is  honest reputation: 0.6608641147613525
# Peer 16  is  honest reputation: 0.37356072664260864
# Peer 18  is  honest reputation: 0.7313545346260071
# Peer 13  is  honest reputation: 0.13303080201148987
# Peer 1  is  honest reputation: 0.6166306734085083
# Peer 17  is  honest reputation: 0.7415248453617096
# Peer 19  is  honest reputation: 0.6210134327411652
# Peer 9  is  honest reputation: 1.1055777668952942
# Peer 8  is  honest reputation: 0.8676633238792419
# Average of peers' local losses: 1.340181
# Mixing took 2.7795
# -> Update reputation
# [0.63065246 0.49198488 0.70703049 0.         0.45552013 0.60914357
#  0.52850409 0.57186958 0.28542296 0.88687821]
# Aggregation took 1.9938
#
# Average test loss: 1.2438, Test accuracy: 5539/10000 (55.39%)
#
# Class      - Accuracy
# Plane      - 43.9
# Car        - 74.3
# Bird       - 42.2
# Cat        - 28.7
# Deer       - 54.5
# Dog        - 33.2
# Frog       - 84.9
# Horse      - 47.0
# Ship       - 78.2
# Truck      - 67.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.6167640089988708
# Peer 14  is  honest reputation: 0.12546348571777344
# Peer 7  is  honest reputation: 0.7397629618644714
# Peer 18  is  honest reputation: 0.8326787352561951
# Peer 9  is  honest reputation: 1.0063412189483643
# Peer 10  is  honest reputation: 1.0264897346496582
# Peer 4  is  honest reputation: 0.5189623534679413
# Peer 19  is  honest reputation: 0.6637959182262421
# Peer 17  is  honest reputation: 0.775416761636734
# Peer 16  is  honest reputation: 0.4186963438987732
# Average of peers' local losses: 1.298201
# Mixing took 2.7985
# -> Update reputation
# [0.39715332 0.48753318 0.31223439 0.36999486 0.53295549 0.61817026
#  0.03460133 0.54269486 0.52627008 0.71794664]
# Aggregation took 1.9918
#
# Average test loss: 1.2283, Test accuracy: 5591/10000 (55.91%)
#
# Class      - Accuracy
# Plane      - 51.5
# Car        - 79.8
# Bird       - 33.5
# Cat        - 24.7
# Deer       - 64.7
# Dog        - 27.0
# Frog       - 79.7
# Horse      - 55.9
# Ship       - 85.3
# Truck      - 57.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.1313301920890808
# Peer 4  is  honest reputation: 0.6163529455661774
# Peer 15  is  honest reputation: 0.48838871717453003
# Peer 3  is  honest reputation: 1.5322271883487701
# Peer 16  is  honest reputation: 0.550955057144165
# Peer 1  is  honest reputation: 0.6482003927230835
# Peer 9  is  honest reputation: 0.9499740600585938
# Peer 11  is  honest reputation: 0.7369430959224701
# Peer 5  is  attacker reputation: -0.3552810847759247
# Peer 17  is  honest reputation: 0.7607550323009491
# Average of peers' local losses: 1.266581
# Mixing took 2.239
# -> Update reputation
# [0.84490592 0.60392186 0.50935378 0.47506191 0.34938875 0.34760942
#  0.40767765 0.4690509 ]
# Aggregation took 1.6065
#
# Average test loss: 1.2096, Test accuracy: 5656/10000 (56.56%)
#
# Class      - Accuracy
# Plane      - 52.8
# Car        - 76.5
# Bird       - 44.5
# Cat        - 31.6
# Deer       - 49.7
# Dog        - 24.2
# Frog       - 84.9
# Horse      - 56.3
# Ship       - 81.5
# Truck      - 63.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.8221999406814575
# Peer 8  is  honest reputation: 0.8676189184188843
# Peer 17  is  honest reputation: 0.7897925674915314
# Peer 16  is  honest reputation: 0.5906578302383423
# Peer 7  is  honest reputation: 0.8359034061431885
# Peer 6  is  honest reputation: 0.7131873965263367
# Peer 15  is  honest reputation: 0.5926831364631653
# Peer 11  is  honest reputation: 0.7445232570171356
# Peer 3  is  honest reputation: 1.4660116136074066
# Peer 14  is  honest reputation: 0.262550950050354
# Average of peers' local losses: 1.241569
# Mixing took 2.7685
# -> Update reputation
# [0.53279613 0.50181538 0.57428583 0.33344061 0.37571685 0.58163253
#  0.3357693  0.27845513 0.84295865 0.05458366]
# Aggregation took 1.9808
#
# Average test loss: 1.1853, Test accuracy: 5759/10000 (57.59%)
#
# Class      - Accuracy
# Plane      - 55.0
# Car        - 75.9
# Bird       - 38.0
# Cat        - 26.3
# Deer       - 65.7
# Dog        - 34.4
# Frog       - 82.6
# Horse      - 48.6
# Ship       - 83.3
# Truck      - 66.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/100 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 0.3426421880722046
# Peer 4  is  honest reputation: 0.6607585847377777
# Peer 17  is  honest reputation: 0.8397338092327118
# Peer 9  is  honest reputation: 0.9272335767745972
# Peer 18  is  honest reputation: 0.8820458054542542
# Peer 1  is  honest reputation: 0.7367886304855347
# Peer 3  is  honest reputation: 1.5193134248256683
# Peer 15  is  honest reputation: 0.6830673217773438
# Peer 10  is  honest reputation: 1.1313301920890808
# Peer 11  is  honest reputation: 0.6373207867145538
# Average of peers' local losses: 1.188566
# Mixing took 2.7815
# -> Update reputation
# [0.41475694 0.05454916 0.72142078 0.35412705 0.5692384  0.46353465
#  0.5250596  0.44725654 0.84331965 0.37616256]
# Aggregation took 1.9928
#
# Average test loss: 1.0818, Test accuracy: 6191/10000 (61.91%)
#
# Class      - Accuracy
# Plane      - 60.7
# Car        - 80.1
# Bird       - 41.6
# Cat        - 40.2
# Deer       - 60.4
# Dog        - 40.0
# Frog       - 78.0
# Horse      - 60.2
# Ship       - 82.7
# Truck      - 75.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/100 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.1985018253326416
# Peer 1  is  honest reputation: 0.7897043228149414
# Peer 7  is  honest reputation: 0.9418986439704895
# Peer 15  is  honest reputation: 0.6834825873374939
# Peer 19  is  honest reputation: 0.8129082024097443
# Peer 3  is  honest reputation: 1.5204582512378693
# Peer 17  is  honest reputation: 0.9342958629131317
# Peer 16  is  honest reputation: 0.5740107893943787
# Peer 9  is  honest reputation: 0.8712001442909241
# Peer 18  is  honest reputation: 0.7691659331321716
# Average of peers' local losses: 1.173052
# Mixing took 2.8086
# -> Update reputation
# [0.53694163 0.71272193 0.38631427 0.48891085 0.45029177 0.60559887
#  0.56655589 0.50817665 0.30301936 0.87065178]
# Aggregation took 1.9848
#
# Average test loss: 1.0802, Test accuracy: 6140/10000 (61.40%)
#
# Class      - Accuracy
# Plane      - 57.0
# Car        - 85.2
# Bird       - 40.6
# Cat        - 36.1
# Deer       - 62.8
# Dog        - 39.8
# Frog       - 78.5
# Horse      - 59.0
# Ship       - 86.0
# Truck      - 69.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/100 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.8481689691543579
# Peer 10  is  honest reputation: 1.1805946826934814
# Peer 19  is  honest reputation: 0.8877487480640411
# Peer 4  is  honest reputation: 0.7292433083057404
# Peer 3  is  honest reputation: 1.623667448759079
# Peer 7  is  honest reputation: 0.9898422360420227
# Peer 9  is  honest reputation: 0.7729666233062744
# Peer 18  is  honest reputation: 0.8225284814834595
# Peer 12  is  attacker reputation: -0.6314343810081482
# Peer 15  is  honest reputation: 0.6953608989715576
# Average of peers' local losses: 1.133078
# Mixing took 2.8015
# -> Update reputation
# [0.34174465 0.         0.87204782 0.49422118 0.60883597 0.51412564
#  0.41819305 0.71203943 0.39558937 0.54156665]
# Aggregation took 1.9798
#
# Average test loss: 1.0451, Test accuracy: 6233/10000 (62.33%)
#
# Class      - Accuracy
# Plane      - 59.9
# Car        - 79.4
# Bird       - 46.7
# Cat        - 52.3
# Deer       - 53.7
# Dog        - 30.8
# Frog       - 78.0
# Horse      - 64.5
# Ship       - 82.7
# Truck      - 75.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/100 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 0.8295308947563171
# Peer 0  is  attacker reputation: -0.7139664888381958
# Peer 7  is  honest reputation: 0.9949700236320496
# Peer 8  is  honest reputation: 0.9529305696487427
# Peer 16  is  honest reputation: 0.6007413268089294
# Peer 17  is  honest reputation: 0.9303363859653473
# Peer 19  is  honest reputation: 0.8942702114582062
# Peer 3  is  honest reputation: 1.6294662058353424
# Peer 14  is  honest reputation: 0.34250378608703613
# Peer 5  is  attacker reputation: -0.3552810847759247
# Average of peers' local losses: 1.179327
# Mixing took 2.8306
# -> Update reputation
# [0.         0.56668526 0.         0.0545365  0.57796724 0.65346445
#  0.68466983 0.62611104 0.41368487 0.89922262]
# Aggregation took 1.9878
#
# Average test loss: 1.1220, Test accuracy: 5964/10000 (59.64%)
#
# Class      - Accuracy
# Plane      - 58.8
# Car        - 84.7
# Bird       - 41.8
# Cat        - 40.2
# Deer       - 70.0
# Dog        - 29.0
# Frog       - 67.1
# Horse      - 50.7
# Ship       - 84.7
# Truck      - 69.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/100 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 1.0691836476325989
# Peer 7  is  honest reputation: 1.125714659690857
# Peer 6  is  honest reputation: 0.6346985101699829
# Peer 18  is  honest reputation: 0.9472672343254089
# Peer 16  is  honest reputation: 0.727911114692688
# Peer 17  is  honest reputation: 0.9304888546466827
# Peer 15  is  honest reputation: 0.7063095569610596
# Peer 19  is  honest reputation: 1.022856205701828
# Peer 1  is  honest reputation: 0.8562220931053162
# Peer 5  is  attacker reputation: -0.43887338042259216
# Average of peers' local losses: 1.465115
# Mixing took 2.8246
# -> Update reputation
# [0.58564252 0.56981126 0.         0.52909862 0.51372197 0.65447161
#  0.4038786  0.6894832  0.33646735 0.41787349]
# Aggregation took 2.0559
#
# Average test loss: 1.8114, Test accuracy: 3842/10000 (38.42%)
#
# Class      - Accuracy
# Plane      - 25.8
# Car        - 40.0
# Bird       - 36.7
# Cat        - 7.9
# Deer       - 73.5
# Dog        - 10.1
# Frog       - 79.8
# Horse      - 23.4
# Ship       - 63.5
# Truck      - 23.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.6379658579826355
# Peer 1  is  honest reputation: 0.8556354641914368
# Peer 16  is  honest reputation: 0.73297518491745
# Peer 7  is  honest reputation: 1.1348323225975037
# Peer 8  is  honest reputation: 1.0709434151649475
# Peer 3  is  honest reputation: 1.7560053169727325
# Peer 4  is  honest reputation: 0.7334004938602448
# Peer 10  is  honest reputation: 1.1792089343070984
# Peer 13  is  honest reputation: 0.12409034371376038
# Peer 14  is  honest reputation: 0.3424530029296875
# Average of peers' local losses: 1.462279
# Mixing took 2.7905
# -> Update reputation
# [0.54201511 0.40172496 0.5882836  0.47553798 0.77027207 0.91822519
#  0.68486018 0.         0.01208112 0.73001305]
# Aggregation took 1.9978
#
# Average test loss: 1.4125, Test accuracy: 4952/10000 (49.52%)
#
# Class      - Accuracy
# Plane      - 50.6
# Car        - 63.9
# Bird       - 34.1
# Cat        - 35.5
# Deer       - 73.2
# Dog        - 10.2
# Frog       - 82.2
# Horse      - 26.9
# Ship       - 80.1
# Truck      - 38.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/100 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.8354972898960114
# Peer 19  is  honest reputation: 0.8767548501491547
# Peer 15  is  honest reputation: 0.7161372303962708
# Peer 7  is  honest reputation: 1.2494891285896301
# Peer 6  is  honest reputation: 0.6541968584060669
# Peer 17  is  honest reputation: 0.9351056516170502
# Peer 16  is  honest reputation: 0.745695173740387
# Peer 8  is  honest reputation: 1.06670343875885
# Peer 11  is  honest reputation: 0.6580551564693451
# Peer 14  is  honest reputation: 0.2405744194984436
# Average of peers' local losses: 1.289974
# Mixing took 2.217
# -> Update reputation
# [0.51304722 0.51420325 0.53667254 0.79456559 0.65833001 0.61110154
#  0.41834082 0.59552004]
# Aggregation took 1.6005
#
# Average test loss: 1.2628, Test accuracy: 5589/10000 (55.89%)
#
# Class      - Accuracy
# Plane      - 55.3
# Car        - 74.0
# Bird       - 33.6
# Cat        - 27.8
# Deer       - 63.4
# Dog        - 16.6
# Frog       - 87.5
# Horse      - 52.2
# Ship       - 82.3
# Truck      - 66.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/100 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.8279630243778229
# Peer 10  is  honest reputation: 1.1572480201721191
# Peer 9  is  honest reputation: 0.6439669728279114
# Peer 16  is  honest reputation: 0.7953495979309082
# Peer 4  is  honest reputation: 0.9146691262722015
# Peer 6  is  honest reputation: 0.6541968584060669
# Peer 18  is  honest reputation: 0.9588702917098999
# Peer 11  is  honest reputation: 0.6741718947887421
# Peer 8  is  honest reputation: 1.0183532238006592
# Peer 13  is  honest reputation: 0.19224759936332703
# Average of peers' local losses: 1.237976
# Mixing took 2.225
# -> Update reputation
# [0.64234633 0.50470828 0.6946016  0.56228144 0.43300248 0.35292988
#  0.78009607 0.39627759]
# Aggregation took 1.5924
#
# Average test loss: 1.2277, Test accuracy: 5630/10000 (56.30%)
#
# Class      - Accuracy
# Plane      - 57.9
# Car        - 77.0
# Bird       - 25.8
# Cat        - 34.4
# Deer       - 70.1
# Dog        - 27.2
# Frog       - 83.8
# Horse      - 47.8
# Ship       - 80.6
# Truck      - 58.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/100 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.6920788288116455
# Peer 3  is  honest reputation: 1.8060859143733978
# Peer 17  is  honest reputation: 0.8646558821201324
# Peer 10  is  honest reputation: 1.274108648300171
# Peer 7  is  honest reputation: 1.312188446521759
# Peer 15  is  honest reputation: 0.7969198822975159
# Peer 9  is  honest reputation: 0.6477180123329163
# Peer 13  is  honest reputation: 0.19224759936332703
# Peer 1  is  honest reputation: 0.903529942035675
# Peer 4  is  honest reputation: 0.9906507432460785
# Average of peers' local losses: 1.208236
# Mixing took 2.2681
# -> Update reputation
# [0.91571328 0.45264091 0.51072528 0.56580628 0.47563325 0.54987433
#  0.00974019 0.74377037]
# Aggregation took 1.6395
