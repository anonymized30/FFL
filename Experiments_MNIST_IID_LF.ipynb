# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1000000
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 200 #"number of rounds of federated model training"
LOCAL_EPOCHS = 1 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,strategy = 's1', resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 2  is  attacker reputation: 0.0
# Peer 1  is  attacker reputation: 0.0
# Peer 19  is  attacker reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Average of peers' local losses: 2.294932
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.037
#
# Average test loss: 2.2794, Test accuracy: 1486/10000 (14.86%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 15.9
# Two        - 49.7
# Three      - 5.1
# Four       - 0.0
# Five       - 0.2
# Six        - 0.0
# Seven      - 5.1
# Eight      - 27.6
# Nine       - 41.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/200 |
#
#
# Selected Peers:
# Peer 12  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: -0.05957460403442383
# Peer 18  is  honest reputation: 0.19871032238006592
# Peer 7  is  honest reputation: 0.33671873807907104
# Peer 4  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.3453889489173889
# Peer 3  is  honest reputation: 0.34817516803741455
# Peer 16  is  honest reputation: 0.31065285205841064
# Peer 1  is  attacker reputation: -0.06840604543685913
# Peer 15  is  honest reputation: 0.0
# Average of peers' local losses: 2.278089
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.04
#
# Average test loss: 2.2591, Test accuracy: 2999/10000 (29.99%)
#
# Class      - Accuracy
# Zero       - 2.2
# One        - 79.1
# Two        - 59.6
# Three      - 32.3
# Four       - 0.0
# Five       - 0.3
# Six        - 0.0
# Seven      - 20.0
# Eight      - 41.4
# Nine       - 52.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 0.3478708863258362
# Peer 14  is  honest reputation: 0.0
# Peer 12  is  honest reputation: 0.013704240322113037
# Peer 5  is  honest reputation: 0.0
# Peer 13  is  honest reputation: 0.16548985242843628
# Peer 1  is  attacker reputation: -0.6876575946807861
# Peer 8  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.014121055603027344
# Peer 2  is  attacker reputation: -0.05516326427459717
# Peer 11  is  attacker reputation: 0.0
# Average of peers' local losses: 2.258144
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.04
#
# Average test loss: 2.2289, Test accuracy: 4297/10000 (42.97%)
#
# Class      - Accuracy
# Zero       - 38.4
# One        - 91.2
# Two        - 59.2
# Three      - 47.8
# Four       - 5.0
# Five       - 0.9
# Six        - 3.2
# Seven      - 47.8
# Eight      - 64.0
# Nine       - 58.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/200 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 0.3501524329185486
# Peer 6  is  honest reputation: 0.7705338597297668
# Peer 8  is  honest reputation: 0.06804323196411133
# Peer 10  is  honest reputation: 0.0
# Peer 19  is  attacker reputation: -0.6809086799621582
# Peer 1  is  attacker reputation: -0.7103387117385864
# Peer 16  is  honest reputation: 0.3099937438964844
# Peer 17  is  honest reputation: 0.33584094047546387
# Peer 11  is  attacker reputation: -0.12153300642967224
# Peer 5  is  honest reputation: 0.3953275680541992
# Average of peers' local losses: 2.227727
# Mixing took 0.01
# -> Update reputation
# Aggregation took 0.043
#
# Average test loss: 2.1773, Test accuracy: 5815/10000 (58.15%)
#
# Class      - Accuracy
# Zero       - 84.5
# One        - 95.1
# Two        - 58.2
# Three      - 66.2
# Four       - 20.1
# Five       - 0.8
# Six        - 36.3
# Seven      - 70.5
# Eight      - 68.8
# Nine       - 68.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.011380910873413086
# Peer 13  is  honest reputation: 0.5597526431083679
# Peer 4  is  honest reputation: 0.4257577061653137
# Peer 2  is  attacker reputation: -0.19699183106422424
# Peer 3  is  honest reputation: 0.6108980774879456
# Peer 12  is  honest reputation: 0.11344552040100098
# Peer 14  is  honest reputation: 0.27982479333877563
# Peer 18  is  honest reputation: 0.21072793006896973
# Peer 0  is  honest reputation: 0.0
# Peer 1  is  attacker reputation: -0.7368667125701904
# Average of peers' local losses: 2.180433
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.021
#
# Average test loss: 2.0855, Test accuracy: 6263/10000 (62.63%)
#
# Class      - Accuracy
# Zero       - 94.0
# One        - 96.1
# Two        - 40.4
# Three      - 69.3
# Four       - 38.2
# Five       - 3.5
# Six        - 66.8
# Seven      - 82.0
# Eight      - 70.8
# Nine       - 55.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: -0.021177291870117188
# Peer 14  is  honest reputation: 0.5465136170387268
# Peer 7  is  honest reputation: 0.344272255897522
# Peer 18  is  honest reputation: 0.49234843254089355
# Peer 8  is  honest reputation: 0.3088086247444153
# Peer 6  is  honest reputation: 1.0124720931053162
# Peer 5  is  honest reputation: 0.47491157054901123
# Peer 11  is  attacker reputation: -0.23706930875778198
# Peer 2  is  attacker reputation: -0.3278250992298126
# Peer 3  is  honest reputation: 0.8433400392532349
# Average of peers' local losses: 2.093937
# Mixing took 0.01
# -> Update reputation
# Aggregation took 0.021
#
# Average test loss: 1.9230, Test accuracy: 6522/10000 (65.22%)
#
# Class      - Accuracy
# Zero       - 94.3
# One        - 96.9
# Two        - 41.1
# Three      - 75.6
# Four       - 58.6
# Five       - 5.5
# Six        - 76.0
# Seven      - 80.6
# Eight      - 61.7
# Nine       - 52.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 0.7000404596328735
# Peer 2  is  attacker reputation: -0.5120310485363007
# Peer 7  is  honest reputation: 0.5614376068115234
# Peer 5  is  honest reputation: 0.7100854516029358
# Peer 19  is  attacker reputation: -0.7824994325637817
# Peer 11  is  attacker reputation: -0.49863794445991516
# Peer 16  is  honest reputation: 0.5010595321655273
# Peer 6  is  honest reputation: 0.9535859227180481
# Peer 8  is  honest reputation: 0.4854670763015747
# Peer 13  is  honest reputation: 0.6574273109436035
# Average of peers' local losses: 1.957608
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.021
#
# Average test loss: 1.6846, Test accuracy: 6873/10000 (68.73%)
#
# Class      - Accuracy
# Zero       - 94.2
# One        - 97.9
# Two        - 53.3
# Three      - 76.0
# Four       - 71.1
# Five       - 16.0
# Six        - 76.1
# Seven      - 79.1
# Eight      - 60.7
# Nine       - 54.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/200 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -0.6918618977069855
# Peer 9  is  honest reputation: 0.0
# Peer 8  is  honest reputation: 0.7184194326400757
# Peer 11  is  attacker reputation: -0.7276245653629303
# Peer 0  is  honest reputation: 0.2506933808326721
# Peer 10  is  honest reputation: 0.24450260400772095
# Peer 4  is  honest reputation: 0.947847843170166
# Peer 12  is  honest reputation: 0.38023656606674194
# Peer 18  is  honest reputation: 0.7049469351768494
# Peer 5  is  honest reputation: 0.961138904094696
# Average of peers' local losses: 1.779412
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.021
#
# Average test loss: 1.3966, Test accuracy: 7324/10000 (73.24%)
#
# Class      - Accuracy
# Zero       - 95.9
# One        - 98.0
# Two        - 64.7
# Three      - 84.2
# Four       - 76.2
# Five       - 28.7
# Six        - 77.3
# Seven      - 82.7
# Eight      - 57.1
# Nine       - 59.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 1.044029951095581
# Peer 11  is  attacker reputation: -1.0079882740974426
# Peer 3  is  honest reputation: 1.084666669368744
# Peer 14  is  honest reputation: 0.7936529517173767
# Peer 7  is  honest reputation: 0.8135992884635925
# Peer 1  is  attacker reputation: -1.0044287145137787
# Peer 8  is  honest reputation: 0.7044520378112793
# Peer 9  is  honest reputation: 0.17497599124908447
# Peer 10  is  honest reputation: 0.4265521764755249
# Peer 16  is  honest reputation: 0.7422115802764893
# Average of peers' local losses: 1.590439
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.021
#
# Average test loss: 1.1405, Test accuracy: 7770/10000 (77.70%)
#
# Class      - Accuracy
# Zero       - 95.2
# One        - 97.0
# Two        - 73.9
# Three      - 85.1
# Four       - 78.9
# Five       - 48.8
# Six        - 83.2
# Seven      - 83.1
# Eight      - 58.6
# Nine       - 67.5
#
# Backdoor ASR 0.0
#  | Global training round : 10/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.49955928325653076
# Peer 15  is  honest reputation: 0.19004756212234497
# Peer 12  is  honest reputation: 0.5397531390190125
# Peer 1  is  attacker reputation: -1.1901798248291016
# Peer 4  is  honest reputation: 1.1319591999053955
# Peer 14  is  honest reputation: 0.821938157081604
# Peer 19  is  attacker reputation: -0.8126474618911743
# Peer 9  is  honest reputation: 0.43380701541900635
# Peer 3  is  honest reputation: 1.362098217010498
# Peer 7  is  honest reputation: 1.0760192275047302
# Average of peers' local losses: 1.420230
# Mixing took 0.009
# -> Update reputation
# Aggregation took 0.02
#
# Average test loss: 0.9331, Test accuracy: 8125/10000 (81.25%)
#
# Class      - Accuracy
# Zero       - 95.7
# One        - 95.4
# Two        - 82.8
# Three      - 87.2
# Four       - 81.6
# Five       - 62.3
# Six        - 85.1
# Seven      - 83.5
# Eight      - 64.0
# Nine       - 71.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 1.4258981347084045
# Peer 17  is  honest reputation: 0.48846298456192017
# Peer 8  is  honest reputation: 0.9776470065116882
# Peer 2  is  attacker reputation: -0.8807766139507294
# Peer 5  is  honest reputation: 1.123323142528534
# Peer 13  is  honest reputation: 0.9005868434906006
# Peer 6  is  honest reputation: 1.0346015691757202
# Peer 18  is  honest reputation: 0.8538538813591003
# Peer 16  is  honest reputation: 1.010417401790619
# Peer 1  is  attacker reputation: -1.2999432682991028
# Average of peers' local losses: 1.285840
# Mixing took 0.009
# -> Update reputation
# [ 0.18066803 -0.93796476 -0.88632696  0.69151209  0.79076589  0.77618522
#   0.89747796  0.72269336  0.75175525  0.82772472]
# Aggregation took 0.016
#
# Average test loss: 0.7884, Test accuracy: 8150/10000 (81.50%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 92.2
# Two        - 80.4
# Three      - 81.4
# Four       - 82.0
# Five       - 69.1
# Six        - 86.5
# Seven      - 94.3
# Eight      - 61.7
# Nine       - 67.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/200 |
#
#
# Selected Peers:
# Peer 2  is  attacker reputation: -1.1292494535446167
# Peer 10  is  honest reputation: 0.6899906992912292
# Peer 4  is  honest reputation: 1.473840355873108
# Peer 6  is  honest reputation: 1.1261285543441772
# Peer 12  is  honest reputation: 0.9077672362327576
# Peer 14  is  honest reputation: 1.177890658378601
# Peer 9  is  honest reputation: 0.7823566198348999
# Peer 18  is  honest reputation: 1.1885409951210022
# Peer 13  is  honest reputation: 1.2522600293159485
# Peer 17  is  honest reputation: 0.4579539895057678
# Average of peers' local losses: 1.169259
# Mixing took 0.01
# -> Update reputation
# [ 0.69574703  0.72721417 -0.94823131  0.60919995  0.19764225  0.83457797
#   0.46980164  0.39169153  0.7348485   0.58291985]
# Aggregation took 0.016
#
# Average test loss: 0.6636, Test accuracy: 8433/10000 (84.33%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 94.0
# Two        - 85.5
# Three      - 84.7
# Four       - 84.5
# Five       - 73.4
# Six        - 86.6
# Seven      - 91.8
# Eight      - 69.1
# Nine       - 73.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 1.7343823909759521
# Peer 11  is  attacker reputation: -1.2411915063858032
# Peer 9  is  honest reputation: 0.7850965857505798
# Peer 8  is  honest reputation: 1.3109830021858215
# Peer 18  is  honest reputation: 1.2144678235054016
# Peer 5  is  honest reputation: 1.45614755153656
# Peer 4  is  honest reputation: 1.4783157110214233
# Peer 12  is  honest reputation: 0.9421548247337341
# Peer 10  is  honest reputation: 0.6890773773193359
# Peer 19  is  attacker reputation: -0.8970620036125183
# Average of peers' local losses: 1.113538
# Mixing took 0.009
# -> Update reputation
# [ 0.87781875  0.9101049   0.94221114  0.69463984 -0.92610699  0.73550633
#   0.76492269  0.91203584 -0.846033    0.39128748]
# Aggregation took 0.016
#
# Average test loss: 0.5970, Test accuracy: 8510/10000 (85.10%)
#
# Class      - Accuracy
# Zero       - 96.7
# One        - 94.4
# Two        - 86.8
# Three      - 83.5
# Four       - 87.7
# Five       - 72.4
# Six        - 87.8
# Seven      - 93.6
# Eight      - 77.3
# Nine       - 68.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 0.982928991317749
# Peer 10  is  honest reputation: 0.6886001825332642
# Peer 2  is  attacker reputation: -1.538664996623993
# Peer 18  is  honest reputation: 1.215899407863617
# Peer 15  is  honest reputation: 0.2233365774154663
# Peer 12  is  honest reputation: 1.2832546830177307
# Peer 19  is  attacker reputation: -0.9667471945285797
# Peer 11  is  attacker reputation: -1.3550381362438202
# Peer 9  is  honest reputation: 1.1321476101875305
# Peer 4  is  honest reputation: 1.803415834903717
# Average of peers' local losses: 1.080722
# Mixing took 0.01
# -> Update reputation
# [-0.90012434 -0.96830786  0.7686743   0.70367246  0.70728574 -0.94621123
#   0.13288251  0.50931454  0.78866309  0.93025089]
# Aggregation took 0.016
#
# Average test loss: 3.3739, Test accuracy: 3181/10000 (31.81%)
#
# Class      - Accuracy
# Zero       - 45.7
# One        - 0.4
# Two        - 40.1
# Three      - 7.3
# Four       - 29.7
# Five       - 12.2
# Six        - 73.7
# Seven      - 99.8
# Eight      - 10.8
# Nine       - 0.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5634908676147461
# Peer 6  is  honest reputation: 1.1342903971672058
# Peer 3  is  honest reputation: 1.7131249904632568
# Peer 18  is  honest reputation: 1.4977028965950012
# Peer 10  is  honest reputation: 0.9916216135025024
# Peer 7  is  honest reputation: 2.032674014568329
# Peer 19  is  attacker reputation: -1.0430564880371094
# Peer 0  is  honest reputation: 0.2925955653190613
# Peer 11  is  attacker reputation: -1.364469736814499
# Peer 13  is  honest reputation: 1.3043558597564697
# Average of peers' local losses: 1.426033
# Mixing took 0.01
# -> Update reputation
# [-0.13706104 -0.91378492 -0.95440859  0.13589022  0.94713463  0.89911067
#   0.71564668  0.85128985  0.79190418  0.64189273]
# Aggregation took 0.015
#
# Average test loss: 0.9842, Test accuracy: 6939/10000 (69.39%)
#
# Class      - Accuracy
# Zero       - 91.1
# One        - 67.7
# Two        - 74.1
# Three      - 63.2
# Four       - 60.2
# Five       - 66.0
# Six        - 85.6
# Seven      - 98.2
# Eight      - 61.8
# Nine       - 26.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/200 |
#
#
# Selected Peers:
# Peer 1  is  attacker reputation: -1.4455646872520447
# Peer 9  is  honest reputation: 1.446897268295288
# Peer 3  is  honest reputation: 1.897140622138977
# Peer 14  is  honest reputation: 1.1980698704719543
# Peer 17  is  honest reputation: 0.4755585789680481
# Peer 8  is  honest reputation: 1.6414610743522644
# Peer 6  is  honest reputation: 1.3282461166381836
# Peer 7  is  honest reputation: 2.232765018939972
# Peer 19  is  attacker reputation: -1.1204143166542053
# Peer 2  is  attacker reputation: -1.6346125304698944
# Average of peers' local losses: 1.268174
# Mixing took 0.009
# -> Update reputation
# [ 0.7594356   0.93474833  0.82511305 -0.92572945 -0.97395771 -0.96269628
#   0.80647205  0.84576782  0.27207589  0.9655449 ]
# Aggregation took 0.016
#
# Average test loss: 3.4009, Test accuracy: 4424/10000 (44.24%)
#
# Class      - Accuracy
# Zero       - 48.0
# One        - 11.6
# Two        - 58.4
# Three      - 41.6
# Four       - 31.4
# Five       - 40.2
# Six        - 76.5
# Seven      - 99.3
# Eight      - 34.4
# Nine       - 4.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.7767562866210938
# Peer 12  is  honest reputation: 1.311549425125122
# Peer 13  is  honest reputation: 1.5060999393463135
# Peer 16  is  honest reputation: 1.348753273487091
# Peer 15  is  honest reputation: 0.5663182735443115
# Peer 18  is  honest reputation: 1.6904016137123108
# Peer 4  is  honest reputation: 2.0900681614875793
# Peer 11  is  attacker reputation: -1.4494796097278595
# Peer 5  is  honest reputation: 1.8147780299186707
# Peer 1  is  attacker reputation: -1.483838677406311
# Average of peers' local losses: 1.529717
# Mixing took 0.01
# -> Update reputation
# [ 0.27789699  0.86472209  0.8293594   0.92238841 -0.97935759 -0.97852662
#   0.76218088  0.67025883  0.07086541  0.69749387]
# Aggregation took 0.016
#
# Average test loss: 3.3648, Test accuracy: 5216/10000 (52.16%)
# Class      - Accuracy
# Zero       - 64.1
# One        - 51.5
# Two        - 66.0
# Three      - 60.4
# Four       - 37.7
# Five       - 43.3
# Six        - 70.9
# Seven      - 99.1
# Eight      - 24.5
# Nine       - 2.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.5755906701087952
# Peer 5  is  honest reputation: 1.8163743019104004
# Peer 11  is  attacker reputation: -1.7570405900478363
# Peer 3  is  honest reputation: 2.192392408847809
# Peer 13  is  honest reputation: 1.506004810333252
# Peer 7  is  honest reputation: 2.5195858478546143
# Peer 2  is  attacker reputation: -1.6663850843906403
# Peer 17  is  honest reputation: 0.7900078892707825
# Peer 0  is  honest reputation: 0.2916530966758728
# Peer 12  is  honest reputation: 1.3158192038536072
# Average of peers' local losses: 1.615031
# Mixing took 0.009
# -> Update reputation
# [ 0.96586394  0.76421999  0.90080405 -0.98528123 -0.21039548  0.67552531
#  -0.98810343  0.07671557  0.86814503  0.07107499]
# Aggregation took 0.016
#
# Average test loss: 1.1431, Test accuracy: 7659/10000 (76.59%)
#
# Class      - Accuracy
# Zero       - 96.4
# One        - 89.7
# Two        - 86.6
# Three      - 85.8
# Four       - 74.2
# Five       - 62.1
# Six        - 82.2
# Seven      - 96.9
# Eight      - 52.7
# Nine       - 35.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/200 |
#
#
# Selected Peers:
# Peer 18  is  honest reputation: 1.6906870603561401
# Peer 6  is  honest reputation: 1.6145065426826477
# Peer 7  is  honest reputation: 2.741895377635956
# Peer 19  is  attacker reputation: -1.1300208568572998
# Peer 13  is  honest reputation: 1.7215113639831543
# Peer 16  is  honest reputation: 1.3670096397399902
# Peer 2  is  attacker reputation: -1.7369670569896698
# Peer 11  is  attacker reputation: -1.8441140949726105
# Peer 0  is  honest reputation: 0.5016438961029053
# Peer 3  is  honest reputation: 2.191696524620056
# Average of peers' local losses: 1.684004
# Mixing took 0.01
# -> Update reputation
# [ 0.76738368 -0.99015311  0.96949127  0.61117515  0.79194089  0.74376748
#  -0.9875848   0.91624619 -0.04961768 -0.95984082]
# Aggregation took 0.016
#
# Average test loss: 10.2061, Test accuracy: 3929/10000 (39.29%)
#
# Class      - Accuracy
# Zero       - 32.0
# One        - 10.2
# Two        - 58.4
# Three      - 49.1
# Four       - 42.7
# Five       - 26.2
# Six        - 61.3
# Seven      - 99.4
# Eight      - 11.0
# Nine       - 3.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 2.853630006313324
# Peer 18  is  honest reputation: 1.7838038206100464
# Peer 5  is  honest reputation: 2.0407283306121826
# Peer 6  is  honest reputation: 1.7287302017211914
# Peer 12  is  honest reputation: 1.5360662341117859
# Peer 0  is  honest reputation: 0.7202127575874329
# Peer 9  is  honest reputation: 1.7387477159500122
# Peer 3  is  honest reputation: 2.3349921107292175
# Peer 4  is  honest reputation: 2.1094096899032593
# Peer 16  is  honest reputation: 1.4806662797927856
# Average of peers' local losses: 1.900470
# Mixing took 0.01
# -> Update reputation
# [ 0.68512068  0.91858258 -0.08144476  0.87634783  0.75227073  0.7014522
#   0.82813175  0.96929099  0.86788951  0.7963589 ]
# Aggregation took 0.016
#
# Average test loss: 0.6628, Test accuracy: 8526/10000 (85.26%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 98.4
# Two        - 88.3
# Three      - 80.4
# Four       - 94.0
# Five       - 89.0
# Six        - 93.6
# Seven      - 88.4
# Eight      - 80.9
# Nine       - 43.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.19096839427948
# Peer 9  is  honest reputation: 1.7373811602592468
# Peer 12  is  honest reputation: 1.6293691992759705
# Peer 14  is  honest reputation: 1.4925322532653809
# Peer 4  is  honest reputation: 2.1190205216407776
# Peer 17  is  honest reputation: 0.7920956015586853
# Peer 8  is  honest reputation: 1.6702806949615479
# Peer 6  is  honest reputation: 1.8477944731712341
# Peer 18  is  honest reputation: 1.9413763284683228
# Peer 13  is  honest reputation: 1.8464874029159546
# Average of peers' local losses: 0.940099
# Mixing took 0.009
# -> Update reputation
# [0.89813531 0.83977863 0.67054107 0.60121391 0.82524034 0.50490149
#  0.79680856 0.06479081 0.72123751 0.78860968]
# Aggregation took 0.016
#
# Average test loss: 0.4673, Test accuracy: 8918/10000 (89.18%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 97.9
# Two        - 90.3
# Three      - 87.3
# Four       - 95.5
# Five       - 88.8
# Six        - 93.4
# Seven      - 88.7
# Eight      - 83.5
# Nine       - 69.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.3150784969329834
# Peer 6  is  honest reputation: 1.9322431683540344
# Peer 18  is  honest reputation: 1.9796375632286072
# Peer 9  is  honest reputation: 1.8269593119621277
# Peer 14  is  honest reputation: 1.454261600971222
# Peer 5  is  honest reputation: 2.083678424358368
# Peer 4  is  honest reputation: 2.221706449985504
# Peer 17  is  honest reputation: 0.824097216129303
# Peer 16  is  honest reputation: 1.5979170203208923
# Peer 8  is  honest reputation: 1.6694348454475403
# Average of peers' local losses: 0.832315
# Mixing took 0.01
# -> Update reputation
# [0.83425871 0.61910978 0.88936078 0.56799297 0.82034403 0.154528
#  0.89628177 0.74697773 0.74769334 0.76471988]
# Aggregation took 0.016
#
# Average test loss: 0.4125, Test accuracy: 9017/10000 (90.17%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 97.9
# Two        - 90.8
# Three      - 88.2
# Four       - 94.8
# Five       - 89.2
# Six        - 94.1
# Seven      - 90.3
# Eight      - 83.9
# Nine       - 74.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 0.7864240407943726
# Peer 7  is  honest reputation: 2.8396518230438232
# Peer 10  is  honest reputation: 1.4037704467773438
# Peer 17  is  honest reputation: 0.9149914383888245
# Peer 18  is  honest reputation: 1.9170840382575989
# Peer 4  is  honest reputation: 2.212201714515686
# Peer 5  is  honest reputation: 2.178075134754181
# Peer 12  is  honest reputation: 1.5709410905838013
# Peer 16  is  honest reputation: 1.7252980470657349
# Peer 6  is  honest reputation: 1.7667007446289062
# Average of peers' local losses: 0.783666
# Mixing took 0.01
# -> Update reputation
# [0.77616887 0.89010539 0.73775142 0.84512892 0.05421173 0.96866056
#  0.87485342 0.60741553 0.09481063 0.55017806]
# Aggregation took 0.015
#
# Average test loss: 0.3761, Test accuracy: 9065/10000 (90.65%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 98.0
# Two        - 90.4
# Three      - 89.2
# Four       - 94.4
# Five       - 90.7
# Six        - 94.3
# Seven      - 90.6
# Eight      - 84.3
# Nine       - 76.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.8946496844291687
# Peer 7  is  honest reputation: 2.9105003476142883
# Peer 9  is  honest reputation: 1.9611993432044983
# Peer 14  is  honest reputation: 1.4827758073806763
# Peer 4  is  honest reputation: 2.193784773349762
# Peer 15  is  honest reputation: 0.9354810118675232
# Peer 8  is  honest reputation: 1.7269189357757568
# Peer 6  is  honest reputation: 1.876045823097229
# Peer 13  is  honest reputation: 1.8490248918533325
# Peer 10  is  honest reputation: 1.4590213894844055
# Average of peers' local losses: 0.744740
# Mixing took 0.01
# -> Update reputation
# [0.52586536 0.96271615 0.7987601  0.48974877 0.86002958 0.8071914
#  0.73401863 0.21050903 0.90099954 0.06754153]
# Aggregation took 0.015
#
# Average test loss: 0.3539, Test accuracy: 9119/10000 (91.19%)
#
# Class      - Accuracy
# Zero       - 97.1
# One        - 97.9
# Two        - 91.0
# Three      - 89.9
# Four       - 94.5
# Five       - 90.9
# Six        - 94.6
# Seven      - 91.1
# Eight      - 85.2
# Nine       - 79.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.9481680393218994
# Peer 9  is  honest reputation: 2.173981785774231
# Peer 8  is  honest reputation: 1.8179088234901428
# Peer 7  is  honest reputation: 2.8622856438159943
# Peer 12  is  honest reputation: 1.5452003479003906
# Peer 3  is  honest reputation: 2.3390918374061584
# Peer 6  is  honest reputation: 1.975701093673706
# Peer 15  is  honest reputation: 1.0942274332046509
# Peer 10  is  honest reputation: 1.4162532985210419
# Peer 5  is  honest reputation: 2.2628178000450134
# Average of peers' local losses: 0.713930
# Mixing took 0.009
# -> Update reputation
# [0.87459303 0.95425128 0.35610072 0.07555098 0.90119242 0.79635856
#  0.64217191 0.74581866 0.27481898 0.87658611]
# Aggregation took 0.016
# Average test loss: 0.3357, Test accuracy: 9164/10000 (91.64%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 97.8
# Two        - 90.5
# Three      - 90.5
# Four       - 94.3
# Five       - 91.4
# Six        - 94.8
# Seven      - 90.8
# Eight      - 85.4
# Nine       - 82.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 1.9932536482810974
# Peer 13  is  honest reputation: 1.9994391202926636
# Peer 4  is  honest reputation: 2.358028829097748
# Peer 7  is  honest reputation: 2.7819748520851135
# Peer 5  is  honest reputation: 2.2569669485092163
# Peer 10  is  honest reputation: 1.2770888209342957
# Peer 12  is  honest reputation: 1.6665367484092712
# Peer 8  is  honest reputation: 1.8681410551071167
# Peer 14  is  honest reputation: 1.4649363458156586
# Peer 15  is  honest reputation: 1.1867446899414062
# Average of peers' local losses: 0.690191
# Mixing took 0.01
# -> Update reputation
# [0.32151486 0.65355258 0.27884286 0.85784581 0.95582166 0.815316
#  0.52067794 0.74854002 0.79969691 0.87410939]
# Aggregation took 0.016
#
# Average test loss: 0.3190, Test accuracy: 9200/10000 (92.00%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 98.0
# Two        - 90.5
# Three      - 91.2
# Four       - 94.0
# Five       - 91.7
# Six        - 95.2
# Seven      - 91.2
# Eight      - 86.2
# Nine       - 83.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.191102534532547
# Peer 9  is  honest reputation: 2.265508532524109
# Peer 18  is  honest reputation: 2.0792404413223267
# Peer 4  is  honest reputation: 2.1898059248924255
# Peer 15  is  honest reputation: 1.2380113005638123
# Peer 3  is  honest reputation: 2.3832067251205444
# Peer 7  is  honest reputation: 2.7998411059379578
# Peer 16  is  honest reputation: 1.7859119772911072
# Peer 6  is  honest reputation: 2.0024465322494507
# Peer 17  is  honest reputation: 0.980370819568634
# Average of peers' local losses: 0.672641
# Mixing took 0.01
# -> Update reputation
# [0.95516325 0.90851393 0.87887782 0.92265714 0.44672416 0.88084828
#  0.43235962 0.78811077 0.06929001 0.75889176]
# Aggregation took 0.015
#
# Average test loss: 0.3072, Test accuracy: 9225/10000 (92.25%)
#
# Class      - Accuracy
# Zero       - 97.4
# One        - 98.3
# Two        - 91.3
# Three      - 91.1
# Four       - 94.8
# Five       - 92.3
# Six        - 94.9
# Seven      - 91.2
# Eight      - 86.2
# Nine       - 84.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 1.4819450080394745
# Peer 10  is  honest reputation: 1.3485887944698334
# Peer 16  is  honest reputation: 1.8793902397155762
# Peer 3  is  honest reputation: 2.4924011826515198
# Peer 7  is  honest reputation: 2.773393988609314
# Peer 8  is  honest reputation: 1.8743019104003906
# Peer 6  is  honest reputation: 1.9522192478179932
# Peer 17  is  honest reputation: 0.9551948308944702
# Peer 12  is  honest reputation: 1.6861507296562195
# Peer 15  is  honest reputation: 1.366393804550171
# Average of peers' local losses: 0.647821
# Mixing took 0.01
# -> Update reputation
# [0.91542418 0.28487599 0.6452546  0.94395621 0.51070106 0.76284063
#  0.656992   0.71281769 0.10600051 0.46339397]
# Aggregation took 0.015
#
# Average test loss: 0.2939, Test accuracy: 9254/10000 (92.54%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.2
# Two        - 90.9
# Three      - 92.1
# Four       - 95.1
# Five       - 92.4
# Six        - 94.8
# Seven      - 91.4
# Eight      - 86.7
# Nine       - 85.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.047359883785248
# Peer 3  is  honest reputation: 2.556813597679138
# Peer 8  is  honest reputation: 1.7842933237552643
# Peer 15  is  honest reputation: 1.4984153509140015
# Peer 5  is  honest reputation: 2.254913330078125
# Peer 10  is  honest reputation: 1.2897713780403137
# Peer 14  is  honest reputation: 1.5604683458805084
# Peer 17  is  honest reputation: 1.103190839290619
# Peer 9  is  honest reputation: 2.404740333557129
# Peer 18  is  honest reputation: 2.256608724594116
# Average of peers' local losses: 0.623354
# Mixing took 0.009
# -> Update reputation
# [0.51905544 0.75390455 0.86290427 0.69595241 0.84424252 0.91296744
#  0.1131739  0.8637511  0.52819603 0.3527128 ]
# Aggregation took 0.015
#
# Average test loss: 0.2821, Test accuracy: 9260/10000 (92.60%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.2
# Two        - 92.0
# Three      - 91.2
# Four       - 94.7
# Five       - 92.5
# Six        - 95.0
# Seven      - 90.8
# Eight      - 87.1
# Nine       - 86.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/200 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 2.3231787383556366
# Peer 6  is  honest reputation: 1.9997653365135193
# Peer 13  is  honest reputation: 2.0005126297473907
# Peer 7  is  honest reputation: 2.7699642181396484
# Peer 17  is  honest reputation: 1.1322333216667175
# Peer 16  is  honest reputation: 1.8896795213222504
# Peer 10  is  honest reputation: 1.387111097574234
# Peer 18  is  honest reputation: 2.254334330558777
# Peer 4  is  honest reputation: 2.265333890914917
# Peer 8  is  honest reputation: 1.8779802322387695
# Average of peers' local losses: 0.613187
# Mixing took 0.01
# -> Update reputation
# [0.77528519 0.90090147 0.90142104 0.83234874 0.80106776 0.48879416
#  0.80173769 0.95619251 0.07063645 0.84294317]
# Aggregation took 0.015
#
# Average test loss: 0.2735, Test accuracy: 9284/10000 (92.84%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.1
# Two        - 91.9
# Three      - 91.8
# Four       - 95.9
# Five       - 92.6
# Six        - 95.1
# Seven      - 91.7
# Eight      - 87.8
# Nine       - 85.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 31/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 1.606212317943573
# Peer 9  is  honest reputation: 2.326504021883011
# Peer 8  is  honest reputation: 1.9914381504058838
# Peer 15  is  honest reputation: 1.593618482351303
# Peer 5  is  honest reputation: 2.369602292776108
# Peer 18  is  honest reputation: 2.3668372631073
# Peer 10  is  honest reputation: 1.4243275225162506
# Peer 16  is  honest reputation: 1.9232949316501617
# Peer 12  is  honest reputation: 1.7639156579971313
# Peer 13  is  honest reputation: 2.085586756467819
# Average of peers' local losses: 0.586923
# Mixing took 0.01
# -> Update reputation
# [0.90068962 0.90307603 0.8429536  0.82875728 0.67230875 0.46318579
#  0.76020335 0.68553548 0.90061444 0.81840298]
# Aggregation took 0.015
#
# Average test loss: 0.2644, Test accuracy: 9308/10000 (93.08%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.2
# Two        - 91.8
# Three      - 92.3
# Four       - 96.2
# Five       - 92.9
# Six        - 95.0
# Seven      - 91.7
# Eight      - 87.4
# Nine       - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 32/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 2.0740077793598175
# Peer 6  is  honest reputation: 1.9933107495307922
# Peer 8  is  honest reputation: 2.1211445331573486
# Peer 14  is  honest reputation: 1.704797089099884
# Peer 9  is  honest reputation: 2.365315616130829
# Peer 17  is  honest reputation: 0.9606070816516876
# Peer 4  is  honest reputation: 2.121108502149582
# Peer 5  is  honest reputation: 2.3657137751579285
# Peer 3  is  honest reputation: 2.5636368095874786
# Peer 12  is  honest reputation: 1.886549472808838
# Average of peers' local losses: 0.581048
# Mixing took 0.009
# -> Update reputation
# [0.79627881 0.89353441 0.84085975 0.82941315 0.07015469 0.94875549
#  0.93085286 0.65006375]
# Aggregation took 0.013
#
# Average test loss: 0.2574, Test accuracy: 9320/10000 (93.20%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.4
# Two        - 91.8
# Three      - 92.4
# Four       - 96.3
# Five       - 92.5
# Six        - 95.1
# Seven      - 91.9
# Eight      - 87.9
# Nine       - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 33/200 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 2.1211445331573486
# Peer 14  is  honest reputation: 1.663809448480606
# Peer 10  is  honest reputation: 1.3912124633789062
# Peer 18  is  honest reputation: 2.3785027861595154
# Peer 3  is  honest reputation: 2.7075692415237427
# Peer 5  is  honest reputation: 2.553140550851822
# Peer 6  is  honest reputation: 2.112501382827759
# Peer 15  is  honest reputation: 1.7293364703655243
# Peer 4  is  honest reputation: 2.3275896310806274
# Peer 12  is  honest reputation: 1.9767604172229767
# Average of peers' local losses: 0.566644
# Mixing took 0.01
# -> Update reputation
# [0.95151117 0.78759244 0.84866471 0.6318513  0.93482854 0.92506238
#  0.79865123 0.46903229 0.86546667 0.90297395]
# Aggregation took 0.016
# Average test loss: 0.2472, Test accuracy: 9345/10000 (93.45%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.0
# Two        - 92.2
# Three      - 92.2
# Four       - 96.0
# Five       - 93.5
# Six        - 95.1
# Seven      - 91.4
# Eight      - 88.5
# Nine       - 88.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 34/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.0418147146701813
# Peer 8  is  honest reputation: 2.20312762260437
# Peer 17  is  honest reputation: 0.9586704671382904
# Peer 15  is  honest reputation: 1.9832772314548492
# Peer 18  is  honest reputation: 2.3764971792697906
# Peer 12  is  honest reputation: 1.95345938205719
# Peer 5  is  honest reputation: 2.583776533603668
# Peer 4  is  honest reputation: 2.5114291310310364
# Peer 16  is  honest reputation: 2.0746533274650574
# Peer 14  is  honest reputation: 1.6328920722007751
# Average of peers' local losses: 0.546358
# Mixing took 0.008
# -> Update reputation
# [0.9204215  0.61796918 0.07166565 0.94616282 0.86109329 0.86980056
#  0.91316379 0.80942903]
# Aggregation took 0.014
#
# Average test loss: 0.2418, Test accuracy: 9368/10000 (93.68%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.2
# Two        - 91.9
# Three      - 93.3
# Four       - 96.1
# Five       - 92.8
# Six        - 95.2
# Seven      - 92.2
# Eight      - 89.6
# Nine       - 88.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 35/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 0.9647448360919952
# Peer 3  is  honest reputation: 2.7359132766723633
# Peer 9  is  honest reputation: 2.365315616130829
# Peer 18  is  honest reputation: 2.439201056957245
# Peer 8  is  honest reputation: 2.2252159416675568
# Peer 4  is  honest reputation: 2.484734147787094
# Peer 7  is  honest reputation: 2.7893280386924744
# Peer 14  is  honest reputation: 1.614668995141983
# Peer 6  is  honest reputation: 2.1397608518600464
# Peer 16  is  honest reputation: 2.1905145347118378
# Average of peers' local losses: 0.551821
# Mixing took 0.008
# -> Update reputation
# [0.12177408 0.74297944 0.80102637 0.83766933 0.87987226 0.90776737
#  0.90511712 0.93756327]
# Aggregation took 0.013
#
# Average test loss: 0.2342, Test accuracy: 9382/10000 (93.82%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 92.1
# Three      - 93.9
# Four       - 96.3
# Five       - 93.6
# Six        - 95.4
# Seven      - 91.5
# Eight      - 89.7
# Nine       - 88.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 36/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.0418147146701813
# Peer 15  is  honest reputation: 1.9832772314548492
# Peer 17  is  honest reputation: 1.1671156287193298
# Peer 4  is  honest reputation: 2.544561952352524
# Peer 3  is  honest reputation: 2.7622505724430084
# Peer 16  is  honest reputation: 2.2580431699752808
# Peer 18  is  honest reputation: 2.5594216883182526
# Peer 6  is  honest reputation: 2.0018317997455597
# Peer 9  is  honest reputation: 2.4199359118938446
# Peer 8  is  honest reputation: 2.1462040543556213
# Average of peers' local losses: 0.536882
# Mixing took 0.01
# -> Update reputation
# [0.71559612 0.75187852 0.88107936 0.94095974 0.78578714 0.13952854
#  0.73579503 0.82663308 0.86587683 0.86923507]
# Aggregation took 0.016
#
# Average test loss: 0.2321, Test accuracy: 9388/10000 (93.88%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 92.8
# Three      - 93.5
# Four       - 95.9
# Five       - 93.7
# Six        - 95.5
# Seven      - 91.5
# Eight      - 89.6
# Nine       - 89.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 37/200 |
#
#
# Selected Peers:
# Peer 8  is  honest reputation: 2.1592462956905365
# Peer 9  is  honest reputation: 2.479496419429779
# Peer 5  is  honest reputation: 2.6867814362049103
# Peer 14  is  honest reputation: 1.614668995141983
# Peer 17  is  honest reputation: 1.2393688261508942
# Peer 15  is  honest reputation: 2.0401719212532043
# Peer 12  is  honest reputation: 2.018327087163925
# Peer 10  is  honest reputation: 1.3972293138504028
# Peer 18  is  honest reputation: 2.428865760564804
# Peer 6  is  honest reputation: 1.9974843859672546
# Average of peers' local losses: 0.525696
# Mixing took 0.01
# -> Update reputation
# [0.76735051 0.72537002 0.74176664 0.80552482 0.91807963 0.13782367
#  0.90414932 0.31346159 0.5663116  0.87614454]
# Aggregation took 0.016
#
# Average test loss: 0.2242, Test accuracy: 9403/10000 (94.03%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.1
# Two        - 92.7
# Three      - 93.0
# Four       - 96.3
# Five       - 94.2
# Six        - 95.7
# Seven      - 91.5
# Eight      - 90.6
# Nine       - 89.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 38/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 2.7893280386924744
# Peer 9  is  honest reputation: 2.5882087647914886
# Peer 10  is  honest reputation: 1.4180888235569
# Peer 6  is  honest reputation: 2.1075611412525177
# Peer 13  is  honest reputation: 2.0761868357658386
# Peer 5  is  honest reputation: 2.670375257730484
# Peer 17  is  honest reputation: 1.232415646314621
# Peer 3  is  honest reputation: 2.845283269882202
# Peer 18  is  honest reputation: 2.4526386857032776
# Peer 14  is  honest reputation: 1.7357854843139648
# Average of peers' local losses: 0.524843
# Mixing took 0.01
# -> Update reputation
# [0.77194015 0.9190308  0.94064233 0.91264199 0.26070432 0.58451334
#  0.91939756 0.14139242 0.89266164 0.74895819]
# Aggregation took 0.015
#
# Average test loss: 0.2198, Test accuracy: 9416/10000 (94.16%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.1
# Two        - 93.3
# Three      - 93.5
# Four       - 96.3
# Five       - 94.1
# Six        - 95.8
# Seven      - 91.9
# Eight      - 90.1
# Nine       - 89.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 39/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 2.129739433526993
# Peer 5  is  honest reputation: 2.6873816549777985
# Peer 18  is  honest reputation: 2.5395049452781677
# Peer 12  is  honest reputation: 2.0481049716472626
# Peer 9  is  honest reputation: 2.647741347551346
# Peer 16  is  honest reputation: 2.276333838701248
# Peer 10  is  honest reputation: 1.2469744086265564
# Peer 14  is  honest reputation: 1.7739193439483643
# Peer 3  is  honest reputation: 2.84822478890419
# Peer 8  is  honest reputation: 2.207860231399536
# Average of peers' local losses: 0.501737
# Mixing took 0.009
# -> Update reputation
# [0.50084316 0.8260862  0.93501806 0.87404829 0.80796161 0.89277245
#  0.79029048 0.1717914 ]
# Aggregation took 0.013
#
# Average test loss: 0.2150, Test accuracy: 9418/10000 (94.18%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.3
# Two        - 93.4
# Three      - 93.5
# Four       - 96.3
# Five       - 93.8
# Six        - 96.0
# Seven      - 91.8
# Eight      - 90.0
# Nine       - 89.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 40/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 2.012595295906067
# Peer 5  is  honest reputation: 2.633439004421234
# Peer 18  is  honest reputation: 2.5479955077171326
# Peer 17  is  honest reputation: 1.3714922368526459
# Peer 8  is  honest reputation: 2.2702215909957886
# Peer 4  is  honest reputation: 2.415288031101227
# Peer 13  is  honest reputation: 2.0752063393592834
# Peer 9  is  honest reputation: 2.8948979675769806
# Peer 12  is  honest reputation: 2.0481049716472626
# Peer 3  is  honest reputation: 2.84822478890419
# Average of peers' local losses: 0.506868
# Mixing took 0.01
# -> Update reputation
# [0.74478755 0.80542688 0.89875323 0.3327554  0.8660036  0.65701035
#  0.76135496 0.94753471 0.83582065 0.946553  ]
# Aggregation took 0.016
#
# Average test loss: 0.2120, Test accuracy: 9428/10000 (94.28%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.1
# Two        - 93.4
# Three      - 93.7
# Four       - 96.1
# Five       - 94.8
# Six        - 95.8
# Seven      - 92.0
# Eight      - 90.1
# Nine       - 90.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 41/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 1.5439675152301788
# Peer 13  is  honest reputation: 2.159189820289612
# Peer 7  is  honest reputation: 2.6897471249103546
# Peer 14  is  honest reputation: 1.7484476566314697
# Peer 9  is  honest reputation: 2.995606392621994
# Peer 12  is  honest reputation: 1.9855789542198181
# Peer 8  is  honest reputation: 2.3119161128997803
# Peer 4  is  honest reputation: 2.4051876962184906
# Peer 18  is  honest reputation: 2.514914631843567
# Peer 10  is  honest reputation: 1.3715286254882812
# Average of peers' local losses: 0.496671
# Mixing took 0.01
# -> Update reputation
# [0.77645672 0.21242963 0.84730946 0.62638195 0.68373105 0.21526979
#  0.94575028 0.41250561 0.73293555 0.84429441]
# Aggregation took 0.016
# Average test loss: 0.2066, Test accuracy: 9431/10000 (94.31%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.2
# Two        - 93.6
# Three      - 93.8
# Four       - 96.0
# Five       - 94.5
# Six        - 95.8
# Seven      - 92.0
# Eight      - 90.5
# Nine       - 90.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 42/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 2.259774297475815
# Peer 8  is  honest reputation: 2.3611187636852264
# Peer 17  is  honest reputation: 1.5434239506721497
# Peer 7  is  honest reputation: 2.560675770044327
# Peer 13  is  honest reputation: 2.1608205139636993
# Peer 3  is  honest reputation: 3.0051278173923492
# Peer 9  is  honest reputation: 3.1146358251571655
# Peer 10  is  honest reputation: 1.5404476821422577
# Peer 16  is  honest reputation: 2.373701900243759
# Peer 15  is  honest reputation: 2.1974746584892273
# Average of peers' local losses: 0.487365
# Mixing took 0.01
# -> Update reputation
# [0.37356609 0.71125169 0.83107789 0.84104362 0.76995449 0.85205292
#  0.78499908 0.96440938 0.18971299 0.96483519]
# Aggregation took 0.015
#
# Average test loss: 0.2023, Test accuracy: 9436/10000 (94.36%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.5
# Two        - 93.7
# Three      - 93.5
# Four       - 96.5
# Five       - 94.4
# Six        - 95.7
# Seven      - 91.6
# Eight      - 90.6
# Nine       - 90.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 43/200 |
#
#
# Selected Peers:
# Peer 3  is  honest reputation: 3.2591406404972076
# Peer 16  is  honest reputation: 2.4784372746944427
# Peer 14  is  honest reputation: 1.7633601129055023
# Peer 8  is  honest reputation: 2.445319414138794
# Peer 6  is  honest reputation: 2.3191466629505157
# Peer 9  is  honest reputation: 3.265267074108124
# Peer 17  is  honest reputation: 1.6462694108486176
# Peer 13  is  honest reputation: 2.1434207260608673
# Peer 12  is  honest reputation: 2.060172826051712
# Peer 18  is  honest reputation: 2.5712693631649017
# Average of peers' local losses: 0.474353
# Mixing took 0.01
# -> Update reputation
# [0.41333879 0.6588476  0.81710919 0.96929533 0.75062666 0.80629405
#  0.56842907 0.97135541 0.86659675 0.8241997 ]
# Aggregation took 0.015
#
# Average test loss: 0.1990, Test accuracy: 9443/10000 (94.43%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.2
# Two        - 93.8
# Three      - 94.0
# Four       - 96.5
# Five       - 94.4
# Six        - 96.0
# Seven      - 91.8
# Eight      - 90.6
# Nine       - 90.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 44/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 2.517305910587311
# Peer 8  is  honest reputation: 2.370053857564926
# Peer 6  is  honest reputation: 2.423482209444046
# Peer 4  is  honest reputation: 2.3119736909866333
# Peer 5  is  honest reputation: 2.663739949464798
# Peer 15  is  honest reputation: 2.273924231529236
# Peer 3  is  honest reputation: 3.369464337825775
# Peer 12  is  honest reputation: 2.044482797384262
# Peer 18  is  honest reputation: 2.401764675974846
# Peer 10  is  honest reputation: 1.4457476735115051
# Average of peers' local losses: 0.478333
# Mixing took 0.008
# -> Update reputation
# [0.91534908 0.81408389 0.21826688 0.79933118 0.78389232 0.74011381
#  0.77511109 0.96184587]
# Aggregation took 0.013
#
# Average test loss: 0.1946, Test accuracy: 9456/10000 (94.56%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.2
# Two        - 93.3
# Three      - 94.5
# Four       - 96.5
# Five       - 94.3
# Six        - 95.9
# Seven      - 91.9
# Eight      - 91.0
# Nine       - 91.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 45/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 2.5729560554027557
# Peer 4  is  honest reputation: 2.2938276529312134
# Peer 13  is  honest reputation: 2.228097230195999
# Peer 7  is  honest reputation: 2.517305910587311
# Peer 5  is  honest reputation: 2.9026562571525574
# Peer 17  is  honest reputation: 1.6933395564556122
# Peer 14  is  honest reputation: 1.8989072144031525
# Peer 18  is  honest reputation: 2.439853861927986
# Peer 3  is  honest reputation: 3.313100188970566
# Peer 9  is  honest reputation: 3.334216356277466
# Average of peers' local losses: 0.469027
# Mixing took 0.009
# -> Update reputation
# [0.76083777 0.82746132 0.81719474 0.63642074 0.97429541 0.93151172
#  0.96211824 0.83462618]
# Aggregation took 0.013
#
# Average test loss: 0.1918, Test accuracy: 9461/10000 (94.61%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.4
# Two        - 93.8
# Three      - 94.3
# Four       - 96.6
# Five       - 94.3
# Six        - 96.0
# Seven      - 92.2
# Eight      - 90.7
# Nine       - 90.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 46/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.3412981033325195
# Peer 8  is  honest reputation: 2.376102536916733
# Peer 4  is  honest reputation: 2.2938276529312134
# Peer 12  is  honest reputation: 2.044482797384262
# Peer 7  is  honest reputation: 2.5231274366378784
# Peer 18  is  honest reputation: 2.491410568356514
# Peer 15  is  honest reputation: 2.3984847366809845
# Peer 9  is  honest reputation: 3.3167518079280853
# Peer 16  is  honest reputation: 2.5462904274463654
# Peer 10  is  honest reputation: 1.5649322271347046
# Average of peers' local losses: 0.462065
# Mixing took 0.01
# -> Update reputation
# [0.81432677 0.70650034 0.85831299 0.78560014 0.83999754 0.61987362
#  0.95813727 0.23733399 0.72587908 0.75456019]
# Aggregation took 0.016
#
# Average test loss: 0.1892, Test accuracy: 9467/10000 (94.67%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.3
# Two        - 93.8
# Three      - 93.9
# Four       - 96.3
# Five       - 94.6
# Six        - 96.3
# Seven      - 92.9
# Eight      - 91.0
# Nine       - 90.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 47/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 2.386892020702362
# ...
# Peer 4  is  honest reputation: 2.4382259845733643
# Peer 10  is  honest reputation: 1.7280907928943634
# Peer 7  is  honest reputation: 2.717708468437195
# Peer 18  is  honest reputation: 2.8625039607286453
# Peer 16  is  honest reputation: 2.635484427213669
# Peer 12  is  honest reputation: 2.5207830369472504
# Peer 6  is  honest reputation: 2.5864857733249664
# Average of peers' local losses: 0.432245
# Mixing took 0.009
# -> Update reputation
# [0.83914592 0.26784832 0.82001683 0.96249924 0.82288591 0.88669878
#  0.75100643 0.79163344 0.96547091 0.83677154]
# Aggregation took 0.016
#
# Average test loss: 0.1745, Test accuracy: 9495/10000 (94.95%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 95.0
# Three      - 94.4
# Four       - 96.5
# Five       - 94.4
# Six        - 96.5
# Seven      - 92.8
# Eight      - 91.6
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 52/200 |
#
#
# Selected Peers:
# Peer 10  is  honest reputation: 1.7362136244773865
# Peer 15  is  honest reputation: 2.436928689479828
# Peer 4  is  honest reputation: 2.6273602843284607
# Peer 9  is  honest reputation: 3.4404756128787994
# Peer 14  is  honest reputation: 2.1997478306293488
# Peer 13  is  honest reputation: 2.668835371732712
# Peer 7  is  honest reputation: 2.6719761788845062
# Peer 6  is  honest reputation: 2.6185380816459656
# Peer 18  is  honest reputation: 2.867936208844185
# Peer 12  is  honest reputation: 2.5374613106250763
# Average of peers' local losses: 0.434249
# Mixing took 0.01
# -> Update reputation
# [0.96664511 0.83587854 0.80853492 0.79818333 0.807697   0.75486662
#  0.91164464 0.83336195 0.2961426  0.71319325]
# Aggregation took 0.015
#
# Average test loss: 0.1732, Test accuracy: 9501/10000 (95.01%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 94.7
# Three      - 94.3
# Four       - 96.5
# Five       - 94.8
# Six        - 96.5
# Seven      - 92.5
# Eight      - 91.6
# Nine       - 92.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 53/200 |
#
#
# Selected Peers:
# Peer 14  is  honest reputation: 2.3553220629692078
# Peer 7  is  honest reputation: 2.6690050661563873
# Peer 17  is  honest reputation: 1.723028987646103
# Peer 6  is  honest reputation: 2.6607105433940887
# Peer 10  is  honest reputation: 1.7669552862644196
# Peer 16  is  honest reputation: 2.679948717355728
# Peer 18  is  honest reputation: 2.9988453835248947
# Peer 13  is  honest reputation: 2.5552554726600647
# Peer 12  is  honest reputation: 2.582037568092346
# Peer 8  is  honest reputation: 2.1256531178951263
# Average of peers' local losses: 0.420295
# Mixing took 0.006
# -> Update reputation
# [0.31138045 0.7105047  0.80404035 0.76488898 0.81625174 0.84581564]
# Aggregation took 0.011
#
# Average test loss: 0.1693, Test accuracy: 9506/10000 (95.06%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.2
# Two        - 94.9
# Three      - 95.0
# Four       - 96.7
# Five       - 95.0
# Six        - 96.2
# Seven      - 92.0
# Eight      - 91.9
# Nine       - 91.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 54/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 2.5844526886940002
# Peer 12  is  honest reputation: 2.607150971889496
# Peer 10  is  honest reputation: 1.7837425768375397
# Peer 18  is  honest reputation: 2.9988453835248947
# Peer 3  is  honest reputation: 3.4825117588043213
# Peer 9  is  honest reputation: 3.5001092851161957
# Peer 5  is  honest reputation: 3.3112727403640747
# Peer 14  is  honest reputation: 2.349871575832367
# Peer 13  is  honest reputation: 2.5716068744659424
# Peer 16  is  honest reputation: 2.679948717355728
# Average of peers' local losses: 0.424226
# Mixing took 0.01
# -> Update reputation
# [0.96843401 0.97261283 0.83148645 0.92432546 0.73077125 0.94960731
#  0.79986182 0.80422847 0.82764354 0.36692757]
# Aggregation took 0.016
#
# Average test loss: 0.1684, Test accuracy: 9510/10000 (95.10%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 94.9
# Three      - 94.7
# Four       - 97.1
# Five       - 95.1
# Six        - 96.3
# Seven      - 92.8
# Eight      - 91.5
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 55/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.5598978102207184
# Peer 3  is  honest reputation: 3.5281259417533875
# Peer 18  is  honest reputation: 3.079613760113716
# Peer 14  is  honest reputation: 2.392049729824066
# Peer 5  is  honest reputation: 3.289437770843506
# Peer 6  is  honest reputation: 2.702932983636856
# Peer 16  is  honest reputation: 2.572139233350754
# Peer 15  is  honest reputation: 2.445842057466507
# Peer 17  is  honest reputation: 1.723028987646103
# Peer 12  is  honest reputation: 2.6422781944274902
# Average of peers' local losses: 0.407264
# Mixing took 0.008
# -> Update reputation
# [0.949286   0.97474966 0.85434621 0.85603054 0.75972466 0.25682837
#  0.81986382 0.72776582]
# Aggregation took 0.014
#
# Average test loss: 0.1676, Test accuracy: 9521/10000 (95.21%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.5
# Two        - 95.3
# Three      - 95.0
# Four       - 97.3
# Five       - 95.2
# Six        - 96.2
# Seven      - 92.8
# Eight      - 91.3
# Nine       - 91.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 56/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.5598978102207184
# Peer 15  is  honest reputation: 2.461282968521118
# Peer 5  is  honest reputation: 3.2902275919914246
# Peer 9  is  honest reputation: 3.6001890897750854
# Peer 18  is  honest reputation: 3.079613760113716
# Peer 7  is  honest reputation: 2.469561845064163
# Peer 6  is  honest reputation: 2.7440164983272552
# Peer 12  is  honest reputation: 2.6221213340759277
# Peer 10  is  honest reputation: 1.8465372323989868
# Peer 4  is  honest reputation: 2.654602736234665
# Average of peers' local losses: 0.416528
# Mixing took 0.009
# -> Update reputation
# [0.96504425 0.94809428 0.82116205 0.4352178  0.86487913 0.93287286
#  0.8690299  0.81286596]
# Aggregation took 0.013
#
# Average test loss: 0.1643, Test accuracy: 9523/10000 (95.23%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.5
# Two        - 95.2
# Three      - 95.0
# Four       - 96.7
# Five       - 95.4
# Six        - 96.7
# Seven      - 92.9
# Eight      - 91.4
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 57/200 |
#
#
# Selected Peers:
# Peer 4  is  honest reputation: 2.778110295534134
# Peer 6  is  honest reputation: 2.7948223054409027
# Peer 7  is  honest reputation: 2.469561845064163
# Peer 12  is  honest reputation: 2.626094400882721
# Peer 5  is  honest reputation: 3.2783083319664
# Peer 13  is  honest reputation: 2.6011389791965485
# Peer 14  is  honest reputation: 2.3896802961826324
# Peer 15  is  honest reputation: 2.461282968521118
# Peer 8  is  honest reputation: 2.1256531178951263
# Peer 3  is  honest reputation: 3.645398050546646
# Average of peers' local losses: 0.406982
# Mixing took 0.008
# -> Update reputation
# [0.75794152 0.97495629 0.94039345 0.87650121 0.80947769 0.75120201
#  0.87763193 0.87197826]
# Aggregation took 0.013
# Average test loss: 0.1633, Test accuracy: 9517/10000 (95.17%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 95.3
# Three      - 95.0
# Four       - 96.8
# Five       - 95.5
# Six        - 96.7
# Seven      - 92.7
# Eight      - 91.3
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 58/200 |
#
#
# Selected Peers:
# Peer 15  is  honest reputation: 2.5912315249443054
# Peer 17  is  honest reputation: 1.728429228067398
# Peer 9  is  honest reputation: 3.4803129136562347
# Peer 6  is  honest reputation: 2.8069948852062225
# Peer 5  is  honest reputation: 3.207159698009491
# Peer 8  is  honest reputation: 2.1256531178951263
# Peer 3  is  honest reputation: 3.6495589315891266
# Peer 16  is  honest reputation: 2.7377468943595886
# Peer 10  is  honest reputation: 1.9320352673530579
# Peer 12  is  honest reputation: 2.826185882091522
# Average of peers' local losses: 0.398079
# Mixing took 0.007
# -> Update reputation
# [0.90342529 0.88699639 0.78103362 0.39941759 0.9060854  0.9760159 ]
# Aggregation took 0.01
#
# Average test loss: 0.1597, Test accuracy: 9528/10000 (95.28%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 95.2
# Three      - 95.4
# Four       - 96.9
# Five       - 95.1
# Six        - 96.5
# Seven      - 92.8
# Eight      - 91.9
# Nine       - 91.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 59/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 1.728429228067398
# Peer 9  is  honest reputation: 3.6714427173137665
# Peer 14  is  honest reputation: 2.441427618265152
# Peer 4  is  honest reputation: 2.8310860097408295
# Peer 3  is  honest reputation: 3.6495589315891266
# Peer 7  is  honest reputation: 2.457079142332077
# Peer 10  is  honest reputation: 1.888675183057785
# Peer 8  is  honest reputation: 2.1256531178951263
# Peer 12  is  honest reputation: 2.9562661051750183
# Peer 6  is  honest reputation: 2.9709299504756927
# Average of peers' local losses: 0.405150
# Mixing took 0.009
# -> Update reputation
# [0.97469728 0.78331598 0.8962495  0.97289948 0.86124994 0.89313187
#  0.27540083 0.59687707 0.39515069 0.54107795]
# Aggregation took 0.016
#
# Average test loss: 0.1598, Test accuracy: 9532/10000 (95.32%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 95.5
# Three      - 95.0
# Four       - 96.7
# Five       - 95.5
# Six        - 96.7
# Seven      - 92.9
# Eight      - 91.5
# Nine       - 92.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 60/200 |
#
#
# Selected Peers:
# Peer 7  is  honest reputation: 2.2139674723148346
# Peer 6  is  honest reputation: 2.9785078167915344
# Peer 16  is  honest reputation: 2.8733803629875183
# Peer 18  is  honest reputation: 3.1458065658807755
# Peer 9  is  honest reputation: 3.6695390343666077
# Peer 5  is  honest reputation: 3.207159698009491
# Peer 14  is  honest reputation: 2.5795804858207703
# Peer 4  is  honest reputation: 2.9628817439079285
# Peer 3  is  honest reputation: 3.7043149769306183
# Peer 10  is  honest reputation: 1.943574845790863
# Average of peers' local losses: 0.404036
# Mixing took 0.008
# -> Update reputation
# [0.84846991 0.93975489 0.97394272 0.97958954 0.43377041 0.94548469
#  0.52152748 0.88039468]
# Aggregation took 0.013
#
# Average test loss: 0.1574, Test accuracy: 9550/10000 (95.50%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.2
# Two        - 95.6
# Three      - 95.1
# Four       - 97.0
# Five       - 95.6
# Six        - 97.0
# Seven      - 93.2
# Eight      - 92.4
# Nine       - 92.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 61/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.6011389791965485
# Peer 12  is  honest reputation: 2.8238503634929657
# Peer 7  is  honest reputation: 2.104121297597885
# Peer 14  is  honest reputation: 2.7763503193855286
# Peer 9  is  honest reputation: 3.6894311010837555
# Peer 10  is  honest reputation: 1.9902172982692719
# Peer 15  is  honest reputation: 2.5137348771095276
# Peer 16  is  honest reputation: 2.8733803629875183
# Peer 17  is  honest reputation: 1.8083842396736145
# Peer 6  is  honest reputation: 2.9785078167915344
# Average of peers' local losses: 0.393184
# Mixing took 0.009
# -> Update reputation
# [0.75720542 0.50689188 0.87959921 0.80472119 0.5750702  0.85874156
#  0.97615024 0.90006146]
# Aggregation took 0.013
#
# Average test loss: 0.1555, Test accuracy: 9554/10000 (95.54%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 95.4
# Three      - 95.4
# Four       - 96.7
# Five       - 95.7
# Six        - 96.8
# Seven      - 93.4
# Eight      - 92.5
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 62/200 |
#
#
# Selected Peers:
# Peer 6  is  honest reputation: 2.9982287287712097
# Peer 5  is  honest reputation: 3.3130781054496765
# Peer 12  is  honest reputation: 2.8238503634929657
# Peer 9  is  honest reputation: 3.7342516481876373
# Peer 18  is  honest reputation: 3.261633411049843
# Peer 4  is  honest reputation: 2.90320548415184
# Peer 16  is  honest reputation: 2.8142175674438477
# Peer 13  is  honest reputation: 2.5153177976608276
# Peer 15  is  honest reputation: 2.6375522017478943
# Peer 7  is  honest reputation: 2.180751234292984
# Average of peers' local losses: 0.389356
# Mixing took 0.01
# -> Update reputation
# [0.87190588 0.89215324 0.86523185 0.5676037  0.8161316  0.98151727
#  0.89731172 0.8053616  0.95470899 0.9599616 ]
# Aggregation took 0.016
#
# Average test loss: 0.1539, Test accuracy: 9555/10000 (95.55%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.6
# Two        - 95.4
# Three      - 95.0
# Four       - 96.9
# Five       - 96.1
# Six        - 96.7
# Seven      - 93.3
# Eight      - 92.1
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 63/200 |
#
#
# Selected Peers:
# Peer 16  is  honest reputation: 2.8666592240333557
# Peer 8  is  honest reputation: 2.131364196538925
# Peer 15  is  honest reputation: 2.6708075404167175
# Peer 5  is  honest reputation: 3.4711062014102936
# Peer 9  is  honest reputation: 3.8630762696266174
# Peer 6  is  honest reputation: 2.958065390586853
# Peer 7  is  honest reputation: 2.169666111469269
# Peer 4  is  honest reputation: 2.8394780308008194
# Peer 13  is  honest reputation: 2.639372020959854
# Peer 18  is  honest reputation: 3.408129647374153
# Average of peers' local losses: 0.380215
# Mixing took 0.009
# -> Update reputation
# [0.9811915  0.88886785 0.58526574 0.96130589 0.60091773 0.96683374
#  0.83638723 0.83854839 0.88004348 0.81748024]
# Aggregation took 0.016
#
# Average test loss: 0.1524, Test accuracy: 9554/10000 (95.54%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.3
# Two        - 95.4
# Three      - 95.1
# Four       - 97.3
# Five       - 96.0
# Six        - 96.9
# Seven      - 93.8
# Eight      - 92.0
# Nine       - 91.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 64/200 |
#
#
# Selected Peers:
# Peer 13  is  honest reputation: 2.6748596131801605
# Peer 8  is  honest reputation: 2.220268040895462
# Peer 4  is  honest reputation: 2.9016460925340652
# Peer 3  is  honest reputation: 3.812984198331833
# Peer 10  is  honest reputation: 2.084223657846451
# Peer 14  is  honest reputation: 2.8996795415878296
# Peer 5  is  honest reputation: 3.5670092403888702
# Peer 18  is  honest reputation: 3.488524928689003
# Peer 16  is  honest reputation: 2.734712153673172
# Peer 7  is  honest reputation: 2.1961203515529633
# Average of peers' local losses: 0.396184
# Mixing took 0.01
# -> Update reputation
# [0.89204315 0.9876017  0.88229827 0.62939214 0.95500184 0.54700751
#  0.83537414 0.52450554 0.97925209 0.84408647]
# Aggregation took 0.015
#
# Average test loss: 0.1520, Test accuracy: 9561/10000 (95.61%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.6
# Two        - 95.3
# Three      - 95.4
# Four       - 96.7
# Five       - 96.1
# Six        - 96.9
# Seven      - 93.4
# Eight      - 92.0
# Nine       - 93.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 65/200 |
#
#
# Selected Peers:
# Peer 17  is  honest reputation: 1.8083842396736145
# Peer 4  is  honest reputation: 2.9117332249879837
# Peer 3  is  honest reputation: 4.064247876405716
# Peer 14  is  honest reputation: 2.95752614736557
# Peer 8  is  honest reputation: 2.2660945653915405
# Peer 15  is  honest reputation: 2.741948753595352
# Peer 5  is  honest reputation: 3.8047001659870148
# Peer 7  is  honest reputation: 2.1082207560539246
# Peer 12  is  honest reputation: 2.9839333295822144
# Peer 16  is  honest reputation: 2.7313497960567474
# Average of peers' local losses: 0.379869
# Mixing took 0.011
# -> Update reputation
# [0.98054256 0.93283946 0.87789217 0.75330693 0.85030431 0.52322044
#  0.89883578 0.27331092 0.86355292 0.99092949]
# Aggregation took 0.016
# Average test loss: 0.1486, Test accuracy: 9562/10000 (95.62%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.1
# Two        - 95.9
# Three      - 95.4
# Four       - 96.6
# Five       - 96.0
# Six        - 96.9
# Seven      - 92.9
# Eight      - 92.9
# Nine       - 92.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 66/200 |
#
#
# Selected Peers:
# Peer 5  is  honest reputation: 3.8303538858890533
# Peer 12  is  honest reputation: 3.1987353563308716
# Peer 13  is  honest reputation: 2.7609045207500458
# Peer 6  is  honest reputation: 2.942192107439041
# Peer 15  is  honest reputation: 2.8260572254657745
# Peer 7  is  honest reputation: 2.0996695160865784
# Peer 17  is  honest reputation: 1.799344152212143
# Peer 8  is  honest reputation: 2.499462604522705
# Peer 3  is  honest reputation: 4.214570075273514
# Peer 16  is  honest reputation: 2.776156038045883

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
