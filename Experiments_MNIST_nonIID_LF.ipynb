# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'NON_IID'
ALPHA = 0.5
NUM_PEERS = 100 # "number of peers: K" 
FRAC_PEERS = 0.5 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 200 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.001#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA,strategy = 's1', resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1',resume = False)

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's1', resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 96
# Data set: MNIST
# Data distribution: NON_IID
# Aggregation rule: ffl
# Attack Type: label_flipping
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
# Attack Strategy: s1
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  | Global training round : 1/200 |
#
#
# Selected Peers:
# Peer 94  is  honest reputation: 0.0
# Peer 34  is  attacker reputation: 0.0
# Peer 28  is  attacker reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 65  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.0
# Peer 2  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 36  is  honest reputation: 0.0
# Peer 73  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 18  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 60  is  attacker reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 90  is  attacker reputation: 0.0
# Peer 71  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 45  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.0
# Peer 38  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.0
# Peer 96  is  honest reputation: 0.0
# Peer 8  is  attacker reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 89  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.0
# Peer 13  is  attacker reputation: 0.0
# Peer 32  is  attacker reputation: 0.0
# Peer 92  is  attacker reputation: 0.0
# Peer 97  is  attacker reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 61  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Average of peers' local losses: 2.225669
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.03
#
# Average test loss: 2.2875, Test accuracy: 1071/10000 (10.71%)
#
# Class      - Accuracy
# Zero       - 0.2
# One        - 64.2
# Two        - 10.9
# Three      - 0.0
# Four       - 0.0
# Five       - 0.8
# Six        - 2.1
# Seven      - 1.4
# Eight      - 0.4
# Nine       - 18.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/200 |
#
#
# Selected Peers:
# Peer 31  is  honest reputation: 0.17795045673847198
# Peer 95  is  honest reputation: 0.0
# Peer 4  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 70  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.0
# Peer 29  is  attacker reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 27  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.05796457827091217
# Peer 91  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.10213862359523773
# Peer 37  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.15624360740184784
# Peer 11  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.0
# Peer 15  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.1092054694890976
# Peer 49  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0
# Peer 25  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 78  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.0
# Peer 80  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.0
# Peer 17  is  honest reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.0
# Peer 34  is  attacker reputation: 0.0
# Peer 18  is  honest reputation: 0.08308498561382294
# Peer 87  is  attacker reputation: 0.0
# Peer 98  is  attacker reputation: 0.0
# Peer 21  is  attacker reputation: 0.0
# Peer 90  is  attacker reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 32  is  attacker reputation: 0.13730384409427643
# Peer 65  is  honest reputation: 0.07692201435565948
# Average of peers' local losses: 2.195157
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.029
#
# Average test loss: 2.2769, Test accuracy: 2118/10000 (21.18%)
#
# Class      - Accuracy
# Zero       - 26.6
# One        - 86.3
# Two        - 3.8
# Three      - 0.0
# Four       - 0.0
# Five       - 0.0
# Six        - 55.0
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 30.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/200 |
#
#
# Selected Peers:
# Peer 60  is  attacker reputation: 0.0
# Peer 68  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.0
# Peer 28  is  attacker reputation: 0.1488671451807022
# Peer 31  is  honest reputation: 0.17795045673847198
# Peer 3  is  honest reputation: 0.0
# Peer 8  is  attacker reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 1  is  honest reputation: 0.0
# Peer 51  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.04647281765937805
# Peer 99  is  attacker reputation: 0.0
# Peer 46  is  honest reputation: 0.01954670250415802
# Peer 55  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.09019645303487778
# Peer 21  is  attacker reputation: 0.0
# Peer 57  is  attacker reputation: 0.0
# Peer 93  is  honest reputation: 0.1092054694890976
# Peer 67  is  honest reputation: 0.0
# Peer 50  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.034109920263290405
# Peer 15  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.06409403681755066
# Peer 80  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.0
# Peer 63  is  honest reputation: 0.0
# Peer 90  is  attacker reputation: 0.0
# Peer 65  is  honest reputation: 0.07692201435565948
# Peer 12  is  attacker reputation: 0.04828441143035889
# Peer 58  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.05796457827091217
# Peer 62  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.061364203691482544
# Peer 86  is  honest reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 39  is  honest reputation: 0.0
# Peer 33  is  honest reputation: 0.036143749952316284
# Peer 74  is  honest reputation: 0.0
# Peer 87  is  attacker reputation: 0.0
# Peer 56  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.0
# Peer 43  is  attacker reputation: 0.0
# Peer 5  is  honest reputation: 0.0
# Average of peers' local losses: 2.172194
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.027
#
# Average test loss: 2.2650, Test accuracy: 1600/10000 (16.00%)
#
# Class      - Accuracy
# Zero       - 0.9
# One        - 48.5
# Two        - 0.7
# Three      - 0.0
# Four       - 0.0
# Five       - 0.0
# Six        - 5.1
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 97.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/200 |
#
#
# Selected Peers:
# Peer 26  is  honest reputation: 0.0
# Peer 54  is  honest reputation: 0.078433096408844
# Peer 3  is  honest reputation: 0.09145250916481018
# Peer 4  is  honest reputation: 0.024183154106140137
# Peer 82  is  honest reputation: 0.0
# Peer 83  is  honest reputation: 0.08912637084722519
# Peer 87  is  attacker reputation: 0.0
# Peer 21  is  attacker reputation: 0.061027705669403076
# Peer 20  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.08999219536781311
# Peer 80  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.07415705174207687
# Peer 7  is  honest reputation: 0.0
# Peer 48  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.10150973126292229
# Peer 64  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.10970160365104675
# Peer 1  is  honest reputation: 0.0
# Peer 86  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.017325878143310547
# Peer 63  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.048491910099983215
# Peer 79  is  honest reputation: 0.0
# Peer 0  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.04647281765937805
# Peer 85  is  honest reputation: 0.0
# Peer 84  is  honest reputation: 0.0
# Peer 32  is  attacker reputation: 0.13730384409427643
# Peer 9  is  honest reputation: 0.005248039960861206
# Peer 94  is  honest reputation: 0.01823614537715912
# Peer 89  is  honest reputation: 0.0
# Peer 97  is  attacker reputation: 0.0
# Peer 28  is  attacker reputation: 0.1488671451807022
# Peer 73  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.03830060362815857
# Peer 27  is  honest reputation: 0.06819108128547668
# Peer 95  is  honest reputation: 0.00015738606452941895
# Peer 76  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 10  is  honest reputation: 0.10065770894289017
# Peer 19  is  honest reputation: 0.03295423090457916
# Peer 50  is  honest reputation: 0.011482149362564087
# Peer 22  is  honest reputation: 0.03672561049461365
# Peer 78  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.0198839008808136
# Average of peers' local losses: 2.162657
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.028
# Average test loss: 2.2454, Test accuracy: 2113/10000 (21.13%)
#
# Class      - Accuracy
# Zero       - 20.4
# One        - 61.4
# Two        - 7.2
# Three      - 0.0
# Four       - 0.0
# Five       - 0.0
# Six        - 15.6
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 98.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/200 |
#
#
# Selected Peers:
# Peer 79  is  honest reputation: 0.0
# Peer 7  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 40  is  honest reputation: 0.10150973126292229
# Peer 31  is  honest reputation: 0.17795045673847198
# Peer 33  is  honest reputation: 0.036143749952316284
# Peer 87  is  attacker reputation: 0.0
# Peer 23  is  honest reputation: 0.0
# Peer 26  is  honest reputation: 0.0
# Peer 53  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.1406201273202896
# Peer 32  is  attacker reputation: 0.13730384409427643
# Peer 30  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.04665404558181763
# Peer 78  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.14202700555324554
# Peer 69  is  honest reputation: 0.0
# Peer 37  is  honest reputation: 0.21223898977041245
# Peer 48  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.017325878143310547
# Peer 15  is  honest reputation: 0.0
# Peer 24  is  attacker reputation: 0.1322605162858963
# Peer 50  is  honest reputation: 0.10544353723526001
# Peer 73  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.095282182097435
# Peer 74  is  honest reputation: 0.0
# Peer 81  is  honest reputation: 0.1301061511039734
# Peer 88  is  honest reputation: 0.03830060362815857
# Peer 4  is  honest reputation: 0.024183154106140137
# Peer 66  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.0
# Peer 77  is  honest reputation: 0.0
# Peer 49  is  honest reputation: 0.0
# Peer 90  is  attacker reputation: 0.03992781043052673
# Peer 67  is  honest reputation: 0.02539047598838806
# Peer 43  is  attacker reputation: 0.0
# Peer 47  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.1795947253704071
# Peer 10  is  honest reputation: 0.19836239889264107
# Peer 14  is  honest reputation: 0.0
# Peer 6  is  honest reputation: 0.0
# Peer 57  is  attacker reputation: 0.06381767988204956
# Peer 22  is  honest reputation: 0.020532473921775818
# Peer 96  is  honest reputation: 0.0
# Peer 41  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.13990242406725883
# Peer 55  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.01954670250415802
# Peer 39  is  honest reputation: 0.0
# Average of peers' local losses: 2.158875
# Mixing took 0.016
# -> Update reputation
# Aggregation took 0.028
#
# Average test loss: 2.2277, Test accuracy: 1423/10000 (14.23%)
#
# Class      - Accuracy
# Zero       - 2.7
# One        - 13.7
# Two        - 11.8
# Three      - 0.5
# Four       - 0.1
# Five       - 0.0
# Six        - 10.9
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 100.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/200 |
#
#
# Selected Peers:
# Peer 41  is  honest reputation: 0.0
# Peer 88  is  honest reputation: 0.03830060362815857
# Peer 82  is  honest reputation: 0.0
# Peer 99  is  attacker reputation: 0.0
# Peer 79  is  honest reputation: 0.0
# Peer 52  is  honest reputation: 0.0
# Peer 28  is  attacker reputation: 0.06792458146810532
# Peer 4  is  honest reputation: 0.024183154106140137
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 67  is  honest reputation: 0.21041256189346313
# Peer 40  is  honest reputation: 0.10150973126292229
# Peer 85  is  honest reputation: 0.095282182097435
# Peer 77  is  honest reputation: 0.0
# Peer 62  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.1406201273202896
# Peer 0  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.16691997647285461
# Peer 7  is  honest reputation: 0.1520511358976364
# Peer 13  is  attacker reputation: 0.015483036637306213
# Peer 34  is  attacker reputation: 0.04719516634941101
# Peer 91  is  honest reputation: 0.0
# Peer 90  is  attacker reputation: 0.003930926322937012
# Peer 69  is  honest reputation: 0.0
# Peer 9  is  honest reputation: 0.005248039960861206
# Peer 96  is  honest reputation: 0.0
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 81  is  honest reputation: 0.1301061511039734
# Peer 89  is  honest reputation: 0.19710738211870193
# Peer 29  is  attacker reputation: 0.0
# Peer 20  is  honest reputation: 0.0
# Peer 60  is  attacker reputation: 0.0
# Peer 49  is  honest reputation: 0.10717369616031647
# Peer 15  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.08999219536781311
# Peer 95  is  honest reputation: 0.23487477004528046
# Peer 74  is  honest reputation: 0.0
# Peer 11  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 35  is  honest reputation: 0.0
# Peer 72  is  honest reputation: 0.0
# Peer 68  is  honest reputation: 0.1795947253704071
# Peer 46  is  honest reputation: 0.01954670250415802
# Peer 43  is  attacker reputation: 0.0
# Peer 26  is  honest reputation: 0.14185558259487152
# Peer 71  is  honest reputation: 0.010877043008804321
# Peer 24  is  attacker reputation: 0.01276244968175888
# Peer 54  is  honest reputation: 0.078433096408844
# Peer 66  is  honest reputation: 0.14430786669254303
# Peer 84  is  honest reputation: 0.12951348721981049
# Average of peers' local losses: 2.138592
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.029
#
# Average test loss: 2.2160, Test accuracy: 2688/10000 (26.88%)
#
# Class      - Accuracy
# Zero       - 5.4
# One        - 86.9
# Two        - 36.6
# Three      - 2.0
# Four       - 2.6
# Five       - 0.0
# Six        - 23.4
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 99.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/200 |
#
#
# Selected Peers:
# Peer 62  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.14430786669254303
# Peer 3  is  honest reputation: 0.09145250916481018
# Peer 40  is  honest reputation: 0.18473667465150356
# Peer 96  is  honest reputation: 0.0
# Peer 13  is  attacker reputation: 0.015483036637306213
# Peer 67  is  honest reputation: 0.21041256189346313
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 80  is  honest reputation: 0.0
# Peer 43  is  attacker reputation: 0.1492530256509781
# Peer 1  is  honest reputation: 0.16074208915233612
# Peer 90  is  attacker reputation: 0.003930926322937012
# Peer 84  is  honest reputation: 0.12951348721981049
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 50  is  honest reputation: 0.10544353723526001
# Peer 55  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.19598333537578583
# Peer 74  is  honest reputation: 0.15821664035320282
# Peer 91  is  honest reputation: 0.002885863184928894
# Peer 32  is  attacker reputation: 0.13730384409427643
# Peer 88  is  honest reputation: 0.03830060362815857
# Peer 92  is  attacker reputation: 0.0
# Peer 78  is  honest reputation: 0.0
# Peer 95  is  honest reputation: 0.2843608632683754
# Peer 64  is  honest reputation: 0.0
# Peer 42  is  honest reputation: 0.12334080040454865
# Peer 39  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.095282182097435
# Peer 71  is  honest reputation: 0.010877043008804321
# Peer 77  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.19710738211870193
# Peer 6  is  honest reputation: 0.0
# Peer 46  is  honest reputation: 0.01954670250415802
# Peer 82  is  honest reputation: 0.019272133708000183
# Peer 10  is  honest reputation: 0.11766720749437809
# Peer 26  is  honest reputation: 0.21960905939340591
# Peer 33  is  honest reputation: 0.036143749952316284
# Peer 83  is  honest reputation: 0.08912637084722519
# Peer 86  is  honest reputation: 0.0
# Peer 58  is  honest reputation: 0.00534433126449585
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 76  is  honest reputation: 0.0
# Peer 60  is  attacker reputation: 0.0
# Peer 81  is  honest reputation: 0.19220329821109772
# Peer 31  is  honest reputation: 0.17795045673847198
# Peer 19  is  honest reputation: 0.006195135414600372
# Peer 49  is  honest reputation: 0.1379314586520195
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 16  is  honest reputation: 0.06409403681755066
# Peer 29  is  attacker reputation: 0.0
# Average of peers' local losses: 2.112623
# Mixing took 0.016
# -> Update reputation
# Aggregation took 0.029
#
# Average test loss: 2.1876, Test accuracy: 3832/10000 (38.32%)
# Class      - Accuracy
# Zero       - 0.1
# One        - 74.0
# Two        - 39.5
# Three      - 52.4
# Four       - 17.7
# Five       - 0.0
# Six        - 98.4
# Seven      - 1.7
# Eight      - 0.0
# Nine       - 91.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/200 |
#
#
# Selected Peers:
# Peer 34  is  attacker reputation: 0.04719516634941101
# Peer 6  is  honest reputation: 0.016355395317077637
# Peer 86  is  honest reputation: -0.004916071891784668
# Peer 73  is  honest reputation: 0.14123396575450897
# Peer 7  is  honest reputation: 0.28534845262765884
# Peer 33  is  honest reputation: 0.036143749952316284
# Peer 67  is  honest reputation: 0.21041256189346313
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 77  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.08999219536781311
# Peer 40  is  honest reputation: 0.18473667465150356
# Peer 60  is  attacker reputation: 0.06198170781135559
# Peer 81  is  honest reputation: 0.09774035960435867
# Peer 9  is  honest reputation: 0.005248039960861206
# Peer 95  is  honest reputation: 0.2533084936439991
# Peer 58  is  honest reputation: 0.07509464025497437
# Peer 91  is  honest reputation: 0.002885863184928894
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 3  is  honest reputation: 0.09145250916481018
# Peer 68  is  honest reputation: 0.2627345025539398
# Peer 31  is  honest reputation: 0.021618641912937164
# Peer 71  is  honest reputation: 0.010877043008804321
# Peer 98  is  attacker reputation: -0.00047215819358825684
# Peer 82  is  honest reputation: 0.07010140269994736
# Peer 10  is  honest reputation: 0.1504085110500455
# Peer 46  is  honest reputation: 0.01954670250415802
# Peer 84  is  honest reputation: 0.12951348721981049
# Peer 27  is  honest reputation: 0.10958844423294067
# Peer 54  is  honest reputation: 0.078433096408844
# Peer 42  is  honest reputation: 0.12334080040454865
# Peer 51  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.16581924259662628
# Peer 72  is  honest reputation: 0.0
# Peer 22  is  honest reputation: 0.020532473921775818
# Peer 57  is  attacker reputation: 0.06381767988204956
# Peer 35  is  honest reputation: 0.036421969532966614
# Peer 44  is  honest reputation: 0.16691997647285461
# Peer 88  is  honest reputation: 0.0596935898065567
# Peer 50  is  honest reputation: 0.15608903765678406
# Peer 32  is  attacker reputation: 0.13730384409427643
# Peer 23  is  honest reputation: 0.18331971019506454
# Peer 49  is  honest reputation: 0.056069131940603256
# Peer 26  is  honest reputation: 0.21960905939340591
# Peer 89  is  honest reputation: 0.19710738211870193
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 19  is  honest reputation: 0.006195135414600372
# Peer 43  is  attacker reputation: 0.1492530256509781
# Peer 30  is  honest reputation: 0.0
# Peer 76  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.15323903411626816
# Average of peers' local losses: 2.092274
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.029
#
# Average test loss: 2.1446, Test accuracy: 4142/10000 (41.42%)
#
# Class      - Accuracy
# Zero       - 4.7
# One        - 99.2
# Two        - 74.4
# Three      - 52.6
# Four       - 55.8
# Five       - 0.0
# Six        - 70.8
# Seven      - 0.0
# Eight      - 0.0
# Nine       - 44.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/200 |
#
#
# Selected Peers:
# Peer 86  is  honest reputation: -0.004916071891784668
# Peer 39  is  honest reputation: 0.0
# Peer 85  is  honest reputation: 0.095282182097435
# Peer 46  is  honest reputation: 0.050051249563694
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 22  is  honest reputation: -0.01750672608613968
# Peer 90  is  attacker reputation: 0.003930926322937012
# Peer 84  is  honest reputation: 0.12951348721981049
# Peer 72  is  honest reputation: 0.0
# Peer 57  is  attacker reputation: 0.11077186465263367
# Peer 96  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.1505390703678131
# Peer 18  is  honest reputation: -0.016106851398944855
# Peer 31  is  honest reputation: 0.021618641912937164
# Peer 37  is  honest reputation: 0.21223898977041245
# Peer 6  is  honest reputation: 0.016355395317077637
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 58  is  honest reputation: 0.10413262248039246
# Peer 1  is  honest reputation: 0.16074208915233612
# Peer 16  is  honest reputation: 0.04219578206539154
# Peer 79  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 19  is  honest reputation: 0.006195135414600372
# Peer 9  is  honest reputation: 0.005248039960861206
# Peer 99  is  attacker reputation: 0.14244671165943146
# Peer 82  is  honest reputation: 0.08329300209879875
# Peer 66  is  honest reputation: 0.121300108730793
# Peer 34  is  attacker reputation: 0.04719516634941101
# Peer 43  is  attacker reputation: 0.1492530256509781
# Peer 52  is  honest reputation: 0.0
# Peer 23  is  honest reputation: 0.18331971019506454
# Peer 60  is  attacker reputation: 0.06198170781135559
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 7  is  honest reputation: 0.2096545584499836
# Peer 54  is  honest reputation: 0.07536861300468445
# Peer 42  is  honest reputation: 0.12334080040454865
# Peer 62  is  honest reputation: 0.04670071601867676
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 89  is  honest reputation: 0.19710738211870193
# Peer 4  is  honest reputation: 0.024183154106140137
# Peer 33  is  honest reputation: 0.036143749952316284
# Peer 27  is  honest reputation: 0.10958844423294067
# Peer 74  is  honest reputation: 0.06989557668566704
# Peer 68  is  honest reputation: 0.2627345025539398
# Peer 71  is  honest reputation: 0.09260566532611847
# Peer 40  is  honest reputation: 0.12135374825447798
# Peer 13  is  attacker reputation: 0.015483036637306213
# Peer 29  is  attacker reputation: 0.0
# Peer 30  is  honest reputation: 0.0
# Peer 78  is  honest reputation: 0.09454154968261719
# Average of peers' local losses: 2.022863
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.029
#
# Average test loss: 2.1090, Test accuracy: 4211/10000 (42.11%)
#
# Class      - Accuracy
# Zero       - 7.7
# One        - 99.2
# Two        - 68.9
# Three      - 79.8
# Four       - 16.1
# Five       - 0.0
# Six        - 83.2
# Seven      - 2.1
# Eight      - 0.4
# Nine       - 50.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/200 |
#
#
# Selected Peers:
# Peer 85  is  honest reputation: 0.10976671427488327
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 90  is  attacker reputation: -0.022039934992790222
# Peer 51  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.11452855169773102
# Peer 29  is  attacker reputation: 0.0
# Peer 0  is  honest reputation: -0.008657574653625488
# Peer 55  is  honest reputation: 0.0
# Peer 67  is  honest reputation: 0.1505390703678131
# Peer 77  is  honest reputation: 0.0
# Peer 82  is  honest reputation: 0.055827727541327477
# Peer 7  is  honest reputation: 0.2096545584499836
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 52  is  honest reputation: 0.0
# Peer 66  is  honest reputation: 0.19846251979470253
# Peer 49  is  honest reputation: 0.056069131940603256
# Peer 46  is  honest reputation: 0.03302742913365364
# Peer 18  is  honest reputation: -0.016106851398944855
# Peer 79  is  honest reputation: 0.04318559169769287
# Peer 76  is  honest reputation: 0.0
# Peer 12  is  attacker reputation: 0.16581924259662628
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 60  is  attacker reputation: 0.06198170781135559
# Peer 1  is  honest reputation: 0.16074208915233612
# Peer 24  is  attacker reputation: 0.01276244968175888
# Peer 91  is  honest reputation: -0.025387562811374664
# Peer 35  is  honest reputation: 0.036421969532966614
# Peer 93  is  honest reputation: 0.1739057805389166
# Peer 19  is  honest reputation: 0.006195135414600372
# Peer 63  is  honest reputation: -0.01604601740837097
# Peer 92  is  attacker reputation: 0.0
# Peer 37  is  honest reputation: 0.21223898977041245
# Peer 71  is  honest reputation: 0.09260566532611847
# Peer 53  is  honest reputation: 0.0
# Peer 31  is  honest reputation: 0.021618641912937164
# Peer 99  is  attacker reputation: 0.14244671165943146
# Peer 42  is  honest reputation: 0.09137556701898575
# Peer 15  is  honest reputation: -0.03365691006183624
# Peer 33  is  honest reputation: 0.16980411112308502
# Peer 23  is  honest reputation: 0.1708775870501995
# Peer 26  is  honest reputation: 0.21960905939340591
# Peer 4  is  honest reputation: 0.1177789568901062
# Peer 58  is  honest reputation: -0.012029901146888733
# Peer 57  is  attacker reputation: 0.11077186465263367
# Peer 30  is  honest reputation: 0.0
# Peer 44  is  honest reputation: 0.16691997647285461
# Peer 89  is  honest reputation: 0.11198786273598671
# Peer 3  is  honest reputation: 0.09957154095172882
# Peer 81  is  honest reputation: 0.09774035960435867
# Peer 95  is  honest reputation: 0.167356351390481
# Average of peers' local losses: 1.973974
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.029
# Average test loss: 2.0700, Test accuracy: 3716/10000 (37.16%)
#
# Class      - Accuracy
# Zero       - 1.1
# One        - 97.6
# Two        - 4.7
# Three      - 60.9
# Four       - 19.5
# Five       - 6.3
# Six        - 22.8
# Seven      - 25.5
# Eight      - 93.3
# Nine       - 29.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/200 |
#
#
# Selected Peers:
# Peer 86  is  honest reputation: -0.004916071891784668
# Peer 62  is  honest reputation: 0.04670071601867676
# Peer 77  is  honest reputation: 0.15076379477977753
# Peer 82  is  honest reputation: 0.055827727541327477
# Peer 53  is  honest reputation: 0.0
# Peer 75  is  attacker reputation: 0.11452855169773102
# Peer 60  is  attacker reputation: 0.06198170781135559
# Peer 32  is  attacker reputation: -0.04976210743188858
# Peer 11  is  honest reputation: 0.0
# Peer 3  is  honest reputation: 0.19965165108442307
# Peer 12  is  attacker reputation: 0.16581924259662628
# Peer 51  is  honest reputation: 0.0
# Peer 93  is  honest reputation: 0.1739057805389166
# Peer 50  is  honest reputation: 0.08028583228588104
# Peer 90  is  attacker reputation: -0.022039934992790222
# Peer 7  is  honest reputation: 0.2096545584499836
# Peer 58  is  honest reputation: -0.012029901146888733
# Peer 95  is  honest reputation: 0.057465885765850544
# Peer 71  is  honest reputation: 0.09260566532611847
# Peer 41  is  honest reputation: -0.052101343870162964
# Peer 57  is  attacker reputation: 0.11077186465263367
# Peer 27  is  honest reputation: 0.10958844423294067
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 9  is  honest reputation: 0.12703417241573334
# Peer 84  is  honest reputation: 0.15599899739027023
# Peer 13  is  attacker reputation: 0.015483036637306213
# Peer 39  is  honest reputation: 0.0
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 78  is  honest reputation: 0.09454154968261719
# Peer 26  is  honest reputation: 0.2740064300596714
# Peer 18  is  honest reputation: -0.016106851398944855
# Peer 45  is  honest reputation: -0.032631129026412964
# Peer 33  is  honest reputation: 0.25941913574934006
# Peer 23  is  honest reputation: 0.11896394751966
# Peer 10  is  honest reputation: 0.1504085110500455
# Peer 67  is  honest reputation: 0.253775954246521
# Peer 73  is  honest reputation: 0.08458682149648666
# Peer 79  is  honest reputation: 0.04318559169769287
# Peer 46  is  honest reputation: 0.03302742913365364
# Peer 81  is  honest reputation: 0.18981166556477547
# Peer 6  is  honest reputation: 0.016355395317077637
# Peer 4  is  honest reputation: 0.1177789568901062
# Peer 15  is  honest reputation: 0.021875686943531036
# Peer 28  is  attacker reputation: -0.04431106522679329
# Peer 68  is  honest reputation: 0.2627345025539398
# Peer 37  is  honest reputation: 0.21223898977041245
# Peer 40  is  honest reputation: 0.12135374825447798
# Peer 52  is  honest reputation: 0.0
# Peer 64  is  honest reputation: 0.0
# Peer 16  is  honest reputation: 0.04219578206539154
# Average of peers' local losses: 1.935096
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.028
#
# Average test loss: 2.0148, Test accuracy: 5483/10000 (54.83%)
#
# Class      - Accuracy
# Zero       - 0.2
# One        - 98.1
# Two        - 36.4
# Three      - 72.8
# Four       - 28.9
# Five       - 13.7
# Six        - 75.5
# Seven      - 61.0
# Eight      - 64.1
# Nine       - 86.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/200 |
#
#
# Selected Peers:
# Peer 1  is  honest reputation: 0.16074208915233612
# Peer 12  is  attacker reputation: 0.16581924259662628
# Peer 44  is  honest reputation: 0.22407913208007812
# Peer 79  is  honest reputation: 0.15326958894729614
# Peer 18  is  honest reputation: -0.016106851398944855
# Peer 32  is  attacker reputation: -0.04976210743188858
# Peer 76  is  honest reputation: 0.1106986254453659
# Peer 85  is  honest reputation: 0.12078772112727165
# Peer 3  is  honest reputation: 0.20134523138403893
# Peer 40  is  honest reputation: 0.12135374825447798
# Peer 68  is  honest reputation: 0.2627345025539398
# Peer 39  is  honest reputation: 0.0
# Peer 13  is  attacker reputation: 0.015483036637306213
# Peer 89  is  honest reputation: 0.11198786273598671
# Peer 26  is  honest reputation: 0.19703415222465992
# Peer 72  is  honest reputation: 0.0
# Peer 86  is  honest reputation: -0.004916071891784668
# Peer 93  is  honest reputation: 0.21549546252936125
# Peer 24  is  attacker reputation: 0.01276244968175888
# Peer 27  is  honest reputation: 0.10958844423294067
# Peer 60  is  attacker reputation: -0.0009185522794723511
# Peer 87  is  attacker reputation: -0.06030978262424469
# Peer 71  is  honest reputation: 0.09260566532611847
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 94  is  honest reputation: -0.021409831941127777
# Peer 88  is  honest reputation: 0.08984453231096268
# Peer 33  is  honest reputation: 0.25941913574934006
# Peer 46  is  honest reputation: 0.03302742913365364
# Peer 67  is  honest reputation: 0.22956547141075134
# Peer 51  is  honest reputation: 0.0
# Peer 74  is  honest reputation: 0.15534979663789272
# Peer 37  is  honest reputation: 0.21223898977041245
# Peer 28  is  attacker reputation: -0.04431106522679329
# Peer 90  is  attacker reputation: -0.022039934992790222
# Peer 31  is  honest reputation: 0.021618641912937164
# Peer 43  is  attacker reputation: 0.17237690836191177
# Peer 6  is  honest reputation: 0.016355395317077637
# Peer 82  is  honest reputation: 0.055827727541327477
# Peer 53  is  honest reputation: 0.17048949003219604
# Peer 45  is  honest reputation: -0.032631129026412964
# Peer 23  is  honest reputation: 0.196584845893085
# Peer 95  is  honest reputation: 0.040739806834608316
# Peer 16  is  honest reputation: 0.04219578206539154
# Peer 49  is  honest reputation: 0.11003060452640057
# Peer 7  is  honest reputation: 0.2096545584499836
# Peer 48  is  honest reputation: 0.03988261520862579
# Peer 34  is  attacker reputation: 0.1761469691991806
# Peer 41  is  honest reputation: -0.052101343870162964
# Peer 9  is  honest reputation: 0.06408322602510452
# Peer 81  is  honest reputation: 0.18981166556477547
# Average of peers' local losses: 1.869881
# Mixing took 0.017
# -> Update reputation
# Aggregation took 0.028
#
# Average test loss: 1.9337, Test accuracy: 5351/10000 (53.51%)
#
# Class      - Accuracy
# Zero       - 83.4
# One        - 99.4
# Two        - 23.4
# Three      - 82.4
# Four       - 46.8
# Five       - 0.9
# Six        - 83.5
# Seven      - 24.6
# Eight      - 26.8
# Nine       - 54.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/200 |
#
#
# Selected Peers:
# Peer 21  is  attacker reputation: 0.22843798249959946
# Peer 74  is  honest reputation: 0.15534979663789272
# Peer 3  is  honest reputation: 0.21918333880603313
# Peer 1  is  honest reputation: 0.16074208915233612
# Peer 88  is  honest reputation: 0.08984453231096268
# Peer 39  is  honest reputation: 0.1400357484817505
# Peer 68  is  honest reputation: 0.2627345025539398
# Peer 53  is  honest reputation: 0.14459112286567688
# Peer 6  is  honest reputation: 0.016355395317077637
# Peer 24  is  attacker reputation: 0.01276244968175888
# Peer 90  is  attacker reputation: -0.022039934992790222
# Peer 84  is  honest reputation: 0.07630104944109917
# Peer 82  is  honest reputation: 0.10476848017424345
# Peer 48  is  honest reputation: 0.05901525169610977
# Peer 34  is  attacker reputation: 0.1761469691991806
# Peer 59  is  honest reputation: 0.09989161789417267
# Peer 43  is  attacker reputation: 0.17237690836191177
# Peer 13  is  attacker reputation: 0.14265788346529007
# Peer 92  is  attacker reputation: -0.018028706312179565
# Peer 32  is  attacker reputation: -0.04976210743188858
# Peer 99  is  attacker reputation: 0.16298725455999374
# Peer 67  is  honest reputation: 0.2074917107820511
# Peer 42  is  honest reputation: 0.09137556701898575
# Peer 55  is  honest reputation: 0.0
# Peer 89  is  honest reputation: 0.11777524836361408
# Peer 75  is  attacker reputation: 0.11452855169773102
# Peer 63  is  honest reputation: -0.01604601740837097
# Peer 79  is  honest reputation: 0.16962987184524536
# Peer 95  is  honest reputation: 0.040739806834608316
# Peer 15  is  honest reputation: 0.07596716657280922
# Peer 29  is  attacker reputation: 0.0060095638036727905
# Peer 77  is  honest reputation: 0.19346895068883896
# Peer 27  is  honest reputation: 0.10958844423294067
# Peer 16  is  honest reputation: -0.056596748530864716
# Peer 76  is  honest reputation: 0.1106986254453659
# Peer 18  is  honest reputation: -0.016106851398944855
# Peer 49  is  honest reputation: -0.016532772220671177
# Peer 73  is  honest reputation: 0.08458682149648666
# Peer 91  is  honest reputation: -0.025387562811374664
# Peer 86  is  honest reputation: -0.004916071891784668
# Peer 9  is  honest reputation: 0.06408322602510452
# Peer 41  is  honest reputation: -0.052101343870162964
# Peer 69  is  honest reputation: 0.1347857266664505
# Peer 33  is  honest reputation: 0.25941913574934006
# Peer 60  is  attacker reputation: 0.11358586698770523
# Peer 62  is  honest reputation: 0.01925480365753174
# Peer 10  is  honest reputation: 0.1504085110500455
# Peer 23  is  honest reputation: 0.15327028697356582
# Peer 85  is  honest reputation: 0.12078772112727165
# Peer 78  is  honest reputation: 0.17994898557662964

# %%
RULE = 'ffl'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, strategy = 's2', resume = False)
